# %% [markdown]
# #### In this notebook we apply the following steps to prepare our data for classification:
#
# 1. Remove data items with less than 3 seconds of total data
# 2. Remove the last second of data to remove signs of intention to push the 'confused' button
# 3. Remove data items with > 90% invalid rows (row is invalid if all features are negative)
# 4. Replace negative feature values in remaining items with sentinel value of -1
# 5. Split the remaining data items into 4
# 6. Save data items in ./dataset/augmented/ directory

# %%
import os
import shutil
import math
import random

import pickle
import numpy as np
import pandas as pd

SAMPLES_PER_SECOND = 120 # hrz of tobii eye tracker

# %%
#load all paths to unaugmented data, get list of items, remove .DS_Store files
confused_path = '../dataset/unaugmented/confused/'
not_confused_path = '../dataset/unaugmented/not_confused/'
pump_confused_path = '../dataset/unaugmented/confused_PUMP_OpenEnded/'

confused_item_names = os.listdir(confused_path)
not_confused_item_names = os.listdir(not_confused_path)
pump_confused_item_names = os.listdir(pump_confused_path)

if '.DS_Store' in confused_item_names:
    confused_item_names.remove('.DS_Store')
if '.DS_Store' in not_confused_item_names:
    not_confused_item_names.remove('.DS_Store')
if '.DS_Store' in pump_confused_item_names:
    pump_confused_item_names.remove('.DS_Store')
    
print("initial number of not_confused points: ", len(not_confused_item_names))
print("initial number of confused points: ", len(confused_item_names))
print("initial number of pump and OE: ", len(pump_confused_item_names))
# Out:
# initial number of not_confused points:  5256
# initial number of confused points:  110
# initial number of pump and OE:  59

# %%
#1. Remove data items with less than 3 seconds of total data
pump_names_exclude = []
confused_names_exclude = []
not_confused_names_exclude = []

total = 0
too_short = 0

print("Pump Confused\n")

for i in range(len(pump_confused_item_names)):
    f = open('../dataset/unaugmented/confused_PUMP_OpenEnded/'+pump_confused_item_names[i], 'rb')
    item = pickle.load(f)
    if item.shape[0] < SAMPLES_PER_SECOND*3:
        pump_names_exclude.append(pump_confused_item_names[i])
        too_short+= 1
        print("too short: ", pump_confused_item_names[i])
    total+=1
    f.close()
    
print("\nNot Confused\n")
    
for i in range(len(not_confused_item_names)):
    f = open('../dataset/unaugmented/not_confused/'+not_confused_item_names[i], 'rb')
    item = pickle.load(f)
    if item.shape[0] < SAMPLES_PER_SECOND*3:
        not_confused_names_exclude.append(not_confused_item_names[i])
        too_short+= 1
        print("too short: ", not_confused_item_names[i])
    total+=1
    f.close()

print("\nConfused\n")
        
for i in range(len(confused_item_names)):
    f = open('../dataset/unaugmented/confused/'+confused_item_names[i], 'rb')
    item = pickle.load(f)
    if item.shape[0] < SAMPLES_PER_SECOND*3:
        confused_names_exclude.append(confused_item_names[i])
        too_short+= 1
        print("too short: ", confused_item_names[i])
    total+=1
    f.close()
    
print(total)
print(too_short)
print()
print("excluding %d not confused points "% len(not_confused_names_exclude))
print("excluding %d confused points "% len(confused_names_exclude))
print("excluding %d pump or OE points "% len(pump_names_exclude))

print("not_confused points remaining: ", len(not_confused_item_names)-len(not_confused_names_exclude))
print("confused points remaining: ", len(confused_item_names)-len(confused_names_exclude))
print("pump or OE points remaining: ", len(pump_confused_item_names)-len(pump_names_exclude))
# Out:
# Pump Confused
#
# too short:  107b_V-Open_Ended.pkl
#
# Not Confused
#
# too short:  100a_V-CDV-21.pkl
# too short:  100a_V-FE-24.pkl
# too short:  100a_V-RV-16.pkl
# too short:  100a_V-RV-20.pkl
# too short:  100a_V-SortOverall-23.pkl
# too short:  100a_V-SortTwoFactors-10.pkl
# too short:  100b_H-CDV-14.pkl
# too short:  100b_H-FE-15.pkl
# too short:  100b_H-RV-23.pkl
# too short:  100b_H-SortTwoFactors-11.pkl
# too short:  103a_H-FE-24.pkl
# too short:  103a_H-SortTwoFactors-6.pkl
# too short:  103b_V-CDV-5.pkl
# too short:  103b_V-RV-18.pkl
# too short:  104a_V-SortOverall-12.pkl
# too short:  104a_V-SortOverall-15.pkl
# too short:  104a_V-SortOverall-22.pkl
# too short:  104b_H-FE-17.pkl
# too short:  104b_H-RV-24.pkl
# too short:  105a_H-FE-9.pkl
# too short:  105b_V-FE-17.pkl
# too short:  105b_V-RV-11.pkl
# too short:  105b_V-SortTwoFactors-23.pkl
# too short:  106a_V-RV-17.pkl
# too short:  106a_V-SortOverall-16.pkl
# too short:  106b_H-RV-3.pkl
# too short:  107a_H-FE-20.pkl
# too short:  107a_H-RV-18.pkl
# too short:  107a_H-RV-23.pkl
# too short:  107a_H-RV-3.pkl
# too short:  107a_H-SortTwoFactors-16.pkl
# too short:  109b_V-FE-15.pkl
# too short:  109b_V-FE-20.pkl
# too short:  109b_V-RV-3.pkl
# too short:  109b_V-SortOverall-22.pkl
# too short:  10a_V-RV-20.pkl
# too short:  10a_V-SortTwoFactors-12.pkl
# too short:  10b_H-FE-22.pkl
# too short:  10b_H-FE-5.pkl
# too short:  10b_H-RV-18.pkl
# too short:  10b_H-RV-4.pkl
# too short:  110a_V-CDV-2.pkl
# too short:  110a_V-CDV-9.pkl
# too short:  110a_V-RV-15.pkl
# too short:  110a_V-RV-18.pkl
# too short:  110a_V-RV-6.pkl
# too short:  110b_H-CDV-11.pkl
# too short:  110b_H-FE-9.pkl
# too short:  110b_H-RV-2.pkl
# too short:  110b_H-SortTwoFactors-16.pkl
# too short:  111a_H-FE-11.pkl
# too short:  111a_H-FE-24.pkl
# too short:  111b_V-CDV-23.pkl
# too short:  111b_V-FE-24.pkl
# too short:  111b_V-RV-21.pkl
# too short:  111b_V-SortOverall-6.pkl
# too short:  112a_V-RV-22.pkl
# too short:  112b_H-FE-3.pkl
# too short:  112b_H-RV-12.pkl
# too short:  112b_H-RV-18.pkl
# too short:  113a_H-FE-24.pkl
# too short:  113a_H-RV-16.pkl
# too short:  114a_V-FE-24.pkl
# too short:  114a_V-SortOverall-3.pkl
# too short:  114a_V-SortTwoFactors-15.pkl
# too short:  114b_H-CDV-20.pkl
# too short:  114b_H-CDV-6.pkl
# too short:  114b_H-RV-18.pkl
# too short:  114b_H-RV-8.pkl
# too short:  116a_V-CDV-5.pkl
# too short:  116a_V-FE-17.pkl
# too short:  116a_V-SortOverall-21.pkl
# too short:  116a_V-SortOverall-6.pkl
# too short:  116a_V-SortTwoFactors-8.pkl
# too short:  116b_H-CDV-8.pkl
# too short:  116b_H-FE-14.pkl
# too short:  116b_H-SortOverall-12.pkl
# too short:  118a_V-SortOverall-2.pkl
# too short:  118a_V-SortTwoFactors-6.pkl
# too short:  11a_H-RV-15.pkl
# too short:  11a_H-RV-18.pkl
# too short:  11b_V-RV-18.pkl
# too short:  11b_V-SortTwoFactors-9.pkl
# too short:  121a_H-FE-11.pkl
# too short:  121a_H-RV-12.pkl
# too short:  121a_H-RV-16.pkl
# too short:  121a_H-SortOverall-6.pkl
# too short:  121b_V-CDV-5.pkl
# too short:  121b_V-CDV-9.pkl
# too short:  121b_V-FE-23.pkl
# too short:  121b_V-RV-15.pkl
# too short:  121b_V-SortOverall-10.pkl
# too short:  121b_V-SortOverall-16.pkl
# too short:  121b_V-SortOverall-24.pkl
# too short:  122a_V-CDV-8.pkl
# too short:  122a_V-RV-14.pkl
# too short:  122a_V-RV-18.pkl
# too short:  122a_V-SortTwoFactors-22.pkl
# too short:  122b_H-CDV-21.pkl
# too short:  123a_H-FE-4.pkl
# too short:  123b_V-FE-16.pkl
# too short:  123b_V-SortTwoFactors-23.pkl
# too short:  123b_V-SortTwoFactors-9.pkl
# too short:  124a_H-CDV-2.pkl
# too short:  124a_H-RV-18.pkl
# too short:  124b_V-CDV-11.pkl
# too short:  124b_V-CDV-6.pkl
# too short:  124b_V-FE-5.pkl
# too short:  124b_V-RV-18.pkl
# too short:  124b_V-RV-4.pkl
# too short:  125a_H-SortOverall-24.pkl
# too short:  125b_V-CDV-2.pkl
# too short:  125b_V-CDV-21.pkl
# too short:  125b_V-FE-20.pkl
# too short:  125b_V-SortOverall-6.pkl
# too short:  125b_V-SortTwoFactors-11.pkl
# too short:  126a_V-RV-18.pkl
# too short:  126b_H-CDV-24.pkl
# too short:  126b_H-RV-4.pkl
# too short:  126b_H-SortOverall-3.pkl
# too short:  126b_H-SortTwoFactors-17.pkl
# too short:  127a_H-CDV-8.pkl
# too short:  127a_H-RV-17.pkl
# too short:  127a_H-SortOverall-22.pkl
# too short:  127b_V-FE-24.pkl
# too short:  127b_V-RV-18.pkl
# too short:  127b_V-RV-8.pkl
# too short:  128a_V-FE-5.pkl
# too short:  129a_H-FE-5.pkl
# too short:  12a_V-CDV-17.pkl
# too short:  12a_V-FE-2.pkl
# too short:  12a_V-FE-24.pkl
# too short:  12a_V-RV-6.pkl
# too short:  12a_V-SortOverall-15.pkl
# too short:  12a_V-SortOverall-20.pkl
# too short:  12a_V-SortOverall-3.pkl
# too short:  12a_V-SortOverall-8.pkl
# too short:  12b_H-CDV-20.pkl
# too short:  12b_H-FE-11.pkl
# too short:  12b_H-SortOverall-10.pkl
# too short:  130a_V-RV-18.pkl
# too short:  130a_V-SortOverall-3.pkl
# too short:  130b_H-FE-6.pkl
# too short:  130b_H-SortOverall-20.pkl
# too short:  131a_H-RV-10.pkl
# too short:  131a_H-RV-18.pkl
# too short:  131a_H-SortTwoFactors-14.pkl
# too short:  131b_V-CDV-10.pkl
# too short:  131b_V-CDV-17.pkl
# too short:  131b_V-CDV-2.pkl
# too short:  131b_V-RV-5.pkl
# too short:  132a_V-CDV-20.pkl
# too short:  132a_V-RV-18.pkl
# too short:  132a_V-SortOverall-15.pkl
# too short:  132b_H-RV-22.pkl
# too short:  133a_H-SortOverall-4.pkl
# too short:  133b_V-CDV-22.pkl
# too short:  134a_V-FE-10.pkl
# too short:  134a_V-FE-15.pkl
# too short:  134b_H-SortTwoFactors-14.pkl
# too short:  134b_H-SortTwoFactors-21.pkl
# too short:  137a_H-RV-22.pkl
# too short:  137a_H-SortOverall-15.pkl
# too short:  138a_V-CDV-8.pkl
# too short:  138a_V-FE-17.pkl
# too short:  138a_V-FE-21.pkl
# too short:  139a_H-CDV-14.pkl
# too short:  139a_H-CDV-21.pkl
# too short:  139a_H-RV-22.pkl
# too short:  139a_H-SortOverall-10.pkl
# too short:  139b_V-FE-3.pkl
# too short:  13a_H-RV-18.pkl
# too short:  13a_H-RV-6.pkl
# too short:  13b_V-CDV-2.pkl
# too short:  13b_V-RV-3.pkl
# too short:  13b_V-SortOverall-15.pkl
# too short:  13b_V-SortOverall-20.pkl
# too short:  13b_V-SortTwoFactors-10.pkl
# too short:  140a_V-RV-18.pkl
# too short:  140a_V-SortOverall-12.pkl
# too short:  140b_H-FE-15.pkl
# too short:  140b_H-RV-11.pkl
# too short:  140b_H-RV-21.pkl
# too short:  140b_H-SortTwoFactors-23.pkl
# too short:  141a_H-FE-23.pkl
# too short:  141b_V-CDV-23.pkl
# too short:  141b_V-CDV-9.pkl
# too short:  141b_V-FE-21.pkl
# too short:  141b_V-RV-22.pkl
# too short:  141b_V-SortOverall-12.pkl
# too short:  142a_V-SortTwoFactors-4.pkl
# too short:  143a_H-SortTwoFactors-12.pkl
# too short:  143b_V-CDV-9.pkl
# too short:  143b_V-RV-12.pkl
# too short:  143b_V-RV-14.pkl
# too short:  144a_V-CDV-12.pkl
# too short:  144a_V-RV-18.pkl
# too short:  144b_H-RV-5.pkl
# too short:  145a_H-RV-18.pkl
# too short:  145a_H-SortOverall-16.pkl
# too short:  145b_V-CDV-22.pkl
# too short:  145b_V-FE-16.pkl
# too short:  145b_V-FE-23.pkl
# too short:  145b_V-SortOverall-8.pkl
# too short:  146a_V-CDV-4.pkl
# too short:  146a_V-SortOverall-23.pkl
# too short:  146b_H-FE-16.pkl
# too short:  146b_H-FE-4.pkl
# too short:  146b_H-RV-18.pkl
# too short:  146b_H-SortOverall-22.pkl
# too short:  146b_H-SortOverall-5.pkl
# too short:  148a_V-CDV-24.pkl
# too short:  148a_V-RV-18.pkl
# too short:  148b_H-CDV-10.pkl
# too short:  148b_H-RV-11.pkl
# too short:  149a_H-FE-17.pkl
# too short:  149a_H-FE-3.pkl
# too short:  149b_V-CDV-15.pkl
# too short:  149b_V-FE-14.pkl
# too short:  149b_V-SortTwoFactors-17.pkl
# too short:  149b_V-SortTwoFactors-22.pkl
# too short:  14b_H-FE-9.pkl
# too short:  14b_H-RV-5.pkl
# too short:  14b_H-SortTwoFactors-24.pkl
# too short:  150a_V-RV-5.pkl
# too short:  150a_V-SortOverall-22.pkl
# too short:  150b_H-CDV-15.pkl
# too short:  150b_H-CDV-24.pkl
# too short:  150b_H-RV-20.pkl
# too short:  152a_V-CDV-21.pkl
# too short:  152a_V-CDV-9.pkl
# too short:  152a_V-FE-11.pkl
# too short:  152a_V-SortOverall-16.pkl
# too short:  152a_V-SortOverall-20.pkl
# too short:  152b_H-FE-17.pkl
# too short:  152b_H-SortOverall-16.pkl
# too short:  15a_H-CDV-11.pkl
# too short:  15a_H-CDV-20.pkl
# too short:  15a_H-RV-18.pkl
# too short:  15a_H-SortOverall-14.pkl
# too short:  15a_H-SortOverall-4.pkl
# too short:  15b_V-SortOverall-9.pkl
# too short:  16a_V-CDV-11.pkl
# too short:  16a_V-RV-10.pkl
# too short:  16a_V-RV-20.pkl
# too short:  16a_V-RV-5.pkl
# too short:  16a_V-SortOverall-9.pkl
# too short:  16b_H-FE-12.pkl
# too short:  16b_H-FE-23.pkl
# too short:  17a_H-RV-17.pkl
# too short:  17a_H-SortTwoFactors-5.pkl
# too short:  17b_V-FE-21.pkl
# too short:  17b_V-RV-18.pkl
# too short:  18a_V-RV-16.pkl
# too short:  18a_V-SortOverall-14.pkl
# too short:  18b_H-CDV-15.pkl
# too short:  18b_H-CDV-4.pkl
# too short:  18b_H-FE-24.pkl
# too short:  18b_H-SortOverall-11.pkl
# too short:  18b_H-SortOverall-23.pkl
# too short:  19a_H-FE-8.pkl
# too short:  19a_H-RV-21.pkl
# too short:  19a_H-SortOverall-24.pkl
# too short:  1a_H-FE-21.pkl
# too short:  1a_H-RV-14.pkl
# too short:  1a_H-RV-18.pkl
# too short:  1a_H-RV-23.pkl
# too short:  20a_V-SortOverall-14.pkl
# too short:  20a_V-SortOverall-8.pkl
# too short:  20b_H-CDV-24.pkl
# too short:  20b_H-SortOverall-16.pkl
# too short:  21a_H-RV-8.pkl
# too short:  21a_H-SortOverall-14.pkl
# too short:  22a_V-CDV-9.pkl
# too short:  22a_V-FE-20.pkl
# too short:  22b_H-FE-14.pkl
# too short:  23a_H-CDV-11.pkl
# too short:  23a_H-CDV-14.pkl
# too short:  23a_H-CDV-20.pkl
# too short:  23a_H-FE-10.pkl
# too short:  23a_H-RV-18.pkl
# too short:  23a_H-RV-24.pkl
# too short:  23a_H-SortOverall-8.pkl
# too short:  23b_V-RV-5.pkl
# too short:  23b_V-SortOverall-22.pkl
# too short:  24a_V-CDV-16.pkl
# too short:  24a_V-CDV-22.pkl
# too short:  24a_V-FE-10.pkl
# too short:  24a_V-RV-14.pkl
# too short:  24a_V-RV-18.pkl
# too short:  24a_V-SortTwoFactors-8.pkl
# too short:  24b_H-CDV-23.pkl
# too short:  24b_H-CDV-4.pkl
# too short:  24b_H-FE-3.pkl
# too short:  24b_H-RV-20.pkl
# too short:  25a_H-FE-3.pkl
# too short:  25a_H-RV-15.pkl
# too short:  25b_V-CDV-22.pkl
# too short:  26a_V-RV-11.pkl
# too short:  26a_V-SortOverall-14.pkl
# too short:  26b_H-FE-21.pkl
# too short:  26b_H-FE-5.pkl
# too short:  26b_H-RV-15.pkl
# too short:  26b_H-SortOverall-17.pkl
# too short:  26b_H-SortTwoFactors-14.pkl
# too short:  27a_H-FE-14.pkl
# too short:  27b_V-CDV-12.pkl
# too short:  27b_V-CDV-16.pkl
# too short:  27b_V-SortTwoFactors-10.pkl
# too short:  27b_V-SortTwoFactors-2.pkl
# too short:  28b_H-SortTwoFactors-12.pkl
# too short:  29a_H-CDV-8.pkl
# too short:  29a_H-FE-21.pkl
# too short:  2a_V-CDV-14.pkl
# too short:  2a_V-RV-10.pkl
# too short:  2a_V-RV-16.pkl
# too short:  2a_V-SortTwoFactors-15.pkl
# too short:  2b_H-RV-24.pkl
# too short:  30a_V-RV-9.pkl
# too short:  30a_V-SortOverall-10.pkl
# too short:  30b_H-FE-16.pkl
# too short:  30b_H-RV-3.pkl
# too short:  31a_H-RV-11.pkl
# too short:  31a_H-RV-23.pkl
# too short:  31b_V-CDV-10.pkl
# too short:  31b_V-CDV-24.pkl
# too short:  31b_V-FE-22.pkl
# too short:  31b_V-FE-4.pkl
# too short:  31b_V-RV-14.pkl
# too short:  32a_V-CDV-5.pkl
# too short:  32a_V-RV-18.pkl
# too short:  32a_V-RV-24.pkl
# too short:  32a_V-SortOverall-17.pkl
# too short:  32a_V-SortOverall-9.pkl
# too short:  32b_H-RV-18.pkl
# too short:  33a_H-CDV-6.pkl
# too short:  33a_H-FE-10.pkl
# too short:  33a_H-RV-11.pkl
# too short:  33a_H-SortOverall-17.pkl
# too short:  33b_V-CDV-14.pkl
# too short:  33b_V-CDV-2.pkl
# too short:  33b_V-FE-17.pkl
# too short:  33b_V-FE-24.pkl
# too short:  33b_V-FE-4.pkl
# too short:  33b_V-RV-3.pkl
# too short:  33b_V-SortOverall-15.pkl
# too short:  33b_V-SortOverall-9.pkl
# too short:  34a_V-CDV-24.pkl
# too short:  34a_V-RV-14.pkl
# too short:  34b_H-CDV-22.pkl
# too short:  34b_H-RV-18.pkl
# too short:  34b_H-SortOverall-17.pkl
# too short:  35a_H-RV-10.pkl
# too short:  35a_H-RV-16.pkl
# too short:  35a_H-RV-18.pkl
# too short:  35a_H-RV-21.pkl
# too short:  35b_V-FE-12.pkl
# too short:  35b_V-RV-3.pkl
# too short:  35b_V-SortOverall-9.pkl
# too short:  36a_V-CDV-21.pkl
# too short:  36a_V-FE-16.pkl
# too short:  36a_V-RV-15.pkl
# too short:  36a_V-SortOverall-9.pkl
# too short:  36a_V-SortTwoFactors-14.pkl
# too short:  36b_H-CDV-14.pkl
# too short:  36b_H-RV-15.pkl
# too short:  36b_H-RV-4.pkl
# too short:  36b_H-SortTwoFactors-2.pkl
# too short:  37a_H-SortOverall-8.pkl
# too short:  37b_V-CDV-12.pkl
# too short:  37b_V-FE-9.pkl
# too short:  37b_V-SortOverall-11.pkl
# too short:  37b_V-SortOverall-3.pkl
# too short:  38a_V-FE-2.pkl
# too short:  38a_V-RV-18.pkl
# too short:  39a_H-CDV-23.pkl
# too short:  39a_H-CDV-9.pkl
# too short:  39a_H-FE-12.pkl
# too short:  39a_H-RV-18.pkl
# too short:  39a_H-RV-21.pkl
# too short:  39a_H-SortOverall-20.pkl
# too short:  39a_H-SortOverall-3.pkl
# too short:  39b_V-FE-23.pkl
# too short:  39b_V-RV-22.pkl
# too short:  39b_V-SortTwoFactors-21.pkl
# too short:  3a_H-CDV-24.pkl
# too short:  3a_H-CDV-5.pkl
# too short:  3a_H-RV-2.pkl
# too short:  3a_H-SortOverall-20.pkl
# too short:  3b_V-RV-18.pkl
# too short:  3b_V-SortTwoFactors-5.pkl
# too short:  40a_V-FE-22.pkl
# too short:  40a_V-RV-15.pkl
# too short:  41a_H-CDV-12.pkl
# too short:  41a_H-SortTwoFactors-21.pkl
# too short:  41a_H-SortTwoFactors-9.pkl
# too short:  41b_V-CDV-5.pkl
# too short:  41b_V-FE-23.pkl
# too short:  41b_V-RV-16.pkl
# too short:  41b_V-RV-6.pkl
# too short:  41b_V-SortTwoFactors-17.pkl
# too short:  42a_V-CDV-4.pkl
# too short:  42a_V-RV-6.pkl
# too short:  42a_V-SortOverall-11.pkl
# too short:  42b_H-RV-4.pkl
# too short:  42b_H-RV-8.pkl
# too short:  42b_H-SortTwoFactors-9.pkl
# too short:  43a_H-CDV-16.pkl
# too short:  43a_H-FE-17.pkl
# too short:  43b_V-FE-20.pkl
# too short:  43b_V-RV-16.pkl
# too short:  43b_V-RV-18.pkl
# too short:  43b_V-RV-8.pkl
# too short:  43b_V-SortOverall-22.pkl
# too short:  44a_V-RV-15.pkl
# too short:  44a_V-RV-18.pkl
# too short:  44b_H-RV-18.pkl
# too short:  44b_H-SortTwoFactors-15.pkl
# too short:  44b_H-SortTwoFactors-24.pkl
# too short:  44b_H-SortTwoFactors-6.pkl
# too short:  45a_H-CDV-10.pkl
# too short:  45a_H-CDV-17.pkl
# too short:  45a_H-SortOverall-3.pkl
# too short:  45b_V-CDV-14.pkl
# too short:  46a_V-RV-16.pkl
# too short:  46b_H-FE-20.pkl
# too short:  46b_H-RV-18.pkl
# too short:  46b_H-SortOverall-4.pkl
# too short:  46b_H-SortOverall-8.pkl
# too short:  46b_H-SortTwoFactors-23.pkl
# too short:  47a_H-CDV-16.pkl
# too short:  47a_H-CDV-9.pkl
# too short:  47a_H-FE-10.pkl
# too short:  47a_H-RV-15.pkl
# too short:  47a_H-RV-2.pkl
# too short:  47a_H-SortOverall-17.pkl
# too short:  47b_V-CDV-22.pkl
# too short:  47b_V-FE-24.pkl
# too short:  47b_V-FE-9.pkl
# too short:  48a_V-CDV-15.pkl
# too short:  48a_V-CDV-23.pkl
# too short:  48a_V-FE-8.pkl
# too short:  48b_H-FE-5.pkl
# too short:  48b_H-RV-3.pkl
# too short:  48b_H-SortOverall-17.pkl
# too short:  48b_H-SortOverall-20.pkl
# too short:  49b_V-CDV-4.pkl
# too short:  49b_V-RV-3.pkl
# too short:  49b_V-SortOverall-24.pkl
# too short:  4a_V-FE-24.pkl
# too short:  4a_V-RV-14.pkl
# too short:  4a_V-RV-18.pkl
# too short:  4b_H-SortOverall-20.pkl
# too short:  4b_H-SortTwoFactors-12.pkl
# too short:  50a_V-CDV-10.pkl
# too short:  50a_V-CDV-2.pkl
# too short:  50a_V-FE-8.pkl
# too short:  50a_V-RV-20.pkl
# too short:  50a_V-SortOverall-21.pkl
# too short:  50a_V-SortOverall-3.pkl
# too short:  50b_H-CDV-5.pkl
# too short:  50b_H-RV-23.pkl
# too short:  52a_V-FE-22.pkl
# too short:  52b_H-RV-14.pkl
# too short:  52b_H-SortOverall-2.pkl
# too short:  52b_H-SortTwoFactors-17.pkl
# too short:  54a_V-CDV-10.pkl
# too short:  54a_V-CDV-15.pkl
# too short:  54a_V-FE-23.pkl
# too short:  54a_V-RV-18.pkl
# too short:  54a_V-SortTwoFactors-4.pkl
# too short:  54b_H-RV-14.pkl
# too short:  54b_H-RV-6.pkl
# too short:  54b_H-SortOverall-8.pkl
# too short:  55a_H-CDV-11.pkl
# too short:  55a_H-FE-22.pkl
# too short:  55a_H-SortOverall-10.pkl
# too short:  55a_H-SortOverall-14.pkl
# too short:  55a_H-SortTwoFactors-15.pkl
# too short:  55b_V-CDV-20.pkl
# too short:  55b_V-RV-18.pkl
# too short:  56a_V-CDV-24.pkl
# too short:  56a_V-FE-22.pkl
# too short:  56a_V-RV-12.pkl
# too short:  56a_V-SortOverall-11.pkl
# too short:  56a_V-SortOverall-4.pkl
# too short:  56b_H-CDV-5.pkl
# too short:  56b_H-FE-10.pkl
# too short:  56b_H-FE-3.pkl
# too short:  56b_H-RV-6.pkl
# too short:  57a_H-CDV-21.pkl
# too short:  57a_H-CDV-3.pkl
# too short:  57a_H-FE-10.pkl
# too short:  57a_H-FE-6.pkl
# too short:  57a_H-RV-18.pkl
# too short:  57a_H-SortOverall-12.pkl
# too short:  57a_H-SortTwoFactors-15.pkl
# too short:  57a_H-SortTwoFactors-23.pkl
# too short:  57b_V-FE-4.pkl
# too short:  57b_V-SortOverall-3.pkl
# too short:  58b_H-FE-11.pkl
# too short:  58b_H-RV-18.pkl
# too short:  59b_V-CDV-12.pkl
# too short:  59b_V-RV-3.pkl
# too short:  59b_V-RV-9.pkl
# too short:  60a_V-FE-22.pkl
# too short:  60a_V-RV-18.pkl
# too short:  60a_V-SortOverall-10.pkl
# too short:  60b_H-CDV-2.pkl
# too short:  60b_H-RV-18.pkl
# too short:  61a_V-CDV-22.pkl
# too short:  61a_V-CDV-9.pkl
# too short:  61a_V-FE-15.pkl
# too short:  61a_V-RV-21.pkl
# too short:  61b_H-CDV-4.pkl
# too short:  61b_H-FE-6.pkl
# too short:  61b_H-SortOverall-9.pkl
# too short:  61b_H-SortTwoFactors-22.pkl
# too short:  62a_H-CDV-17.pkl
# too short:  62a_H-SortOverall-16.pkl
# too short:  62a_H-SortOverall-6.pkl
# too short:  62b_V-FE-12.pkl
# too short:  62b_V-FE-17.pkl
# too short:  62b_V-RV-18.pkl
# too short:  62b_V-SortOverall-14.pkl
# too short:  62b_V-SortOverall-24.pkl
# too short:  62b_V-SortTwoFactors-10.pkl
# too short:  63a_H-CDV-17.pkl
# too short:  63a_H-CDV-20.pkl
# too short:  63a_H-FE-15.pkl
# too short:  63a_H-RV-18.pkl
# too short:  63a_H-RV-9.pkl
# too short:  63a_H-SortOverall-24.pkl
# too short:  63b_V-CDV-16.pkl
# too short:  63b_V-FE-22.pkl
# too short:  63b_V-FE-8.pkl
# too short:  63b_V-SortOverall-15.pkl
# too short:  63b_V-SortOverall-23.pkl
# too short:  63b_V-SortOverall-9.pkl
# too short:  64a_V-FE-22.pkl
# too short:  64a_V-RV-16.pkl
# too short:  64a_V-RV-18.pkl
# too short:  64a_V-SortOverall-15.pkl
# too short:  64b_H-FE-10.pkl
# too short:  64b_H-RV-9.pkl
# too short:  64b_H-SortOverall-21.pkl
# too short:  65b_V-FE-23.pkl
# too short:  65b_V-FE-6.pkl
# too short:  65b_V-SortOverall-3.pkl
# too short:  66a_V-CDV-22.pkl
# too short:  66b_H-FE-3.pkl
# too short:  67a_H-CDV-12.pkl
# too short:  67a_H-FE-10.pkl
# too short:  67a_H-FE-14.pkl
# too short:  67a_H-SortOverall-6.pkl
# too short:  67a_H-SortTwoFactors-20.pkl
# too short:  67b_V-FE-22.pkl
# too short:  67b_V-RV-18.pkl
# too short:  67b_V-RV-21.pkl
# too short:  69a_H-RV-23.pkl
# too short:  69b_V-CDV-20.pkl
# too short:  69b_V-FE-14.pkl
# too short:  69b_V-FE-24.pkl
# too short:  69b_V-RV-21.pkl
# too short:  69b_V-RV-4.pkl
# too short:  69b_V-SortOverall-16.pkl
# too short:  69b_V-SortOverall-6.pkl
# too short:  6a_V-CDV-10.pkl
# too short:  6a_V-CDV-15.pkl
# too short:  6a_V-CDV-4.pkl
# too short:  6a_V-RV-18.pkl
# too short:  6a_V-RV-9.pkl
# too short:  6a_V-SortOverall-8.pkl
# too short:  6b_H-CDV-11.pkl
# too short:  6b_H-CDV-24.pkl
# too short:  6b_H-FE-22.pkl
# too short:  6b_H-SortOverall-21.pkl
# too short:  70a_V-CDV-15.pkl
# too short:  70a_V-RV-17.pkl
# too short:  70a_V-RV-9.pkl
# too short:  70b_H-SortOverall-14.pkl
# too short:  70b_H-SortOverall-8.pkl
# too short:  70b_H-SortTwoFactors-4.pkl
# too short:  71a_H-FE-17.pkl
# too short:  71a_H-FE-20.pkl
# too short:  71a_H-RV-16.pkl
# too short:  71a_H-RV-3.pkl
# too short:  71a_H-RV-8.pkl
# too short:  71a_H-SortOverall-11.pkl
# too short:  71b_V-FE-20.pkl
# too short:  71b_V-FE-5.pkl
# too short:  71b_V-SortOverall-14.pkl
# too short:  72a_V-RV-14.pkl
# too short:  72a_V-SortOverall-2.pkl
# too short:  72b_H-CDV-6.pkl
# too short:  72b_H-CDV-8.pkl
# too short:  72b_H-FE-3.pkl
# too short:  72b_H-RV-14.pkl
# too short:  72b_H-RV-4.pkl
# too short:  73a_H-CDV-22.pkl
# too short:  73a_H-SortOverall-20.pkl
# too short:  73a_H-SortTwoFactors-17.pkl
# too short:  73b_V-RV-11.pkl
# too short:  73b_V-SortOverall-21.pkl
# too short:  74a_V-FE-14.pkl
# too short:  74b_H-CDV-24.pkl
# too short:  74b_H-RV-6.pkl
# too short:  74b_H-RV-9.pkl
# too short:  75a_H-CDV-3.pkl
# too short:  75a_H-FE-8.pkl
# too short:  75a_H-RV-12.pkl
# too short:  75a_H-RV-14.pkl
# too short:  75a_H-RV-18.pkl
# too short:  75a_H-SortTwoFactors-17.pkl
# too short:  75b_V-CDV-17.pkl
# too short:  75b_V-SortOverall-21.pkl
# too short:  76a_V-RV-14.pkl
# too short:  76a_V-RV-21.pkl
# too short:  76a_V-SortOverall-20.pkl
# too short:  76b_H-CDV-15.pkl
# too short:  76b_H-CDV-22.pkl
# too short:  76b_H-CDV-4.pkl
# too short:  76b_H-SortOverall-6.pkl
# too short:  77a_H-CDV-22.pkl
# too short:  77a_H-SortTwoFactors-2.pkl
# too short:  77b_V-FE-16.pkl
# too short:  77b_V-RV-15.pkl
# too short:  77b_V-RV-18.pkl
# too short:  78a_V-SortOverall-21.pkl
# too short:  78a_V-SortTwoFactors-6.pkl
# too short:  78b_H-RV-22.pkl
# too short:  79a_H-CDV-10.pkl
# too short:  79a_H-CDV-24.pkl
# too short:  79a_H-SortOverall-16.pkl
# too short:  79b_V-CDV-22.pkl
# too short:  79b_V-FE-16.pkl
# too short:  79b_V-FE-23.pkl
# too short:  79b_V-SortOverall-12.pkl
# too short:  7a_H-CDV-17.pkl
# too short:  7a_H-RV-14.pkl
# too short:  7a_H-SortOverall-24.pkl
# too short:  7b_V-CDV-23.pkl
# too short:  7b_V-SortOverall-21.pkl
# too short:  80a_V-CDV-14.pkl
# too short:  80a_V-CDV-21.pkl
# too short:  80a_V-CDV-9.pkl
# too short:  80a_V-FE-11.pkl
# too short:  80a_V-FE-17.pkl
# too short:  80a_V-FE-24.pkl
# too short:  80a_V-FE-6.pkl
# too short:  80a_V-RV-12.pkl
# too short:  80a_V-RV-15.pkl
# too short:  80a_V-RV-18.pkl
# too short:  80a_V-RV-4.pkl
# too short:  80a_V-SortOverall-23.pkl
# too short:  80a_V-SortOverall-5.pkl
# too short:  80a_V-SortOverall-8.pkl
# too short:  80a_V-SortTwoFactors-10.pkl
# too short:  80a_V-SortTwoFactors-16.pkl
# too short:  80a_V-SortTwoFactors-20.pkl
# too short:  80a_V-SortTwoFactors-3.pkl
# too short:  80b_H-CDV-17.pkl
# too short:  80b_H-CDV-24.pkl
# too short:  80b_H-CDV-3.pkl
# too short:  80b_H-CDV-9.pkl
# too short:  80b_H-FE-10.pkl
# too short:  80b_H-FE-16.pkl
# too short:  80b_H-FE-23.pkl
# too short:  80b_H-FE-6.pkl
# too short:  80b_H-RV-11.pkl
# too short:  80b_H-RV-14.pkl
# too short:  80b_H-RV-18.pkl
# too short:  80b_H-RV-2.pkl
# too short:  80b_H-RV-21.pkl
# too short:  80b_H-SortOverall-12.pkl
# too short:  80b_H-SortOverall-15.pkl
# too short:  80b_H-SortOverall-22.pkl
# too short:  80b_H-SortOverall-4.pkl
# too short:  80b_H-SortTwoFactors-20.pkl
# too short:  80b_H-SortTwoFactors-5.pkl
# too short:  80b_H-SortTwoFactors-8.pkl
# too short:  81a_H-SortOverall-17.pkl
# too short:  81b_V-CDV-8.pkl
# too short:  81b_V-FE-11.pkl
# too short:  81b_V-FE-17.pkl
# too short:  81b_V-RV-18.pkl
# too short:  81b_V-SortTwoFactors-22.pkl
# too short:  82a_V-FE-9.pkl
# too short:  82a_V-RV-2.pkl
# too short:  82a_V-RV-23.pkl
# too short:  82b_H-FE-10.pkl
# too short:  82b_H-RV-15.pkl
# too short:  83a_H-RV-20.pkl
# too short:  83b_V-CDV-21.pkl
# too short:  84b_H-CDV-11.pkl
# too short:  85b_V-CDV-17.pkl
# too short:  85b_V-FE-15.pkl
# too short:  85b_V-RV-14.pkl
# too short:  85b_V-SortOverall-6.pkl
# too short:  86a_V-CDV-15.pkl
# too short:  86a_V-RV-16.pkl
# too short:  86b_H-FE-15.pkl
# too short:  86b_H-RV-11.pkl
# too short:  86b_H-RV-17.pkl
# too short:  86b_H-RV-18.pkl
# too short:  86b_H-RV-23.pkl
# too short:  86b_H-RV-3.pkl
# too short:  86b_H-SortOverall-22.pkl
# too short:  87a_V-FE-9.pkl
# too short:  87a_V-RV-18.pkl
# too short:  87b_H-FE-8.pkl
# too short:  87b_H-SortOverall-22.pkl
# too short:  89a_V-CDV-23.pkl
# too short:  89a_V-FE-5.pkl
# too short:  89a_V-FE-8.pkl
# too short:  89a_V-RV-17.pkl
# too short:  89a_V-SortTwoFactors-16.pkl
# too short:  89b_H-FE-5.pkl
# too short:  89b_H-RV-22.pkl
# too short:  89b_H-SortOverall-9.pkl
# too short:  89b_H-SortTwoFactors-16.pkl
# too short:  8a_V-FE-11.pkl
# too short:  8a_V-RV-2.pkl
# too short:  8a_V-RV-24.pkl
# too short:  8b_H-CDV-6.pkl
# too short:  8b_H-RV-10.pkl
# too short:  8b_H-SortOverall-20.pkl
# too short:  8b_H-SortTwoFactors-14.pkl
# too short:  90a_H-RV-8.pkl
# too short:  90a_H-SortTwoFactors-9.pkl
# too short:  90b_V-CDV-17.pkl
# too short:  90b_V-CDV-22.pkl
# too short:  90b_V-FE-12.pkl
# too short:  90b_V-FE-23.pkl
# too short:  90b_V-RV-15.pkl
# too short:  90b_V-SortOverall-11.pkl
# too short:  90b_V-SortOverall-21.pkl
# too short:  91a_V-RV-16.pkl
# too short:  91a_V-RV-18.pkl
# too short:  91a_V-SortOverall-5.pkl
# too short:  91b_H-FE-21.pkl
# too short:  91b_H-RV-11.pkl
# too short:  91b_H-SortOverall-17.pkl
# too short:  91b_H-SortOverall-3.pkl
# too short:  92a_H-CDV-4.pkl
# too short:  92a_H-SortOverall-22.pkl
# too short:  92a_H-SortOverall-3.pkl
# too short:  92b_V-RV-18.pkl
# too short:  92b_V-SortTwoFactors-17.pkl
# too short:  93a_V-SortOverall-3.pkl
# too short:  93b_H-SortOverall-15.pkl
# too short:  94a_H-FE-17.pkl
# too short:  94a_H-FE-23.pkl
# too short:  94a_H-FE-9.pkl
# too short:  94a_H-RV-11.pkl
# too short:  94a_H-RV-14.pkl
# too short:  94a_H-RV-18.pkl
# too short:  94a_H-RV-24.pkl
# too short:  94a_H-RV-4.pkl
# too short:  94a_H-SortOverall-20.pkl
# too short:  94a_H-SortTwoFactors-10.pkl
# too short:  94b_V-CDV-15.pkl
# too short:  94b_V-CDV-21.pkl
# too short:  94b_V-CDV-6.pkl
# too short:  94b_V-CDV-8.pkl
# too short:  94b_V-FE-14.pkl
# too short:  94b_V-FE-5.pkl
# too short:  94b_V-FE-9.pkl
# too short:  94b_V-RV-10.pkl
# too short:  94b_V-RV-18.pkl
# too short:  94b_V-RV-24.pkl
# too short:  94b_V-SortOverall-23.pkl
# too short:  94b_V-SortTwoFactors-4.pkl
# too short:  95a_H-CDV-16.pkl
# too short:  95a_H-FE-8.pkl
# too short:  95a_H-RV-11.pkl
# too short:  96a_V-SortOverall-21.pkl
# too short:  96a_V-SortTwoFactors-12.pkl
# too short:  96a_V-SortTwoFactors-14.pkl
# too short:  96b_H-FE-20.pkl
# too short:  96b_H-FE-9.pkl
# too short:  96b_H-RV-6.pkl
# too short:  97a_H-CDV-12.pkl
# too short:  97a_H-FE-9.pkl
# too short:  97a_H-SortOverall-10.pkl
# too short:  97a_H-SortOverall-6.pkl
# too short:  97a_H-SortTwoFactors-24.pkl
# too short:  97b_V-FE-9.pkl
# too short:  97b_V-RV-15.pkl
# too short:  97b_V-RV-23.pkl
# too short:  98a_V-CDV-17.pkl
# too short:  98a_V-CDV-20.pkl
# too short:  98a_V-FE-21.pkl
# too short:  98a_V-RV-2.pkl
# too short:  98b_H-CDV-14.pkl
# too short:  98b_H-FE-9.pkl
# too short:  98b_H-SortOverall-3.pkl
# too short:  99a_H-CDV-11.pkl
# too short:  99a_H-CDV-16.pkl
# too short:  99a_H-FE-24.pkl
# too short:  99b_V-CDV-20.pkl
# too short:  9a_H-FE-24.pkl
# too short:  9a_H-RV-22.pkl
# too short:  9b_V-CDV-10.pkl
# too short:  9b_V-RV-6.pkl
# too short:  9b_V-SortOverall-14.pkl
# too short:  9b_V-SortOverall-2.pkl
# too short:  9b_V-SortOverall-20.pkl
#
# Confused
#
# too short:  105b_V-RV-11.pkl
# too short:  132a_V-RV-18.pkl
# too short:  39b_V-SortTwoFactors-11.pkl
# too short:  39b_V-SortTwoFactors-21.pkl
# 5425
# 813
#
# excluding 808 not confused points
# excluding 4 confused points
# excluding 1 pump or OE points
# not_confused points remaining:  4448
# confused points remaining:  106
# pump or OE points remaining:  58

# %%
def percent_invalid_rows(df):
    """ checks the % of invalid rows in a data item
    
    """
    # return # invalid and total rows (int,int)
    total_rows = df.shape[0]
    if total_rows == 0:
        print("empty pkl")
        input()
    # we define a row as invalid if all of the features named below contain invalid values
    num_invalid = df[(df['ValidityLeft'] == 4.0) & (df['ValidityRight'] == 4.0)].shape[0]
    return (num_invalid/total_rows)

# %%
def fix_missing_eye(df):
    """ items passed in must have only one of ValidityLeft or ValidityRight = 4.0
    
    """
    df = df.values
    i_left = (df[:,6] == 4.0) & (df[:,13] == 0.0)#get indicies of rows with ValidityLeft = 4.0 (invalid)
    i_right = (df[:,6] == 0.0) & (df[:,13] == 4.0)#get indicies of rows with ValidityRight = 4.0 (invalid)

    df[i_left,0:7] = df[i_left,7:14]
    df[i_right,7:14] = df[i_right,0:7]

    df = pd.DataFrame(df)

    return df

def fix_invalid_rows(df):
    """ Replace values corresponding to an invalid eye with -1 everywhere
    
    """
    df = df.values
    i_left = (df[:,6] == 4.0) #get indicies of rows with ValidityLeft = 4.0 (invalid)
    i_right = (df[:,13] == 4.0)#get indicies of rows with ValidityRight = 4.0 (invalid)

    df[i_left,0:7] = -1.0
    df[i_right,7:14] = -1.0

    df = pd.DataFrame(df)

    return df

# %%
# 3. 
total = 0
invalid_pump = 0
invalid_not_confused = 0
invalid_confused = 0

print("\nPump Confused\n")

for i in range(len(pump_confused_item_names)):
    f = open('../dataset/unaugmented/confused_PUMP_OpenEnded/'+ pump_confused_item_names[i], 'rb')
    item = pickle.load(f)
    if pump_confused_item_names[i] not in pump_names_exclude:
        percent_inval = percent_invalid_rows(item)
        if percent_inval > 0.35:
                print(pump_confused_item_names[i])
                print(percent_inval)
                pump_names_exclude.append(pump_confused_item_names[i])
                invalid_pump+=1
    total+=1
    f.close()

print("\nNot Confused\n")

for i in range(len(not_confused_item_names)):
    f = open('../dataset/unaugmented/not_confused/'+ not_confused_item_names[i], 'rb')
    item = pickle.load(f)
    
    if not_confused_item_names[i] not in not_confused_names_exclude:
        percent_inval = percent_invalid_rows(item)
        if percent_inval > 0.35:
            print(not_confused_item_names[i])
            print(percent_inval)
            not_confused_names_exclude.append(not_confused_item_names[i])
            invalid_not_confused+=1
    total+=1
    f.close()
      
print("\nConfused\n")

for i in range(len(confused_item_names)):
    f = open('../dataset/unaugmented/confused/'+ confused_item_names[i], 'rb')
    item = pickle.load(f)
    
    if confused_item_names[i] not in confused_names_exclude:
        percent_inval = percent_invalid_rows(item)
        if percent_inval > 0.35:
            print(confused_item_names[i])
            print(percent_inval)
            confused_names_exclude.append(confused_item_names[i])
            invalid_confused+=1
    total+=1
    f.close()

print()
print("%f points processed"% total)
print("Number of invalid not_confused: ", invalid_not_confused)
print("Number of invalid confused: ", invalid_confused)
print("Number of pump confused: ", invalid_pump)

print()

print("total number of not_confused to exclued so far: ", len(not_confused_names_exclude))
print("total number of confused to exclued so far: ", len(confused_names_exclude))
print("total number of pump or OE to exclued so far: ", len(pump_names_exclude))
# Out:
# Pump Confused
#
# 110b_H-PUMP-7.pkl
# 0.8394241417497231
# 127b_V-PUMP-13.pkl
# 0.6618625277161863
# 132a_V-Open_Ended.pkl
# 0.5139455782312925
# 134a_V-Open_Ended.pkl
# 0.39718035974720467
# 141a_H-Open_Ended.pkl
# 0.5514893617021277
# 142a_V-Open_Ended.pkl
# 0.6933848382423949
# 143a_H-PUMP-1.pkl
# 0.9528563505268997
# 152a_V-PUMP-1.pkl
# 0.9294377067254685
# 152b_H-PUMP-1.pkl
# 0.8515235457063712
# 20a_V_Open_Ended.pkl
# 0.6020186335403727
# 24b_H_Open_Ended.pkl
# 0.8349698535745047
# 30a_V_Open_Ended.pkl
# 0.7062193126022913
# 33b_V-PUMP-7.pkl
# 0.4772727272727273
# 56b_H-PUMP-7.pkl
# 0.545655783065855
# 78a_V-PUMP-7.pkl
# 0.9988907376594565
# 82b_H-PUMP-7.pkl
# 0.6760641238253179
# 99b_V-PUMP-13.pkl
# 0.9162072767364939
# 9a_H_Open_Ended.pkl
# 0.5284360189573459
# 9b_V-PUMP-19.pkl
# 0.9939293598233996
# 9b_V-PUMP-7.pkl
# 0.9944781888459415
#
# Not Confused
#
# 100a_V-SortTwoFactors-14.pkl
# 0.5314861460957179
# 103b_V-SortOverall-23.pkl
# 0.45732022762545266
# 103b_V-SortTwoFactors-24.pkl
# 0.7257597684515196
# 105a_H-SortOverall-24.pkl
# 0.4529463500439754
# 105b_V-RV-18.pkl
# 0.4090909090909091
# 109a_H-CDV-15.pkl
# 0.7614107883817427
# 109a_H-FE-11.pkl
# 0.3716216216216216
# 109b_V-CDV-8.pkl
# 0.5337349397590362
# 109b_V-SortOverall-12.pkl
# 0.496996996996997
# 10b_H-CDV-17.pkl
# 0.8123406425293218
# 110a_V-CDV-17.pkl
# 0.4317673378076063
# 111a_H-CDV-16.pkl
# 0.4195601851851852
# 116a_V-CDV-11.pkl
# 0.7048567870485679
# 116a_V-CDV-23.pkl
# 0.6040494938132733
# 116a_V-FE-2.pkl
# 0.6225165562913907
# 116a_V-FE-20.pkl
# 0.6061224489795919
# 116a_V-RV-10.pkl
# 0.55359765051395
# 116a_V-RV-18.pkl
# 0.669980879541109
# 116a_V-RV-24.pkl
# 0.7126373626373627
# 116a_V-RV-4.pkl
# 0.4869927159209157
# 116a_V-SortOverall-12.pkl
# 0.6475558237779119
# 116a_V-SortOverall-15.pkl
# 0.7067812798471824
# 118a_V-CDV-17.pkl
# 0.357630979498861
# 118a_V-CDV-3.pkl
# 0.40896664844177144
# 118a_V-FE-8.pkl
# 0.37373737373737376
# 118a_V-RV-15.pkl
# 0.3579295154185022
# 118a_V-RV-23.pkl
# 0.4272930648769575
# 118a_V-RV-4.pkl
# 0.36372093023255814
# 118a_V-SortOverall-20.pkl
# 0.5797224582271311
# 118a_V-SortOverall-9.pkl
# 0.5852534562211982
# 118a_V-SortTwoFactors-10.pkl
# 0.35282155566853074
# 118a_V-SortTwoFactors-14.pkl
# 0.48404701931150296
# 122a_V-CDV-5.pkl
# 0.3986983246956731
# 122a_V-FE-12.pkl
# 0.39282103134479274
# 122a_V-RV-11.pkl
# 0.35776311219173323
# 122a_V-SortOverall-24.pkl
# 0.5099403578528827
# 122a_V-SortTwoFactors-10.pkl
# 0.3887106184364061
# 122a_V-SortTwoFactors-17.pkl
# 0.3600352112676056
# 123b_V-CDV-11.pkl
# 0.4991158267020336
# 123b_V-CDV-20.pkl
# 0.38697068403908796
# 123b_V-RV-18.pkl
# 0.46830265848670755
# 123b_V-RV-21.pkl
# 0.5525902668759811
# 123b_V-RV-4.pkl
# 0.4106104651162791
# 123b_V-SortOverall-14.pkl
# 0.3898750821827745
# 123b_V-SortOverall-22.pkl
# 0.8043478260869565
# 123b_V-SortOverall-6.pkl
# 0.3576702214930271
# 123b_V-SortOverall-8.pkl
# 0.5115303983228512
# 124a_H-CDV-16.pkl
# 0.9964601769911504
# 124a_H-CDV-22.pkl
# 0.9690402476780186
# 124a_H-CDV-9.pkl
# 0.9974842767295597
# 124a_H-FE-10.pkl
# 1.0
# 124a_H-FE-15.pkl
# 0.9990074441687344
# 124a_H-FE-20.pkl
# 0.9348739495798319
# 124a_H-FE-4.pkl
# 0.9425981873111783
# 124a_H-RV-24.pkl
# 0.966344432509846
# 124a_H-RV-3.pkl
# 0.7964305633017289
# 124a_H-RV-8.pkl
# 0.9285714285714286
# 124a_H-SortOverall-11.pkl
# 0.9930124223602484
# 124a_H-SortOverall-17.pkl
# 1.0
# 124a_H-SortOverall-23.pkl
# 0.9382861635220126
# 124a_H-SortOverall-6.pkl
# 0.9504293520686963
# 124a_H-SortTwoFactors-12.pkl
# 0.9856230031948882
# 124a_H-SortTwoFactors-14.pkl
# 0.9994327850255247
# 124a_H-SortTwoFactors-21.pkl
# 0.9373368146214099
# 124a_H-SortTwoFactors-5.pkl
# 0.989778534923339
# 124b_V-CDV-14.pkl
# 0.9393326592517695
# 124b_V-CDV-20.pkl
# 0.9982638888888888
# 124b_V-FE-12.pkl
# 0.998017839444995
# 124b_V-FE-21.pkl
# 0.9986910994764397
# 124b_V-RV-17.pkl
# 0.9978991596638656
# 124b_V-RV-24.pkl
# 1.0
# 124b_V-RV-8.pkl
# 0.998992950654582
# 124b_V-SortOverall-10.pkl
# 0.994121969140338
# 124b_V-SortOverall-16.pkl
# 0.9977116704805492
# 124b_V-SortOverall-2.pkl
# 0.9827586206896551
# 124b_V-SortOverall-22.pkl
# 0.9976717112922002
# 124b_V-SortTwoFactors-15.pkl
# 0.999168744804655
# 124b_V-SortTwoFactors-23.pkl
# 0.9973421926910299
# 124b_V-SortTwoFactors-3.pkl
# 0.9920589903573455
# 124b_V-SortTwoFactors-9.pkl
# 0.9540942928039702
# 125a_H-CDV-11.pkl
# 0.4543189368770764
# 125a_H-CDV-16.pkl
# 0.38345864661654133
# 125a_H-CDV-23.pkl
# 0.9306020066889632
# 125a_H-FE-17.pkl
# 0.46225614927905007
# 125a_H-FE-20.pkl
# 0.6311728395061729
# 125a_H-RV-21.pkl
# 0.4689807976366322
# 125a_H-SortOverall-14.pkl
# 0.6014625228519196
# 125a_H-SortOverall-8.pkl
# 0.5088899567515618
# 125a_H-SortTwoFactors-12.pkl
# 0.664303586321935
# 125a_H-SortTwoFactors-15.pkl
# 0.7142339731981167
# 125a_H-SortTwoFactors-22.pkl
# 0.9428487690504103
# 125a_H-SortTwoFactors-6.pkl
# 0.39743132358187655
# 125b_V-FE-12.pkl
# 0.41139896373056994
# 125b_V-FE-5.pkl
# 0.4518229166666667
# 125b_V-SortOverall-14.pkl
# 0.5134228187919463
# 125b_V-SortOverall-22.pkl
# 0.7389597644749755
# 125b_V-SortOverall-9.pkl
# 0.666127728375101
# 125b_V-SortTwoFactors-23.pkl
# 0.4665841584158416
# 125b_V-SortTwoFactors-3.pkl
# 0.4553191489361702
# 126a_V-SortOverall-9.pkl
# 0.40171990171990174
# 126b_H-FE-23.pkl
# 0.4897435897435897
# 127a_H-FE-24.pkl
# 0.3771043771043771
# 127a_H-SortOverall-12.pkl
# 0.5136116152450091
# 127b_V-CDV-14.pkl
# 0.7820343461030383
# 127b_V-CDV-20.pkl
# 0.4962686567164179
# 127b_V-CDV-9.pkl
# 0.6372592924317062
# 127b_V-FE-11.pkl
# 0.7082474226804124
# 127b_V-FE-15.pkl
# 0.40773480662983425
# 127b_V-RV-21.pkl
# 0.4011379800853485
# 127b_V-RV-3.pkl
# 0.6055625790139064
# 127b_V-SortOverall-10.pkl
# 0.5525170913610938
# 127b_V-SortOverall-17.pkl
# 0.4276315789473684
# 127b_V-SortOverall-23.pkl
# 0.4874696847210994
# 127b_V-SortTwoFactors-12.pkl
# 0.46420472951085195
# 127b_V-SortTwoFactors-16.pkl
# 0.3820065944418276
# 127b_V-SortTwoFactors-22.pkl
# 0.42296918767507
# 127b_V-SortTwoFactors-6.pkl
# 0.4495985727029438
# 128a_V-SortTwoFactors-12.pkl
# 0.359404990403071
# 129b_V-CDV-8.pkl
# 0.39858490566037735
# 129b_V-FE-3.pkl
# 0.45938375350140054
# 134a_V-CDV-16.pkl
# 0.9973045822102425
# 134a_V-CDV-23.pkl
# 0.8168642951251647
# 134a_V-CDV-3.pkl
# 0.8546384222059897
# 134a_V-FE-24.pkl
# 0.7073170731707317
# 134a_V-RV-12.pkl
# 0.6863979848866498
# 134a_V-RV-18.pkl
# 0.8530721282279609
# 134a_V-RV-21.pkl
# 0.8349650349650349
# 134a_V-RV-4.pkl
# 0.8556962025316456
# 134a_V-SortOverall-17.pkl
# 0.5604265402843602
# 134a_V-SortOverall-2.pkl
# 0.4232558139534884
# 134a_V-SortOverall-20.pkl
# 0.7620253164556962
# 134a_V-SortOverall-8.pkl
# 0.45278969957081544
# 134a_V-SortTwoFactors-14.pkl
# 0.3875
# 134a_V-SortTwoFactors-22.pkl
# 0.6281848532771042
# 134a_V-SortTwoFactors-6.pkl
# 0.5934203468621491
# 134a_V-SortTwoFactors-9.pkl
# 0.6297136376523959
# 134b_H-CDV-20.pkl
# 0.5387679235262879
# 134b_H-CDV-9.pkl
# 0.3670053795576808
# 134b_H-FE-10.pkl
# 0.5221606648199446
# 134b_H-FE-16.pkl
# 0.6173708920187794
# 134b_H-FE-24.pkl
# 0.5961538461538461
# 134b_H-RV-17.pkl
# 0.3575638506876228
# 134b_H-RV-18.pkl
# 0.6787479406919276
# 134b_H-RV-2.pkl
# 0.701
# 134b_H-RV-23.pkl
# 0.61133069828722
# 134b_H-SortOverall-11.pkl
# 0.5160621761658031
# 134b_H-SortOverall-22.pkl
# 0.7204301075268817
# 134b_H-SortTwoFactors-6.pkl
# 0.4122479462285287
# 134b_H-SortTwoFactors-8.pkl
# 0.5433604336043361
# 137a_H-SortTwoFactors-16.pkl
# 0.5329949238578681
# 137b_V-CDV-12.pkl
# 0.4010840108401084
# 137b_V-CDV-2.pkl
# 0.3768046198267565
# 137b_V-FE-3.pkl
# 0.47348837209302325
# 137b_V-RV-11.pkl
# 0.37809187279151946
# 137b_V-RV-6.pkl
# 0.4269578313253012
# 137b_V-SortOverall-17.pkl
# 0.590186592950933
# 137b_V-SortOverall-23.pkl
# 0.4017355793772333
# 137b_V-SortOverall-5.pkl
# 0.3947061113273647
# 137b_V-SortOverall-9.pkl
# 0.4274952919020716
# 137b_V-SortTwoFactors-4.pkl
# 0.3543046357615894
# 138a_V-SortOverall-4.pkl
# 0.4665898617511521
# 139a_H-FE-12.pkl
# 0.6842767295597484
# 139a_H-FE-15.pkl
# 0.8837735849056604
# 139a_H-FE-20.pkl
# 0.9448529411764706
# 139a_H-RV-11.pkl
# 0.447178002894356
# 139a_H-RV-16.pkl
# 0.5692074326886614
# 139a_H-RV-18.pkl
# 0.9311023622047244
# 139a_H-SortOverall-24.pkl
# 0.9422718808193669
# 139a_H-SortTwoFactors-17.pkl
# 0.7822277847309136
# 139a_H-SortTwoFactors-23.pkl
# 0.7774373259052925
# 139a_H-SortTwoFactors-9.pkl
# 0.4434782608695652
# 141b_V-RV-15.pkl
# 0.3656093489148581
# 141b_V-SortOverall-24.pkl
# 0.8955512572533849
# 142b_H-RV-10.pkl
# 0.35725510738606603
# 142b_H-SortOverall-11.pkl
# 0.6200156372165755
# 142b_H-SortOverall-15.pkl
# 0.4080717488789238
# 142b_H-SortTwoFactors-14.pkl
# 0.4755784061696658
# 143a_H-FE-10.pkl
# 0.39553752535496955
# 143a_H-RV-18.pkl
# 0.49220103986135183
# 143a_H-RV-2.pkl
# 0.7165801828514949
# 143a_H-SortTwoFactors-23.pkl
# 0.6019753086419753
# 143a_H-SortTwoFactors-6.pkl
# 0.43590875643855775
# 143b_V-CDV-23.pkl
# 0.4319526627218935
# 143b_V-SortTwoFactors-22.pkl
# 0.371239081203494
# 148b_H-CDV-16.pkl
# 0.42945544554455445
# 148b_H-FE-12.pkl
# 0.5235849056603774
# 148b_H-FE-17.pkl
# 0.3587174348697395
# 149a_H-CDV-10.pkl
# 0.938337801608579
# 149a_H-CDV-14.pkl
# 0.9852430555555556
# 149a_H-FE-11.pkl
# 0.9961880559085133
# 149a_H-RV-4.pkl
# 0.37905695039804044
# 149a_H-RV-9.pkl
# 0.9610610854222439
# 149a_H-SortOverall-15.pkl
# 0.924547803617571
# 149a_H-SortOverall-21.pkl
# 0.5280898876404494
# 149a_H-SortOverall-8.pkl
# 0.9896907216494846
# 149a_H-SortTwoFactors-12.pkl
# 0.9986996098829649
# 149a_H-SortTwoFactors-16.pkl
# 0.9786938397406206
# 149b_V-RV-21.pkl
# 0.6700924974306269
# 149b_V-SortOverall-8.pkl
# 0.5492341356673961
# 149b_V-SortTwoFactors-10.pkl
# 0.4324186991869919
# 14b_H-CDV-23.pkl
# 0.35323383084577115
# 14b_H-FE-15.pkl
# 0.45870044052863435
# 14b_H-FE-21.pkl
# 0.7215515026971487
# 14b_H-SortOverall-16.pkl
# 0.6566371681415929
# 14b_H-SortOverall-22.pkl
# 0.75
# 152a_V-CDV-17.pkl
# 0.7357212003872217
# 152a_V-CDV-5.pkl
# 0.6514469453376206
# 152a_V-FE-22.pkl
# 0.4912353923205342
# 152a_V-FE-6.pkl
# 0.8026666666666666
# 152a_V-RV-15.pkl
# 0.7008196721311475
# 152a_V-RV-18.pkl
# 0.43626206196038597
# 152a_V-RV-23.pkl
# 0.5329260013577732
# 152a_V-RV-4.pkl
# 0.5642833165491776
# 152a_V-RV-8.pkl
# 0.6655587868716244
# 152a_V-SortOverall-12.pkl
# 0.6525885558583107
# 152a_V-SortOverall-3.pkl
# 0.40625
# 152a_V-SortTwoFactors-10.pkl
# 0.4366838148001583
# 152a_V-SortTwoFactors-14.pkl
# 0.5124910778015703
# 152a_V-SortTwoFactors-2.pkl
# 0.5915288129431012
# 152b_H-CDV-15.pkl
# 0.9835390946502057
# 152b_H-CDV-24.pkl
# 0.5362614913176711
# 152b_H-CDV-6.pkl
# 0.9241590214067278
# 152b_H-CDV-9.pkl
# 0.8160278745644599
# 152b_H-FE-5.pkl
# 0.9804469273743017
# 152b_H-FE-8.pkl
# 0.8791208791208791
# 152b_H-RV-12.pkl
# 0.5699300699300699
# 152b_H-RV-14.pkl
# 0.6052631578947368
# 152b_H-RV-18.pkl
# 0.717816683831102
# 152b_H-RV-20.pkl
# 0.6577986437141367
# 152b_H-RV-3.pkl
# 0.6207627118644068
# 152b_H-SortOverall-11.pkl
# 0.7877947295423023
# 152b_H-SortOverall-2.pkl
# 0.9088909833490418
# 152b_H-SortOverall-22.pkl
# 0.4428121720881427
# 152b_H-SortTwoFactors-10.pkl
# 0.8205933682373473
# 152b_H-SortTwoFactors-4.pkl
# 0.7149425287356321
# 15b_V-CDV-16.pkl
# 0.6865256124721604
# 15b_V-FE-17.pkl
# 0.5652173913043478
# 15b_V-FE-20.pkl
# 0.4306569343065693
# 15b_V-RV-18.pkl
# 0.4333764553686934
# 15b_V-SortTwoFactors-23.pkl
# 0.7684391080617495
# 16a_V-CDV-23.pkl
# 0.5200945626477541
# 16a_V-FE-24.pkl
# 0.5547290116896918
# 16a_V-RV-18.pkl
# 0.6405867970660146
# 16a_V-SortTwoFactors-8.pkl
# 0.5518617021276596
# 17a_H-CDV-16.pkl
# 1.0
# 17a_H-CDV-23.pkl
# 1.0
# 17a_H-CDV-8.pkl
# 0.4607438016528926
# 17a_H-FE-11.pkl
# 1.0
# 17a_H-FE-14.pkl
# 1.0
# 17a_H-FE-24.pkl
# 1.0
# 17a_H-RV-10.pkl
# 1.0
# 17a_H-RV-18.pkl
# 1.0
# 17a_H-RV-21.pkl
# 1.0
# 17a_H-SortOverall-20.pkl
# 1.0
# 17a_H-SortOverall-9.pkl
# 0.9983179142136249
# 17a_H-SortTwoFactors-12.pkl
# 0.9977220956719818
# 17a_H-SortTwoFactors-15.pkl
# 0.9987333755541482
# 17a_H-SortTwoFactors-22.pkl
# 0.9983857949959645
# 17b_V-FE-6.pkl
# 0.36007580543272266
# 17b_V-RV-5.pkl
# 0.41427660930529
# 17b_V-SortTwoFactors-4.pkl
# 0.42327650111193477
# 18a_V-CDV-17.pkl
# 1.0
# 18a_V-CDV-6.pkl
# 0.9314285714285714
# 18a_V-CDV-9.pkl
# 0.9541751527494908
# 18a_V-FE-11.pkl
# 0.6449422946367956
# 18a_V-FE-2.pkl
# 0.8832419617721143
# 18a_V-FE-22.pkl
# 0.5539845758354756
# 18a_V-RV-18.pkl
# 0.9971139971139971
# 18a_V-RV-23.pkl
# 0.7205882352941176
# 18a_V-RV-4.pkl
# 0.8131553860819828
# 18a_V-RV-8.pkl
# 0.9966832504145937
# 18a_V-SortOverall-10.pkl
# 0.9917355371900827
# 18a_V-SortOverall-21.pkl
# 0.993214588634436
# 18a_V-SortOverall-5.pkl
# 0.9669117647058824
# 18a_V-SortTwoFactors-12.pkl
# 0.901453957996769
# 18a_V-SortTwoFactors-15.pkl
# 0.40267433987813134
# 18a_V-SortTwoFactors-3.pkl
# 0.705991404735822
# 18b_H-FE-3.pkl
# 0.5288562434417629
# 18b_H-FE-8.pkl
# 0.5536332179930796
# 18b_H-RV-10.pkl
# 0.5468164794007491
# 18b_H-RV-22.pkl
# 0.5609065155807366
# 18b_H-SortOverall-14.pkl
# 0.99375
# 18b_H-SortOverall-5.pkl
# 0.5468607825295724
# 18b_H-SortTwoFactors-6.pkl
# 0.434052757793765
# 19a_H-CDV-23.pkl
# 0.9993876301285977
# 19a_H-CDV-5.pkl
# 0.3602510460251046
# 19a_H-FE-16.pkl
# 0.8986254295532646
# 19a_H-FE-20.pkl
# 0.5027624309392266
# 19a_H-SortTwoFactors-12.pkl
# 0.35272219637040486
# 19a_H-SortTwoFactors-22.pkl
# 0.8615344872126066
# 19b_V-CDV-16.pkl
# 0.4407643312101911
# 19b_V-CDV-21.pkl
# 0.4147836078130984
# 19b_V-CDV-9.pkl
# 0.5672333848531684
# 19b_V-FE-20.pkl
# 0.9617834394904459
# 19b_V-RV-18.pkl
# 0.40313504823151125
# 19b_V-SortOverall-15.pkl
# 0.41154791154791154
# 19b_V-SortOverall-22.pkl
# 0.49653579676674364
# 1a_H-SortOverall-12.pkl
# 0.7533875338753387
# 1b_V-FE-9.pkl
# 1.0
# 1b_V-RV-12.pkl
# 0.42319277108433734
# 1b_V-SortOverall-11.pkl
# 0.992776886035313
# 1b_V-SortTwoFactors-10.pkl
# 0.8114558472553699
# 20b_H-CDV-12.pkl
# 0.8756260434056762
# 20b_H-CDV-15.pkl
# 0.9065180102915952
# 20b_H-CDV-6.pkl
# 0.9865771812080537
# 20b_H-FE-10.pkl
# 0.8924157984007753
# 20b_H-FE-21.pkl
# 0.8169191919191919
# 20b_H-FE-3.pkl
# 0.9235955056179775
# 20b_H-RV-11.pkl
# 0.9442231075697212
# 20b_H-RV-17.pkl
# 0.9403095062638173
# 20b_H-RV-18.pkl
# 0.9397590361445783
# 20b_H-RV-2.pkl
# 0.9034869240348692
# 20b_H-RV-23.pkl
# 0.9397677793904209
# 20b_H-SortOverall-20.pkl
# 0.8611764705882353
# 20b_H-SortOverall-5.pkl
# 0.9269005847953217
# 20b_H-SortOverall-9.pkl
# 0.7391304347826086
# 20b_H-SortTwoFactors-14.pkl
# 0.8982161594963274
# 20b_H-SortTwoFactors-22.pkl
# 0.6862170087976539
# 20b_H-SortTwoFactors-4.pkl
# 0.7874396135265701
# 20b_H-SortTwoFactors-8.pkl
# 0.8557541549074945
# 21b_V-RV-14.pkl
# 0.5804347826086956
# 22a_V-CDV-14.pkl
# 0.3809015421115065
# 22a_V-CDV-6.pkl
# 0.6191123188405797
# 22a_V-FE-5.pkl
# 0.535442652874962
# 22a_V-RV-11.pkl
# 0.47715404699738906
# 22a_V-RV-16.pkl
# 0.5496732026143791
# 22a_V-SortOverall-23.pkl
# 0.4
# 22b_H-CDV-9.pkl
# 0.36273817925194074
# 24a_V-CDV-12.pkl
# 0.9206927985414768
# 24a_V-CDV-3.pkl
# 0.6416803953871499
# 24a_V-FE-4.pkl
# 0.44213444213444214
# 24a_V-RV-2.pkl
# 0.5094339622641509
# 24a_V-RV-21.pkl
# 0.8489974937343359
# 24a_V-RV-9.pkl
# 0.9879663056558363
# 24a_V-SortOverall-11.pkl
# 0.4147005444646098
# 24a_V-SortOverall-17.pkl
# 0.40561622464898595
# 24a_V-SortOverall-23.pkl
# 0.6596669080376538
# 24a_V-SortOverall-5.pkl
# 0.8278529980657641
# 24a_V-SortTwoFactors-6.pkl
# 0.5054203313561055
# 24b_H-CDV-10.pkl
# 0.936031984007996
# 24b_H-CDV-15.pkl
# 0.9939540507859734
# 24b_H-FE-24.pkl
# 0.5321100917431193
# 24b_H-FE-9.pkl
# 0.8676470588235294
# 24b_H-RV-11.pkl
# 0.9749739311783108
# 24b_H-RV-17.pkl
# 0.9652014652014652
# 24b_H-RV-18.pkl
# 0.995850622406639
# 24b_H-RV-2.pkl
# 0.9814471243042672
# 24b_H-SortOverall-12.pkl
# 0.9611829944547134
# 24b_H-SortOverall-16.pkl
# 0.7386363636363636
# 24b_H-SortOverall-21.pkl
# 0.9132231404958677
# 24b_H-SortOverall-5.pkl
# 0.9844236760124611
# 24b_H-SortTwoFactors-14.pkl
# 0.9715189873417721
# 24b_H-SortTwoFactors-22.pkl
# 0.9906716417910447
# 24b_H-SortTwoFactors-6.pkl
# 0.947586809347019
# 24b_H-SortTwoFactors-8.pkl
# 0.850967007963595
# 25a_H-SortTwoFactors-23.pkl
# 0.41364003228410007
# 27b_V-CDV-23.pkl
# 0.520686175580222
# 27b_V-CDV-6.pkl
# 0.68
# 27b_V-FE-24.pkl
# 0.5378590078328982
# 27b_V-FE-3.pkl
# 0.7453083109919572
# 27b_V-FE-9.pkl
# 0.7742363877822045
# 27b_V-RV-11.pkl
# 0.5433884297520661
# 27b_V-RV-15.pkl
# 0.6742313323572474
# 27b_V-RV-18.pkl
# 0.7025183630640084
# 27b_V-RV-4.pkl
# 0.7522734399498275
# 27b_V-SortOverall-21.pkl
# 0.705019305019305
# 27b_V-SortOverall-5.pkl
# 0.7902350813743219
# 27b_V-SortOverall-8.pkl
# 0.727363184079602
# 27b_V-SortTwoFactors-17.pkl
# 0.7012118679481822
# 27b_V-SortTwoFactors-22.pkl
# 0.6587800369685767
# 29a_H-FE-14.pkl
# 0.4132841328413284
# 29a_H-RV-15.pkl
# 0.3924588422729687
# 30a_V-CDV-14.pkl
# 0.6323218066337333
# 30a_V-CDV-3.pkl
# 0.9843505477308294
# 30a_V-CDV-8.pkl
# 0.6310096153846154
# 30a_V-FE-2.pkl
# 0.6578947368421053
# 30a_V-FE-23.pkl
# 0.44106745737583397
# 30a_V-RV-4.pkl
# 0.9786096256684492
# 30a_V-SortOverall-5.pkl
# 0.5558458523840627
# 30a_V-SortTwoFactors-12.pkl
# 0.7380530973451327
# 30a_V-SortTwoFactors-15.pkl
# 0.762472885032538
# 30a_V-SortTwoFactors-6.pkl
# 0.6050531914893617
# 30b_H-CDV-14.pkl
# 0.6117424242424242
# 30b_H-CDV-21.pkl
# 0.8712230215827338
# 30b_H-FE-4.pkl
# 0.457089552238806
# 31a_H-CDV-3.pkl
# 0.4204488778054863
# 31a_H-FE-17.pkl
# 0.5637513171759747
# 31a_H-FE-21.pkl
# 0.6020321761219306
# 31a_H-FE-8.pkl
# 0.38425593098490296
# 31a_H-RV-16.pkl
# 0.5008156606851549
# 31a_H-RV-18.pkl
# 0.41923076923076924
# 31a_H-SortOverall-10.pkl
# 0.45773874862788144
# 31a_H-SortOverall-20.pkl
# 0.5634408602150538
# 31a_H-SortOverall-4.pkl
# 0.3624661246612466
# 31a_H-SortTwoFactors-15.pkl
# 0.6054545454545455
# 31a_H-SortTwoFactors-2.pkl
# 0.44171532111938794
# 33a_H-CDV-12.pkl
# 0.8795411089866156
# 33a_H-CDV-14.pkl
# 0.9048765803732691
# 33a_H-CDV-23.pkl
# 0.9010327022375215
# 33a_H-FE-20.pkl
# 0.7583892617449665
# 33a_H-FE-3.pkl
# 0.8848080133555927
# 33a_H-RV-16.pkl
# 0.7
# 33a_H-RV-18.pkl
# 0.7
# 33a_H-RV-22.pkl
# 0.8379562043795621
# 33a_H-RV-4.pkl
# 1.0
# 33a_H-SortOverall-24.pkl
# 0.4634146341463415
# 33a_H-SortOverall-9.pkl
# 0.9840182648401826
# 33a_H-SortTwoFactors-15.pkl
# 0.9036839769196626
# 33a_H-SortTwoFactors-21.pkl
# 0.846218487394958
# 33a_H-SortTwoFactors-5.pkl
# 0.9231559482227245
# 33a_H-SortTwoFactors-8.pkl
# 0.9016759776536313
# 33b_V-CDV-12.pkl
# 0.6306306306306306
# 33b_V-CDV-23.pkl
# 0.9814814814814815
# 33b_V-FE-8.pkl
# 0.795003203074952
# 33b_V-RV-18.pkl
# 0.9696509863429439
# 33b_V-RV-22.pkl
# 0.9965811965811966
# 33b_V-SortOverall-21.pkl
# 0.9467532467532468
# 33b_V-SortOverall-6.pkl
# 0.9790055248618784
# 33b_V-SortTwoFactors-11.pkl
# 0.5509031198686372
# 33b_V-SortTwoFactors-16.pkl
# 0.6460348162475822
# 33b_V-SortTwoFactors-20.pkl
# 0.9417221693625119
# 33b_V-SortTwoFactors-5.pkl
# 0.9776240846216436
# 34a_V-CDV-12.pkl
# 0.5498154981549815
# 34a_V-CDV-16.pkl
# 0.8271092669432918
# 34a_V-FE-11.pkl
# 0.8581424936386769
# 34a_V-FE-17.pkl
# 0.5206073752711496
# 34a_V-FE-23.pkl
# 0.530278232405892
# 34a_V-FE-3.pkl
# 0.7531391260673028
# 34a_V-RV-18.pkl
# 0.6819407008086253
# 34a_V-RV-20.pkl
# 0.7485768500948766
# 34a_V-RV-6.pkl
# 0.9604298974108452
# 34a_V-SortOverall-22.pkl
# 0.6176470588235294
# 34a_V-SortOverall-5.pkl
# 0.8849009900990099
# 34a_V-SortOverall-8.pkl
# 0.9925293489861259
# 34a_V-SortTwoFactors-10.pkl
# 0.6449438202247191
# 34a_V-SortTwoFactors-15.pkl
# 0.7751724137931034
# 34a_V-SortTwoFactors-21.pkl
# 0.7979644867908186
# 34a_V-SortTwoFactors-4.pkl
# 0.9370995923121724
# 34b_H-CDV-12.pkl
# 0.4925864909390445
# 34b_H-RV-9.pkl
# 0.5990888382687927
# 34b_H-SortOverall-10.pkl
# 0.6308316430020284
# 34b_H-SortOverall-20.pkl
# 0.41627906976744183
# 34b_H-SortTwoFactors-8.pkl
# 0.61667347772783
# 36b_H-CDV-20.pkl
# 0.4257907542579075
# 37b_V-CDV-17.pkl
# 0.3943746259724716
# 37b_V-RV-18.pkl
# 0.4705003734129948
# 38a_V-CDV-10.pkl
# 1.0
# 38a_V-CDV-3.pkl
# 0.8021417644059153
# 38a_V-FE-12.pkl
# 0.35496957403651114
# 38a_V-RV-11.pkl
# 0.660873440285205
# 38a_V-RV-4.pkl
# 0.9776301992310381
# 38a_V-SortOverall-6.pkl
# 1.0
# 38a_V-SortOverall-9.pkl
# 0.9427662957074722
# 38a_V-SortTwoFactors-5.pkl
# 0.8421219319081552
# 38a_V-SortTwoFactors-8.pkl
# 0.8770718232044199
# 38b_H-CDV-22.pkl
# 0.5444646098003629
# 38b_H-FE-20.pkl
# 0.42276422764227645
# 38b_H-RV-11.pkl
# 0.37919826652221017
# 38b_H-RV-18.pkl
# 0.585427135678392
# 38b_H-SortOverall-24.pkl
# 0.45951859956236324
# 38b_H-SortTwoFactors-21.pkl
# 0.5277044854881267
# 3b_V-CDV-20.pkl
# 0.3741573033707865
# 3b_V-FE-14.pkl
# 0.623688155922039
# 3b_V-FE-24.pkl
# 0.8802045288531775
# 3b_V-RV-22.pkl
# 0.3675675675675676
# 3b_V-SortOverall-16.pkl
# 0.5530035335689046
# 3b_V-SortOverall-21.pkl
# 0.5454545454545454
# 40a_V-CDV-2.pkl
# 0.7265070921985816
# 40a_V-FE-4.pkl
# 0.984144960362401
# 40a_V-RV-21.pkl
# 0.4820627802690583
# 40a_V-RV-3.pkl
# 0.9982547993019197
# 40a_V-SortOverall-6.pkl
# 0.7578692493946732
# 40a_V-SortOverall-8.pkl
# 0.4854202401372213
# 40a_V-SortTwoFactors-5.pkl
# 0.5974695983294436
# 40b_H-FE-14.pkl
# 1.0
# 40b_H-FE-24.pkl
# 1.0
# 40b_H-RV-15.pkl
# 1.0
# 40b_H-SortOverall-16.pkl
# 0.9990393852065321
# 40b_H-SortTwoFactors-11.pkl
# 0.39733453806189295
# 40b_H-SortTwoFactors-3.pkl
# 0.47418850215095815
# 41a_H-CDV-17.pkl
# 0.5674799522265825
# 41a_H-CDV-23.pkl
# 0.6112305212251478
# 41a_H-FE-11.pkl
# 0.38511749347258484
# 41a_H-FE-14.pkl
# 0.6110080395794681
# 41a_H-FE-20.pkl
# 0.4641434262948207
# 41a_H-RV-10.pkl
# 0.6336241078509119
# 41a_H-RV-24.pkl
# 0.424190800681431
# 41a_H-RV-4.pkl
# 0.35545023696682465
# 41a_H-SortOverall-15.pkl
# 0.3987034035656402
# 41a_H-SortOverall-2.pkl
# 0.36766275346851657
# 41a_H-SortOverall-22.pkl
# 0.5200553250345782
# 41a_H-SortOverall-8.pkl
# 0.3995568685376662
# 41a_H-SortTwoFactors-16.pkl
# 0.3654929577464789
# 41a_H-SortTwoFactors-3.pkl
# 0.3734384009225447
# 41b_V-CDV-12.pkl
# 0.6118363794604004
# 41b_V-CDV-22.pkl
# 0.42778793418647165
# 41b_V-FE-11.pkl
# 0.4296675191815857
# 41b_V-FE-15.pkl
# 0.5722411831626849
# 41b_V-FE-3.pkl
# 0.4933404368673415
# 41b_V-RV-10.pkl
# 0.39285714285714285
# 41b_V-RV-18.pkl
# 0.447741935483871
# 41b_V-RV-24.pkl
# 0.738626964433416
# 41b_V-SortOverall-14.pkl
# 0.52447216890595
# 41b_V-SortOverall-21.pkl
# 0.6285714285714286
# 41b_V-SortOverall-4.pkl
# 0.41236559139784945
# 41b_V-SortOverall-9.pkl
# 0.5447482908638906
# 41b_V-SortTwoFactors-2.pkl
# 0.40978921043229727
# 41b_V-SortTwoFactors-20.pkl
# 0.4385171790235081
# 42a_V-CDV-16.pkl
# 1.0
# 42a_V-CDV-23.pkl
# 1.0
# 42a_V-CDV-8.pkl
# 1.0
# 42a_V-FE-15.pkl
# 0.9989669421487604
# 42a_V-FE-24.pkl
# 1.0
# 42a_V-FE-3.pkl
# 1.0
# 42a_V-FE-9.pkl
# 0.9993648777389648
# 42a_V-RV-12.pkl
# 0.9986082115518441
# 42a_V-RV-17.pkl
# 1.0
# 42a_V-RV-18.pkl
# 0.9991582491582491
# 42a_V-RV-22.pkl
# 1.0
# 42a_V-SortOverall-2.pkl
# 0.9962581852198317
# 42a_V-SortOverall-20.pkl
# 0.9940374787052811
# 42a_V-SortTwoFactors-10.pkl
# 0.9974416373520947
# 42a_V-SortTwoFactors-14.pkl
# 0.9973984679867033
# 42a_V-SortTwoFactors-21.pkl
# 0.9992732558139535
# 42a_V-SortTwoFactors-5.pkl
# 0.9995708154506437
# 42b_H-CDV-11.pkl
# 1.0
# 42b_H-CDV-16.pkl
# 0.9992755373098285
# 42b_H-CDV-2.pkl
# 1.0
# 42b_H-CDV-24.pkl
# 1.0
# 42b_H-FE-12.pkl
# 1.0
# 42b_H-FE-15.pkl
# 1.0
# 42b_H-FE-21.pkl
# 0.9730215827338129
# 42b_H-FE-6.pkl
# 0.9967061923583662
# 42b_H-RV-18.pkl
# 0.9974093264248705
# 42b_H-RV-22.pkl
# 1.0
# 42b_H-SortOverall-10.pkl
# 0.992816091954023
# 42b_H-SortOverall-14.pkl
# 0.9968553459119497
# 42b_H-SortOverall-20.pkl
# 0.989804587935429
# 42b_H-SortOverall-5.pkl
# 0.9852830188679246
# 42b_H-SortTwoFactors-17.pkl
# 0.9966239027683997
# 42b_H-SortTwoFactors-23.pkl
# 0.9922958397534669
# 42b_H-SortTwoFactors-3.pkl
# 1.0
# 43a_H-CDV-2.pkl
# 0.7659574468085106
# 43a_H-CDV-23.pkl
# 0.9965337954939342
# 43a_H-CDV-9.pkl
# 0.9452554744525548
# 43a_H-FE-10.pkl
# 0.8985801217038539
# 43a_H-FE-22.pkl
# 1.0
# 43a_H-FE-3.pkl
# 0.9037433155080213
# 43a_H-RV-11.pkl
# 0.9396771452846219
# 43a_H-RV-18.pkl
# 1.0
# 43a_H-RV-24.pkl
# 1.0
# 43a_H-RV-5.pkl
# 0.9973509933774835
# 43a_H-SortOverall-14.pkl
# 0.995
# 43a_H-SortOverall-21.pkl
# 0.9885057471264368
# 43a_H-SortOverall-6.pkl
# 1.0
# 43a_H-SortOverall-8.pkl
# 0.970357454228422
# 43a_H-SortTwoFactors-12.pkl
# 0.8729054694909896
# 43a_H-SortTwoFactors-15.pkl
# 0.888402625820569
# 43a_H-SortTwoFactors-20.pkl
# 0.9974619289340102
# 43a_H-SortTwoFactors-4.pkl
# 0.9335189697180647
# 43b_V-CDV-12.pkl
# 0.9812286689419796
# 43b_V-CDV-15.pkl
# 1.0
# 43b_V-CDV-24.pkl
# 0.942318358291736
# 43b_V-FE-6.pkl
# 0.7875
# 43b_V-FE-9.pkl
# 0.9617224880382775
# 43b_V-RV-23.pkl
# 0.9335022165927802
# 43b_V-RV-4.pkl
# 0.6409119696010133
# 43b_V-SortOverall-11.pkl
# 0.9454545454545454
# 43b_V-SortOverall-17.pkl
# 0.9871428571428571
# 43b_V-SortTwoFactors-10.pkl
# 0.9784543325526932
# 43b_V-SortTwoFactors-14.pkl
# 0.9876796714579056
# 43b_V-SortTwoFactors-21.pkl
# 0.9427414690572585
# 43b_V-SortTwoFactors-5.pkl
# 0.9704880817253121
# 44a_V-CDV-10.pkl
# 0.9399141630901288
# 44a_V-CDV-14.pkl
# 0.9989010989010989
# 44a_V-CDV-24.pkl
# 0.9976825028968713
# 44a_V-CDV-4.pkl
# 0.9989506820566632
# 44a_V-FE-11.pkl
# 0.9986120749479528
# 44a_V-FE-17.pkl
# 0.9973544973544973
# 44a_V-FE-22.pkl
# 0.9938875305623472
# 44a_V-FE-5.pkl
# 0.9460974557999138
# 44a_V-RV-20.pkl
# 0.9971590909090909
# 44a_V-RV-3.pkl
# 0.928087986463621
# 44a_V-RV-8.pkl
# 1.0
# 44a_V-SortOverall-12.pkl
# 0.9875424688561721
# 44a_V-SortOverall-16.pkl
# 0.8862980235398623
# 44a_V-SortOverall-2.pkl
# 0.9130434782608695
# 44a_V-SortOverall-23.pkl
# 0.970074812967581
# 44a_V-SortTwoFactors-21.pkl
# 0.9945215485756026
# 44a_V-SortTwoFactors-6.pkl
# 0.965917379484119
# 44a_V-SortTwoFactors-9.pkl
# 0.8647946761889304
# 44b_H-CDV-21.pkl
# 0.9578059071729957
# 44b_H-CDV-5.pkl
# 0.998179335457442
# 44b_H-CDV-9.pkl
# 0.9930503847108464
# 44b_H-FE-14.pkl
# 1.0
# 44b_H-FE-22.pkl
# 1.0
# 44b_H-FE-3.pkl
# 0.9645015105740181
# 44b_H-FE-8.pkl
# 1.0
# 44b_H-RV-11.pkl
# 0.8801666132649791
# 44b_H-RV-16.pkl
# 0.4931129476584022
# 44b_H-RV-23.pkl
# 0.8097345132743363
# 44b_H-RV-4.pkl
# 0.8960138648180243
# 44b_H-SortOverall-12.pkl
# 0.9561231172233137
# 44b_H-SortOverall-17.pkl
# 0.6089743589743589
# 44b_H-SortOverall-20.pkl
# 0.9107282693813625
# 44b_H-SortTwoFactors-10.pkl
# 0.9831865492393915
# 45b_V-CDV-10.pkl
# 0.44273127753303965
# 45b_V-FE-20.pkl
# 0.46348517715112075
# 45b_V-SortOverall-8.pkl
# 0.3742362525458248
# 46a_V-CDV-24.pkl
# 0.4338664158043274
# 46a_V-FE-9.pkl
# 0.40085287846481876
# 46a_V-RV-18.pkl
# 0.48330182734719596
# 46a_V-SortOverall-17.pkl
# 0.5187165775401069
# 46b_H-FE-6.pkl
# 0.42936802973977695
# 48b_H-CDV-11.pkl
# 0.8588996763754045
# 48b_H-CDV-15.pkl
# 0.9693945442448436
# 48b_H-CDV-22.pkl
# 0.9877750611246944
# 48b_H-CDV-4.pkl
# 0.9779005524861878
# 48b_H-FE-12.pkl
# 0.946925566343042
# 48b_H-FE-23.pkl
# 0.951559934318555
# 48b_H-RV-14.pkl
# 0.9965095986038395
# 48b_H-RV-18.pkl
# 0.7395833333333334
# 48b_H-RV-21.pkl
# 0.996551724137931
# 48b_H-RV-8.pkl
# 0.663259511641113
# 48b_H-SortOverall-10.pkl
# 0.8270676691729323
# 48b_H-SortTwoFactors-16.pkl
# 0.9589603283173734
# 48b_H-SortTwoFactors-6.pkl
# 0.9430051813471503
# 48b_H-SortTwoFactors-9.pkl
# 0.9548780487804878
# 49a_H-CDV-14.pkl
# 0.7273550724637681
# 49a_H-CDV-22.pkl
# 0.42687385740402195
# 49a_H-CDV-4.pkl
# 0.6693140794223826
# 49a_H-CDV-9.pkl
# 0.7053406998158379
# 49a_H-FE-10.pkl
# 0.9830866807610994
# 49a_H-FE-15.pkl
# 0.725
# 49a_H-FE-3.pkl
# 0.9324499030381384
# 49a_H-RV-6.pkl
# 0.5473015873015873
# 49a_H-RV-8.pkl
# 0.5717877797334674
# 49a_H-SortOverall-12.pkl
# 0.5597426470588235
# 49a_H-SortOverall-17.pkl
# 0.4155251141552511
# 49a_H-SortOverall-20.pkl
# 0.5863431151241535
# 49a_H-SortOverall-5.pkl
# 0.7097288676236044
# 49a_H-SortTwoFactors-11.pkl
# 0.6895556837853434
# 49a_H-SortTwoFactors-16.pkl
# 0.9098270150901729
# 49a_H-SortTwoFactors-2.pkl
# 0.7631394533987386
# 49a_H-SortTwoFactors-21.pkl
# 0.3711882229232387
# 49b_V-CDV-10.pkl
# 1.0
# 49b_V-CDV-17.pkl
# 0.8704980842911877
# 49b_V-CDV-21.pkl
# 0.8984025559105431
# 49b_V-FE-16.pkl
# 0.9504761904761905
# 49b_V-FE-20.pkl
# 0.8503067484662576
# 49b_V-FE-5.pkl
# 0.8821705426356589
# 49b_V-FE-9.pkl
# 1.0
# 49b_V-RV-12.pkl
# 0.823873121869783
# 49b_V-RV-15.pkl
# 0.8443804034582133
# 49b_V-RV-18.pkl
# 0.9865771812080537
# 49b_V-RV-23.pkl
# 0.7316666666666667
# 49b_V-SortOverall-11.pkl
# 0.6682933262991295
# 49b_V-SortOverall-14.pkl
# 0.9812446717817562
# 49b_V-SortOverall-2.pkl
# 0.9023311897106109
# 49b_V-SortTwoFactors-22.pkl
# 0.827485380116959
# 49b_V-SortTwoFactors-6.pkl
# 0.9136069114470843
# 49b_V-SortTwoFactors-8.pkl
# 0.9031117397454032
# 50a_V-FE-5.pkl
# 0.897680763983629
# 52a_V-CDV-12.pkl
# 0.9980353634577603
# 52a_V-CDV-14.pkl
# 0.9984962406015038
# 52a_V-CDV-21.pkl
# 0.9986091794158554
# 52a_V-CDV-4.pkl
# 0.7748829039812647
# 52a_V-FE-17.pkl
# 0.9465174129353234
# 52a_V-FE-5.pkl
# 0.9352172241445598
# 52a_V-FE-9.pkl
# 0.997179125528914
# 52a_V-RV-18.pkl
# 0.9972924187725631
# 52a_V-RV-2.pkl
# 0.6556825823806322
# 52a_V-RV-24.pkl
# 0.8982456140350877
# 52a_V-RV-8.pkl
# 0.9978237214363439
# 52a_V-SortOverall-10.pkl
# 0.9931766489764974
# 52a_V-SortOverall-16.pkl
# 0.9930124223602484
# 52a_V-SortOverall-20.pkl
# 0.9933184855233853
# 52a_V-SortOverall-6.pkl
# 0.9923566878980892
# 52a_V-SortTwoFactors-23.pkl
# 0.9979278905926233
# 52a_V-SortTwoFactors-3.pkl
# 0.7720345440690881
# 52b_H-CDV-21.pkl
# 0.42005420054200543
# 52b_H-FE-10.pkl
# 0.8343296327924851
# 52b_H-RV-24.pkl
# 0.5748930099857347
# 52b_H-SortOverall-23.pkl
# 0.4583333333333333
# 56b_H-CDV-9.pkl
# 0.7198952879581152
# 56b_H-RV-11.pkl
# 0.6789087093389297
# 56b_H-RV-18.pkl
# 0.48822269807280516
# 56b_H-RV-24.pkl
# 0.5335766423357664
# 56b_H-SortOverall-14.pkl
# 0.425531914893617
# 56b_H-SortOverall-2.pkl
# 0.55625
# 56b_H-SortOverall-8.pkl
# 0.774798927613941
# 56b_H-SortTwoFactors-12.pkl
# 0.5993650793650793
# 56b_H-SortTwoFactors-15.pkl
# 0.46421663442940037
# 56b_H-SortTwoFactors-4.pkl
# 0.6895193065405831
# 58a_V-CDV-2.pkl
# 0.7052696078431373
# 58a_V-FE-17.pkl
# 0.5765397810815226
# 58a_V-SortOverall-3.pkl
# 0.722794959908362
# 58b_H-CDV-4.pkl
# 0.38558986539984164
# 58b_H-FE-2.pkl
# 0.8094879518072289
# 58b_H-RV-3.pkl
# 0.8657718120805369
# 59a_H-CDV-11.pkl
# 0.9811060814800237
# 59a_H-CDV-15.pkl
# 1.0
# 59a_H-CDV-23.pkl
# 0.9996991576413959
# 59a_H-CDV-4.pkl
# 1.0
# 59a_H-FE-12.pkl
# 0.9977160258850399
# 59a_H-FE-16.pkl
# 1.0
# 59a_H-FE-21.pkl
# 0.9977349943374858
# 59a_H-FE-6.pkl
# 1.0
# 59a_H-RV-10.pkl
# 1.0
# 59a_H-RV-17.pkl
# 1.0
# 59a_H-RV-18.pkl
# 1.0
# 59a_H-RV-2.pkl
# 0.8192419825072886
# 59a_H-RV-20.pkl
# 1.0
# 59a_H-SortOverall-24.pkl
# 0.9955237242614146
# 59a_H-SortOverall-5.pkl
# 1.0
# 59a_H-SortOverall-9.pkl
# 0.9943820224719101
# 59a_H-SortTwoFactors-14.pkl
# 0.9961910342806914
# 59a_H-SortTwoFactors-22.pkl
# 1.0
# 59a_H-SortTwoFactors-3.pkl
# 0.9987484355444305
# 59a_H-SortTwoFactors-8.pkl
# 0.9963149078726968
# 59b_V-CDV-17.pkl
# 0.995741056218058
# 59b_V-CDV-20.pkl
# 1.0
# 59b_V-CDV-4.pkl
# 1.0
# 59b_V-FE-11.pkl
# 1.0
# 59b_V-FE-14.pkl
# 1.0
# 59b_V-FE-21.pkl
# 0.9980363279332352
# 59b_V-FE-6.pkl
# 0.9989708404802744
# 59b_V-RV-18.pkl
# 0.5652173913043478
# 59b_V-RV-22.pkl
# 1.0
# 59b_V-SortOverall-10.pkl
# 0.9941520467836257
# 59b_V-SortOverall-15.pkl
# 0.9964285714285714
# 59b_V-SortOverall-23.pkl
# 0.9908675799086758
# 59b_V-SortOverall-5.pkl
# 0.9960906958561376
# 59b_V-SortTwoFactors-16.pkl
# 0.9975155279503105
# 59b_V-SortTwoFactors-2.pkl
# 0.9980026631158455
# 59b_V-SortTwoFactors-24.pkl
# 0.9978287841191067
# 59b_V-SortTwoFactors-8.pkl
# 0.9980857580398163
# 60a_V-CDV-20.pkl
# 0.994
# 60a_V-CDV-5.pkl
# 0.9967845659163987
# 60a_V-CDV-9.pkl
# 0.5584415584415584
# 60a_V-FE-12.pkl
# 0.9964221824686941
# 60a_V-FE-14.pkl
# 0.9193154034229829
# 60a_V-FE-3.pkl
# 0.9976415094339622
# 60a_V-RV-11.pkl
# 0.9478380233356212
# 60a_V-RV-16.pkl
# 0.9972640218878249
# 60a_V-RV-2.pkl
# 1.0
# 60a_V-RV-24.pkl
# 0.9967373572593801
# 60a_V-SortOverall-17.pkl
# 1.0
# 60a_V-SortOverall-23.pkl
# 0.9904912836767037
# 60a_V-SortOverall-4.pkl
# 0.9953426480372588
# 60a_V-SortTwoFactors-15.pkl
# 0.9968847352024922
# 60a_V-SortTwoFactors-21.pkl
# 0.9969711090400746
# 60a_V-SortTwoFactors-6.pkl
# 0.9987908101571947
# 60a_V-SortTwoFactors-8.pkl
# 0.9976732161323681
# 60b_H-CDV-15.pkl
# 0.9978197674418605
# 60b_H-CDV-20.pkl
# 0.9988016776512882
# 60b_H-CDV-9.pkl
# 0.9984591679506933
# 60b_H-FE-12.pkl
# 1.0
# 60b_H-FE-17.pkl
# 0.9977272727272727
# 60b_H-FE-23.pkl
# 0.9976190476190476
# 60b_H-FE-3.pkl
# 0.9970104633781763
# 60b_H-RV-11.pkl
# 1.0
# 60b_H-RV-16.pkl
# 0.9952229299363057
# 60b_H-RV-22.pkl
# 1.0
# 60b_H-RV-4.pkl
# 1.0
# 60b_H-SortOverall-24.pkl
# 0.9895150720838795
# 60b_H-SortOverall-6.pkl
# 0.9937254901960785
# 60b_H-SortOverall-8.pkl
# 0.9959422903516681
# 60b_H-SortTwoFactors-10.pkl
# 0.8555776892430279
# 60b_H-SortTwoFactors-14.pkl
# 0.9760456273764259
# 60b_H-SortTwoFactors-21.pkl
# 0.9944237918215614
# 60b_H-SortTwoFactors-5.pkl
# 0.995995995995996
# 61a_V-CDV-17.pkl
# 0.9983060417843026
# 61a_V-FE-24.pkl
# 1.0
# 61a_V-FE-8.pkl
# 0.8747390396659708
# 61a_V-RV-10.pkl
# 0.9978828510938603
# 61a_V-RV-14.pkl
# 0.9979859013091642
# 61a_V-RV-18.pkl
# 0.7607260726072608
# 61a_V-SortOverall-11.pkl
# 0.9954519613416714
# 61a_V-SortOverall-20.pkl
# 0.8625
# 61a_V-SortTwoFactors-12.pkl
# 1.0
# 61a_V-SortTwoFactors-16.pkl
# 0.9980645161290322
# 61a_V-SortTwoFactors-23.pkl
# 0.9984051036682615
# 61b_H-CDV-17.pkl
# 1.0
# 61b_H-CDV-8.pkl
# 0.9986197377501725
# 61b_H-FE-12.pkl
# 0.9991869918699187
# 61b_H-FE-16.pkl
# 0.9984484096198604
# 61b_H-FE-20.pkl
# 1.0
# 61b_H-RV-10.pkl
# 1.0
# 61b_H-RV-15.pkl
# 1.0
# 61b_H-RV-18.pkl
# 0.9448909299655568
# 61b_H-RV-21.pkl
# 0.5679012345679012
# 61b_H-RV-5.pkl
# 0.998272884283247
# 61b_H-SortOverall-14.pkl
# 0.9934735315445975
# 61b_H-SortOverall-3.pkl
# 1.0
# 61b_H-SortTwoFactors-11.pkl
# 0.9987363100252739
# 61b_H-SortTwoFactors-2.pkl
# 0.6233108108108109
# 62a_H-CDV-24.pkl
# 0.3819500402900886
# 62a_H-CDV-3.pkl
# 0.998501872659176
# 62a_H-CDV-9.pkl
# 1.0
# 62a_H-FE-12.pkl
# 0.9972862957937585
# 62a_H-FE-14.pkl
# 1.0
# 62a_H-FE-22.pkl
# 0.948780487804878
# 62a_H-FE-5.pkl
# 0.9988623435722411
# 62a_H-RV-18.pkl
# 0.9964093357271095
# 62a_H-RV-20.pkl
# 0.9967532467532467
# 62a_H-RV-4.pkl
# 0.9984177215189873
# 62a_H-RV-8.pkl
# 0.9969512195121951
# 62a_H-SortOverall-11.pkl
# 0.991130820399113
# 62a_H-SortOverall-21.pkl
# 0.9905660377358491
# 62a_H-SortTwoFactors-10.pkl
# 0.9951159951159951
# 62a_H-SortTwoFactors-15.pkl
# 0.9908424908424909
# 62a_H-SortTwoFactors-2.pkl
# 0.99795605518651
# 62a_H-SortTwoFactors-23.pkl
# 0.772635814889336
# 63a_H-FE-12.pkl
# 0.41935483870967744
# 63a_H-FE-23.pkl
# 0.3851508120649652
# 63a_H-RV-14.pkl
# 0.4309978768577495
# 63a_H-RV-21.pkl
# 0.484472049689441
# 63a_H-SortOverall-16.pkl
# 0.5017921146953405
# 63a_H-SortTwoFactors-22.pkl
# 0.3917371826779492
# 66a_V-CDV-10.pkl
# 0.9983783783783784
# 66a_V-CDV-16.pkl
# 0.4098025867937372
# 66a_V-CDV-3.pkl
# 0.9623942337825133
# 66a_V-FE-14.pkl
# 0.9498452012383901
# 66a_V-FE-2.pkl
# 0.8978738236319275
# 66a_V-FE-21.pkl
# 0.7833827893175074
# 66a_V-RV-17.pkl
# 0.9690934065934066
# 66a_V-RV-18.pkl
# 0.9751724137931035
# 66a_V-RV-5.pkl
# 0.9968164131588256
# 66a_V-RV-9.pkl
# 0.998681608437706
# 66a_V-SortOverall-11.pkl
# 0.994261119081779
# 66a_V-SortOverall-15.pkl
# 0.8306772908366534
# 66a_V-SortOverall-23.pkl
# 0.9840546697038725
# 66a_V-SortOverall-4.pkl
# 0.9483648881239243
# 66a_V-SortTwoFactors-12.pkl
# 0.9967432293452176
# 66a_V-SortTwoFactors-24.pkl
# 0.9397096309431453
# 66a_V-SortTwoFactors-6.pkl
# 0.835752298016449
# 66b_H-CDV-14.pkl
# 0.8177656987555428
# 66b_H-CDV-20.pkl
# 0.6406966086159487
# 66b_H-FE-11.pkl
# 0.37261698440207974
# 66b_H-FE-23.pkl
# 0.6179577464788732
# 66b_H-RV-4.pkl
# 0.49749463135289906
# 66b_H-SortOverall-17.pkl
# 0.5213622291021672
# 66b_H-SortOverall-2.pkl
# 0.9268727705112961
# 66b_H-SortTwoFactors-12.pkl
# 0.998211731044349
# 66b_H-SortTwoFactors-16.pkl
# 0.4389555398729711
# 66b_H-SortTwoFactors-5.pkl
# 0.6685633001422475
# 69a_H-CDV-11.pkl
# 0.7463768115942029
# 69a_H-CDV-17.pkl
# 0.9959919839679359
# 69a_H-CDV-2.pkl
# 0.8915318744053282
# 69a_H-CDV-24.pkl
# 0.6443259710586443
# 69a_H-FE-14.pkl
# 0.8495575221238938
# 69a_H-FE-22.pkl
# 0.5446756425948592
# 69a_H-FE-6.pkl
# 0.8814016172506739
# 69a_H-FE-9.pkl
# 0.9959514170040485
# 69a_H-RV-10.pkl
# 0.9927073837739289
# 69a_H-RV-15.pkl
# 0.9289529914529915
# 69a_H-RV-18.pkl
# 0.6690997566909975
# 69a_H-RV-3.pkl
# 0.9989468141126909
# 69a_H-SortOverall-12.pkl
# 0.5065543071161048
# 69a_H-SortOverall-21.pkl
# 0.759656652360515
# 69a_H-SortOverall-4.pkl
# 0.9960212201591512
# 69a_H-SortTwoFactors-16.pkl
# 0.8361344537815126
# 69a_H-SortTwoFactors-20.pkl
# 0.912147365709133
# 69a_H-SortTwoFactors-5.pkl
# 0.9989151071331706
# 69a_H-SortTwoFactors-8.pkl
# 0.998468606431853
# 69b_V-CDV-10.pkl
# 0.6536248561565017
# 69b_V-CDV-15.pkl
# 0.7081545064377682
# 69b_V-CDV-2.pkl
# 0.5232466509062254
# 69b_V-FE-3.pkl
# 0.9984520123839009
# 69b_V-FE-8.pkl
# 0.8239925891616489
# 69b_V-RV-11.pkl
# 0.92018779342723
# 69b_V-RV-18.pkl
# 0.6254777070063694
# 69b_V-SortOverall-23.pkl
# 0.9661290322580646
# 69b_V-SortOverall-9.pkl
# 0.6807610993657506
# 69b_V-SortTwoFactors-12.pkl
# 0.8309208500153988
# 69b_V-SortTwoFactors-17.pkl
# 0.6296949836148222
# 69b_V-SortTwoFactors-22.pkl
# 0.8958579881656805
# 69b_V-SortTwoFactors-5.pkl
# 0.997805814591333
# 6a_V-CDV-22.pkl
# 0.7272727272727273
# 6a_V-FE-11.pkl
# 0.4621394230769231
# 6a_V-FE-16.pkl
# 0.6714527027027027
# 6a_V-FE-2.pkl
# 0.5029554003224073
# 6a_V-FE-24.pkl
# 0.6779661016949152
# 6a_V-RV-17.pkl
# 0.5885714285714285
# 6a_V-RV-23.pkl
# 0.8387978142076503
# 6a_V-RV-6.pkl
# 0.9121683440073193
# 6a_V-SortOverall-20.pkl
# 0.35246564268391267
# 6a_V-SortOverall-5.pkl
# 0.5598991172761665
# 6a_V-SortTwoFactors-12.pkl
# 0.6167966957319871
# 6a_V-SortTwoFactors-14.pkl
# 0.5013020833333334
# 6a_V-SortTwoFactors-21.pkl
# 0.685885372112917
# 6a_V-SortTwoFactors-3.pkl
# 0.399249530956848
# 6b_H-CDV-14.pkl
# 0.46143057503506313
# 6b_H-CDV-4.pkl
# 0.38100686498855835
# 6b_H-RV-17.pkl
# 0.720626631853786
# 6b_H-SortOverall-16.pkl
# 0.4089506172839506
# 70b_H-CDV-15.pkl
# 0.4315117104329312
# 70b_H-FE-16.pkl
# 0.5979096218874884
# 70b_H-FE-24.pkl
# 0.797071129707113
# 70b_H-RV-18.pkl
# 1.0
# 71a_H-CDV-10.pkl
# 0.41893830703012913
# 71a_H-CDV-5.pkl
# 0.4458940905602456
# 71a_H-FE-9.pkl
# 0.5733122362869199
# 71a_H-RV-18.pkl
# 0.7162162162162162
# 71a_H-RV-21.pkl
# 0.45031905195989064
# 71a_H-SortOverall-14.pkl
# 0.7863636363636364
# 71a_H-SortOverall-24.pkl
# 0.40014847809948034
# 71a_H-SortTwoFactors-12.pkl
# 0.6343622333182024
# 71a_H-SortTwoFactors-15.pkl
# 0.5044742729306487
# 71a_H-SortTwoFactors-2.pkl
# 0.6273512963904423
# 71a_H-SortTwoFactors-22.pkl
# 0.5128571428571429
# 71b_V-CDV-17.pkl
# 0.44986690328305234
# 71b_V-CDV-4.pkl
# 0.485177151120752
# 71b_V-CDV-9.pkl
# 0.5863228699551569
# 71b_V-RV-18.pkl
# 0.5436241610738255
# 71b_V-SortOverall-10.pkl
# 0.38677589233469867
# 73a_H-CDV-8.pkl
# 0.6615969581749049
# 73a_H-FE-24.pkl
# 0.6324614352783366
# 73a_H-FE-6.pkl
# 0.7710184552289815
# 73a_H-FE-9.pkl
# 0.6251567070622649
# 73a_H-RV-12.pkl
# 0.6633333333333333
# 73a_H-RV-18.pkl
# 0.5348837209302325
# 73a_H-RV-2.pkl
# 0.5769757880310644
# 73a_H-RV-23.pkl
# 0.8042328042328042
# 73a_H-SortOverall-11.pkl
# 0.6172979084228377
# 73a_H-SortOverall-5.pkl
# 0.656776263031275
# 73a_H-SortTwoFactors-10.pkl
# 0.7019360648356596
# 73a_H-SortTwoFactors-21.pkl
# 0.5733590733590733
# 73a_H-SortTwoFactors-4.pkl
# 0.7545393409549428
# 73b_V-CDV-15.pkl
# 0.4880636604774536
# 73b_V-CDV-20.pkl
# 0.5839612486544672
# 73b_V-CDV-5.pkl
# 0.649390243902439
# 73b_V-CDV-8.pkl
# 0.5002544529262086
# 73b_V-FE-12.pkl
# 0.5132450331125827
# 73b_V-FE-17.pkl
# 0.46471418489767113
# 73b_V-FE-23.pkl
# 0.970714900947459
# 73b_V-FE-6.pkl
# 0.5531686358754028
# 73b_V-RV-18.pkl
# 0.5062344139650873
# 73b_V-RV-2.pkl
# 0.43249427917620137
# 73b_V-RV-22.pkl
# 0.9673590504451038
# 73b_V-SortOverall-16.pkl
# 0.5984095427435387
# 73b_V-SortOverall-3.pkl
# 0.592090395480226
# 73b_V-SortOverall-9.pkl
# 0.7017114914425427
# 73b_V-SortTwoFactors-14.pkl
# 0.4616419919246299
# 73b_V-SortTwoFactors-24.pkl
# 0.4657534246575342
# 73b_V-SortTwoFactors-4.pkl
# 0.8370323398858592
# 74b_H-CDV-11.pkl
# 0.5268225584594223
# 74b_H-FE-4.pkl
# 0.7514018691588785
# 74b_H-RV-16.pkl
# 0.5282167042889391
# 74b_H-SortOverall-17.pkl
# 0.3831242873432155
# 74b_H-SortOverall-22.pkl
# 0.3783783783783784
# 74b_H-SortOverall-8.pkl
# 0.614569536423841
# 74b_H-SortTwoFactors-10.pkl
# 0.7284545016851228
# 74b_H-SortTwoFactors-15.pkl
# 0.45719277810133957
# 74b_H-SortTwoFactors-3.pkl
# 0.42796092796092794
# 75a_H-SortTwoFactors-9.pkl
# 0.8090154211150652
# 76a_V-CDV-10.pkl
# 0.8383838383838383
# 76a_V-CDV-17.pkl
# 0.7383773928896992
# 76a_V-CDV-24.pkl
# 0.8891191709844559
# 76a_V-CDV-3.pkl
# 0.6033519553072626
# 76a_V-FE-16.pkl
# 0.7917808219178082
# 76a_V-FE-2.pkl
# 0.6369092273068268
# 76a_V-FE-22.pkl
# 0.5876944837340877
# 76a_V-FE-8.pkl
# 0.8292237442922374
# 76a_V-RV-11.pkl
# 0.8014705882352942
# 76a_V-RV-18.pkl
# 0.5857142857142857
# 76a_V-RV-5.pkl
# 0.4956855225311601
# 76a_V-SortOverall-4.pkl
# 0.6049046321525886
# 76a_V-SortOverall-9.pkl
# 0.8334556126192223
# 76a_V-SortTwoFactors-12.pkl
# 0.9218345268931891
# 76a_V-SortTwoFactors-15.pkl
# 0.5893670886075949
# 76a_V-SortTwoFactors-23.pkl
# 0.6598583877995643
# 76a_V-SortTwoFactors-6.pkl
# 0.690188091529891
# 76b_H-CDV-12.pkl
# 0.3621987951807229
# 76b_H-FE-16.pkl
# 0.7393939393939394
# 76b_H-FE-20.pkl
# 0.4681724845995893
# 76b_H-FE-8.pkl
# 0.444683908045977
# 76b_H-RV-14.pkl
# 0.5804597701149425
# 76b_H-RV-18.pkl
# 0.38414634146341464
# 76b_H-RV-23.pkl
# 0.4918347742555235
# 76b_H-RV-5.pkl
# 0.40646425073457393
# 76b_H-RV-9.pkl
# 0.46059782608695654
# 76b_H-SortOverall-10.pkl
# 0.6613351877607788
# 76b_H-SortOverall-21.pkl
# 0.8074162679425837
# 76b_H-SortTwoFactors-11.pkl
# 0.8782643631980716
# 76b_H-SortTwoFactors-17.pkl
# 0.56
# 76b_H-SortTwoFactors-2.pkl
# 0.526671675432006
# 76b_H-SortTwoFactors-24.pkl
# 0.3698630136986301
# 78a_V-CDV-11.pkl
# 1.0
# 78a_V-CDV-15.pkl
# 0.9993373094764745
# 78a_V-CDV-22.pkl
# 1.0
# 78a_V-CDV-4.pkl
# 0.9993011879804332
# 78a_V-FE-10.pkl
# 1.0
# 78a_V-FE-17.pkl
# 0.9973045822102425
# 78a_V-FE-24.pkl
# 0.9992548435171386
# 78a_V-FE-3.pkl
# 0.9992506556762832
# 78a_V-RV-16.pkl
# 1.0
# 78a_V-RV-18.pkl
# 1.0
# 78a_V-RV-2.pkl
# 0.9970384995064165
# 78a_V-RV-23.pkl
# 1.0
# 78a_V-RV-8.pkl
# 0.999199038846616
# 78a_V-SortOverall-12.pkl
# 0.9969356486210419
# 78a_V-SortOverall-14.pkl
# 0.9980997624703087
# 78a_V-SortOverall-5.pkl
# 0.9956521739130435
# 78a_V-SortTwoFactors-20.pkl
# 0.9995511669658886
# 78a_V-SortTwoFactors-9.pkl
# 0.9989498556051457
# 78b_H-CDV-11.pkl
# 1.0
# 78b_H-CDV-17.pkl
# 0.9561855670103093
# 78b_H-CDV-23.pkl
# 0.7556363636363637
# 78b_H-CDV-6.pkl
# 0.9993906154783668
# 78b_H-FE-15.pkl
# 1.0
# 78b_H-FE-2.pkl
# 0.9991228070175439
# 78b_H-FE-24.pkl
# 0.8171717171717172
# 78b_H-FE-8.pkl
# 1.0
# 78b_H-RV-12.pkl
# 1.0
# 78b_H-RV-18.pkl
# 0.9732868757259001
# 78b_H-RV-3.pkl
# 1.0
# 78b_H-SortOverall-10.pkl
# 1.0
# 78b_H-SortOverall-16.pkl
# 0.9879089615931721
# 78b_H-SortOverall-20.pkl
# 0.9903023388476897
# 78b_H-SortOverall-4.pkl
# 0.9877970456005138
# 78b_H-SortTwoFactors-14.pkl
# 0.962570986060919
# 78b_H-SortTwoFactors-21.pkl
# 0.9457142857142857
# 78b_H-SortTwoFactors-5.pkl
# 0.9903469079939669
# 78b_H-SortTwoFactors-9.pkl
# 0.9907192575406032
# 79a_H-FE-2.pkl
# 0.9712092130518234
# 79a_H-SortOverall-11.pkl
# 0.44932781799379523
# 79a_H-SortOverall-21.pkl
# 0.4833164812942366
# 79a_H-SortTwoFactors-17.pkl
# 0.4728778467908903
# 79a_H-SortTwoFactors-22.pkl
# 0.5178424601216906
# 79a_H-SortTwoFactors-3.pkl
# 0.9982608695652174
# 79b_V-CDV-4.pkl
# 0.9933333333333333
# 79b_V-FE-10.pkl
# 0.7798165137614679
# 79b_V-RV-17.pkl
# 0.4255561893896178
# 79b_V-RV-18.pkl
# 0.5142118863049095
# 79b_V-SortOverall-20.pkl
# 0.4666666666666667
# 79b_V-SortOverall-3.pkl
# 0.9782051282051282
# 79b_V-SortTwoFactors-15.pkl
# 0.3695558430357913
# 79b_V-SortTwoFactors-2.pkl
# 0.9858351367302775
# 79b_V-SortTwoFactors-8.pkl
# 0.39930151338766007
# 80a_V-RV-22.pkl
# 0.5853658536585366
# 81a_H-CDV-15.pkl
# 0.5371318822023048
# 81a_H-CDV-21.pkl
# 1.0
# 81a_H-CDV-5.pkl
# 0.6916583912611718
# 81a_H-FE-22.pkl
# 0.5440729483282675
# 81a_H-FE-3.pkl
# 0.5160905840286055
# 81a_H-RV-14.pkl
# 0.3757894736842105
# 81a_H-RV-2.pkl
# 0.7761692650334076
# 81a_H-RV-23.pkl
# 0.8064992614475628
# 81a_H-SortTwoFactors-4.pkl
# 0.5264735264735265
# 81b_V-CDV-14.pkl
# 0.9707943925233645
# 81b_V-CDV-21.pkl
# 0.8388791593695272
# 81b_V-CDV-5.pkl
# 0.9983122362869198
# 81b_V-FE-20.pkl
# 0.9972247918593895
# 81b_V-FE-6.pkl
# 1.0
# 81b_V-RV-10.pkl
# 0.7006869479882237
# 81b_V-RV-16.pkl
# 0.9744408945686901
# 81b_V-RV-24.pkl
# 0.8479087452471483
# 81b_V-RV-3.pkl
# 0.9826429980276135
# 81b_V-SortOverall-12.pkl
# 0.9965493443754313
# 81b_V-SortOverall-15.pkl
# 0.914
# 81b_V-SortOverall-2.pkl
# 0.8310840226382238
# 81b_V-SortOverall-23.pkl
# 0.842516447368421
# 81b_V-SortTwoFactors-4.pkl
# 0.998730964467005
# 81b_V-SortTwoFactors-9.pkl
# 0.9893026126311458
# 82a_V-CDV-16.pkl
# 0.38503253796095444
# 82a_V-CDV-21.pkl
# 0.498936170212766
# 82a_V-FE-22.pkl
# 0.3787969029184038
# 82a_V-FE-5.pkl
# 0.4517439082656474
# 82a_V-RV-10.pkl
# 0.3703099510603589
# 82a_V-RV-18.pkl
# 0.39903846153846156
# 82a_V-SortOverall-11.pkl
# 0.5209235209235209
# 82a_V-SortOverall-20.pkl
# 0.35751295336787564
# 82a_V-SortTwoFactors-14.pkl
# 0.3825136612021858
# 82a_V-SortTwoFactors-24.pkl
# 0.4767886400873839
# 82a_V-SortTwoFactors-8.pkl
# 0.39326169038629105
# 82b_H-CDV-16.pkl
# 0.7473275024295433
# 82b_H-CDV-8.pkl
# 0.7047511312217195
# 82b_H-RV-18.pkl
# 0.45080763582966227
# 82b_H-RV-9.pkl
# 0.3711340206185567
# 82b_H-SortOverall-12.pkl
# 0.5755813953488372
# 82b_H-SortOverall-5.pkl
# 0.45919208573784004
# 82b_H-SortTwoFactors-11.pkl
# 0.7241770715096482
# 82b_H-SortTwoFactors-14.pkl
# 0.6785459729151817
# 82b_H-SortTwoFactors-24.pkl
# 0.44449950445986125
# 82b_H-SortTwoFactors-6.pkl
# 0.6068059299191375
# 83a_H-FE-5.pkl
# 0.36214442013129106
# 83a_H-SortOverall-12.pkl
# 0.38833181403828626
# 83a_H-SortTwoFactors-2.pkl
# 0.42647335718320467
# 84a_V-CDV-22.pkl
# 0.44802578565672846
# 84a_V-FE-12.pkl
# 0.38751625487646296
# 84a_V-FE-21.pkl
# 0.3842696629213483
# 84a_V-RV-23.pkl
# 0.49747474747474746
# 84a_V-SortOverall-11.pkl
# 0.36019736842105265
# 84a_V-SortTwoFactors-24.pkl
# 0.37628865979381443
# 85a_H-CDV-15.pkl
# 0.9660228898426323
# 85a_H-CDV-8.pkl
# 0.8822836962919365
# 85a_H-FE-14.pkl
# 0.5092961487383798
# 85a_H-FE-9.pkl
# 0.9903514817367333
# 85a_H-RV-10.pkl
# 0.4307692307692308
# 85a_H-RV-24.pkl
# 0.3508771929824561
# 85a_H-SortTwoFactors-16.pkl
# 0.990530303030303
# 85b_V-CDV-21.pkl
# 0.5729499467518637
# 85b_V-CDV-8.pkl
# 0.45228215767634855
# 85b_V-FE-22.pkl
# 0.9318181818181818
# 85b_V-FE-9.pkl
# 0.9977997799779978
# 85b_V-RV-10.pkl
# 0.9958847736625515
# 85b_V-RV-18.pkl
# 0.9975669099756691
# 85b_V-RV-24.pkl
# 0.9405705229793978
# 85b_V-SortOverall-12.pkl
# 0.5075034106412005
# 85b_V-SortOverall-23.pkl
# 0.9454976303317536
# 85b_V-SortTwoFactors-11.pkl
# 1.0
# 85b_V-SortTwoFactors-16.pkl
# 0.5389523169912693
# 87a_V-RV-14.pkl
# 1.0
# 87a_V-RV-23.pkl
# 0.6446469248291572
# 87a_V-SortTwoFactors-22.pkl
# 1.0
# 87b_H-CDV-17.pkl
# 0.7109283196239718
# 87b_H-CDV-6.pkl
# 0.7387387387387387
# 87b_H-FE-16.pkl
# 0.9979570990806946
# 87b_H-FE-21.pkl
# 0.36318816762530814
# 87b_H-RV-4.pkl
# 1.0
# 87b_H-SortOverall-5.pkl
# 1.0
# 89a_V-CDV-2.pkl
# 0.6340694006309149
# 89a_V-CDV-9.pkl
# 0.8275488069414316
# 89a_V-FE-15.pkl
# 0.6904176904176904
# 89a_V-FE-22.pkl
# 0.7012345679012346
# 89a_V-RV-18.pkl
# 0.7792592592592592
# 89a_V-RV-20.pkl
# 0.4474835886214442
# 89a_V-RV-6.pkl
# 0.8157248157248157
# 89a_V-SortOverall-10.pkl
# 0.7795071335927367
# 89a_V-SortOverall-14.pkl
# 0.8539130434782609
# 89a_V-SortOverall-24.pkl
# 0.3772819472616633
# 89a_V-SortOverall-4.pkl
# 0.6474708171206226
# 89a_V-SortTwoFactors-12.pkl
# 0.4024390243902439
# 89a_V-SortTwoFactors-21.pkl
# 0.6173503698722259
# 89a_V-SortTwoFactors-3.pkl
# 0.6295723853683668
# 89b_H-CDV-14.pkl
# 0.9990942028985508
# 89b_H-CDV-20.pkl
# 1.0
# 89b_H-CDV-3.pkl
# 1.0
# 89b_H-CDV-8.pkl
# 1.0
# 89b_H-FE-12.pkl
# 1.0
# 89b_H-FE-15.pkl
# 0.9978046103183315
# 89b_H-FE-21.pkl
# 1.0
# 89b_H-RV-11.pkl
# 0.9991673605328892
# 89b_H-RV-18.pkl
# 0.9980842911877394
# 89b_H-RV-6.pkl
# 0.9506578947368421
# 89b_H-SortOverall-17.pkl
# 0.9951757408683667
# 89b_H-SortOverall-2.pkl
# 0.9948586118251928
# 89b_H-SortOverall-23.pkl
# 0.9951807228915662
# 89b_H-SortTwoFactors-10.pkl
# 0.985126425384234
# 89b_H-SortTwoFactors-24.pkl
# 0.9982274741506647
# 89b_H-SortTwoFactors-4.pkl
# 1.0
# 90a_H-SortOverall-12.pkl
# 0.4680259499536608
# 90a_H-SortOverall-15.pkl
# 0.482421875
# 90a_H-SortOverall-20.pkl
# 0.46908602150537637
# 90b_V-CDV-10.pkl
# 0.5178571428571429
# 90b_V-CDV-4.pkl
# 0.47461212976022565
# 90b_V-FE-16.pkl
# 0.37094395280235987
# 90b_V-FE-6.pkl
# 0.5205327413984462
# 90b_V-RV-18.pkl
# 0.3618843683083512
# 90b_V-RV-20.pkl
# 0.5141304347826087
# 90b_V-RV-5.pkl
# 0.37216074548631334
# 90b_V-SortOverall-3.pkl
# 0.38895558223289317
# 90b_V-SortTwoFactors-2.pkl
# 0.5744751749416861
# 91a_V-CDV-10.pkl
# 0.9223744292237442
# 91a_V-CDV-17.pkl
# 0.5040192926045016
# 91a_V-CDV-2.pkl
# 0.927007299270073
# 91a_V-CDV-21.pkl
# 0.9212469237079574
# 91a_V-FE-11.pkl
# 0.6358024691358025
# 91a_V-FE-22.pkl
# 0.7981818181818182
# 91a_V-RV-20.pkl
# 0.4668094218415418
# 91a_V-RV-3.pkl
# 0.8457943925233645
# 91a_V-RV-8.pkl
# 0.5139751552795031
# 91a_V-SortOverall-12.pkl
# 0.992619926199262
# 91a_V-SortOverall-15.pkl
# 0.7446183953033269
# 91a_V-SortOverall-23.pkl
# 0.7795566502463054
# 91a_V-SortTwoFactors-14.pkl
# 0.38372093023255816
# 91a_V-SortTwoFactors-24.pkl
# 0.5196433546949011
# 91a_V-SortTwoFactors-6.pkl
# 0.6517974778844344
# 91a_V-SortTwoFactors-9.pkl
# 0.3798319327731092
# 91b_H-RV-16.pkl
# 0.5413533834586466
# 91b_H-RV-18.pkl
# 0.3697916666666667
# 91b_H-RV-2.pkl
# 0.9928100659077291
# 91b_H-SortOverall-20.pkl
# 0.6251018744906276
# 91b_H-SortTwoFactors-15.pkl
# 0.4513742071881607
# 92a_H-FE-10.pkl
# 0.851063829787234
# 92a_H-RV-11.pkl
# 0.95
# 92a_H-SortTwoFactors-12.pkl
# 0.5535390199637024
# 92b_V-CDV-8.pkl
# 0.4856895056374675
# 92b_V-RV-2.pkl
# 0.5178389398572885
# 92b_V-SortOverall-16.pkl
# 0.37322695035460995
# 93a_V-CDV-24.pkl
# 0.5267665952890792
# 93a_V-RV-23.pkl
# 0.7257751937984496
# 94a_H-CDV-16.pkl
# 0.9
# 94a_H-CDV-21.pkl
# 0.4858490566037736
# 94a_H-CDV-5.pkl
# 0.4245548266166823
# 94a_H-FE-3.pkl
# 0.6749435665914221
# 94b_V-FE-20.pkl
# 0.45010615711252655
# 94b_V-SortTwoFactors-11.pkl
# 0.5733995584988962
# 94b_V-SortTwoFactors-17.pkl
# 0.9585185185185185
# 95a_H-CDV-20.pkl
# 0.4489795918367347
# 95a_H-FE-24.pkl
# 0.9021479713603818
# 95a_H-RV-18.pkl
# 0.39775910364145656
# 95a_H-RV-23.pkl
# 1.0
# 95a_H-SortOverall-22.pkl
# 0.9953890489913545
# 95b_V-CDV-24.pkl
# 0.4224364592462752
# 95b_V-CDV-3.pkl
# 0.8133333333333334
# 95b_V-FE-12.pkl
# 0.39176829268292684
# 95b_V-FE-5.pkl
# 0.7573033707865169
# 95b_V-RV-22.pkl
# 0.7530562347188264
# 95b_V-SortOverall-11.pkl
# 0.43491735537190085
# 95b_V-SortOverall-4.pkl
# 0.9977876106194691
# 95b_V-SortTwoFactors-23.pkl
# 0.7028753993610224
# 95b_V-SortTwoFactors-6.pkl
# 0.6847058823529412
# 96a_V-CDV-16.pkl
# 0.43864097363083165
# 96a_V-FE-22.pkl
# 0.5210008936550492
# 96a_V-RV-18.pkl
# 0.6513888888888889
# 97a_H-CDV-22.pkl
# 0.9988372093023256
# 97a_H-FE-15.pkl
# 0.9993686868686869
# 97a_H-FE-20.pkl
# 0.9987476518472135
# 97a_H-RV-14.pkl
# 0.3763856401911929
# 97a_H-RV-18.pkl
# 0.9990138067061144
# 97a_H-RV-21.pkl
# 1.0
# 97a_H-SortOverall-16.pkl
# 0.9972572682391662
# 97a_H-SortOverall-23.pkl
# 0.9947916666666666
# 97a_H-SortTwoFactors-17.pkl
# 1.0
# 97b_V-CDV-12.pkl
# 0.9972067039106145
# 97b_V-CDV-21.pkl
# 0.9987531172069826
# 97b_V-CDV-5.pkl
# 1.0
# 97b_V-FE-16.pkl
# 1.0
# 97b_V-FE-2.pkl
# 0.9991836734693877
# 97b_V-FE-20.pkl
# 0.9978245105148659
# 97b_V-RV-11.pkl
# 1.0
# 97b_V-RV-18.pkl
# 1.0
# 97b_V-RV-3.pkl
# 1.0
# 97b_V-SortOverall-10.pkl
# 0.9928122192273136
# 97b_V-SortOverall-17.pkl
# 0.9932735426008968
# 97b_V-SortOverall-22.pkl
# 0.9908116385911179
# 97b_V-SortOverall-4.pkl
# 0.9946782776971457
# 97b_V-SortTwoFactors-14.pkl
# 0.9981211836542978
# 97b_V-SortTwoFactors-24.pkl
# 0.996116504854369
# 97b_V-SortTwoFactors-6.pkl
# 0.9974236290025764
# 97b_V-SortTwoFactors-8.pkl
# 1.0
# 98a_V-CDV-4.pkl
# 0.9645833333333333
# 98a_V-CDV-8.pkl
# 0.7773109243697479
# 98a_V-FE-12.pkl
# 1.0
# 98a_V-FE-16.pkl
# 0.7908224076281287
# 98a_V-FE-3.pkl
# 0.8829008649367931
# 98a_V-RV-10.pkl
# 0.8478123018389346
# 98a_V-RV-18.pkl
# 0.8893280632411067
# 98a_V-RV-23.pkl
# 0.7788104089219331
# 98a_V-SortOverall-11.pkl
# 0.9153225806451613
# 98a_V-SortOverall-15.pkl
# 0.706
# 98a_V-SortOverall-24.pkl
# 0.9300833867864016
# 98a_V-SortOverall-6.pkl
# 0.907358390682901
# 98a_V-SortTwoFactors-14.pkl
# 0.7580893682588598
# 98a_V-SortTwoFactors-22.pkl
# 0.9096159399364713
# 98a_V-SortTwoFactors-5.pkl
# 0.939458413926499
# 98a_V-SortTwoFactors-9.pkl
# 0.8468271334792122
# 98b_H-CDV-12.pkl
# 0.5742574257425742
# 98b_H-CDV-23.pkl
# 0.9487750556792873
# 98b_H-CDV-4.pkl
# 0.5846329402814758
# 98b_H-FE-17.pkl
# 0.8231827111984283
# 98b_H-FE-21.pkl
# 0.8693586698337292
# 98b_H-FE-5.pkl
# 0.8033826638477801
# 98b_H-RV-18.pkl
# 0.6581818181818182
# 98b_H-RV-20.pkl
# 0.7329749103942652
# 98b_H-RV-6.pkl
# 0.6386986301369864
# 98b_H-RV-8.pkl
# 0.6915776986951364
# 98b_H-SortOverall-11.pkl
# 0.8477157360406091
# 98b_H-SortOverall-15.pkl
# 0.9478487614080835
# 98b_H-SortOverall-22.pkl
# 0.8937282229965157
# 98b_H-SortTwoFactors-10.pkl
# 0.834941050375134
# 98b_H-SortTwoFactors-16.pkl
# 0.7328767123287672
# 98b_H-SortTwoFactors-2.pkl
# 0.7600974930362117
# 98b_H-SortTwoFactors-24.pkl
# 0.753004005340454
# 99a_H-CDV-22.pkl
# 0.9980092899800929
# 99a_H-FE-12.pkl
# 0.9979919678714859
# 99a_H-FE-5.pkl
# 0.9187425860023725
# 99a_H-RV-10.pkl
# 0.9966777408637874
# 99a_H-RV-14.pkl
# 1.0
# 99a_H-RV-18.pkl
# 0.9951573849878934
# 99a_H-RV-21.pkl
# 0.9961685823754789
# 99a_H-SortOverall-15.pkl
# 0.9933665008291874
# 99a_H-SortOverall-23.pkl
# 0.9931237721021611
# 99a_H-SortOverall-6.pkl
# 0.9961013645224172
# 99a_H-SortOverall-9.pkl
# 0.9953846153846154
# 99a_H-SortTwoFactors-17.pkl
# 0.994478527607362
# 99a_H-SortTwoFactors-20.pkl
# 0.9973684210526316
# 99a_H-SortTwoFactors-8.pkl
# 0.9964881474978051
# 99b_V-CDV-12.pkl
# 0.9908136482939632
# 99b_V-CDV-16.pkl
# 0.995702005730659
# 99b_V-CDV-6.pkl
# 0.5
# 99b_V-FE-10.pkl
# 0.7038461538461539
# 99b_V-FE-17.pkl
# 1.0
# 99b_V-RV-11.pkl
# 0.742238946378175
# 99b_V-RV-14.pkl
# 0.9885844748858448
# 99b_V-RV-18.pkl
# 0.9976359338061466
# 99b_V-RV-21.pkl
# 0.45493562231759654
# 99b_V-RV-3.pkl
# 0.4068504594820384
# 99b_V-SortOverall-22.pkl
# 0.3886986301369863
# 99b_V-SortOverall-9.pkl
# 0.8906633906633906
# 99b_V-SortTwoFactors-15.pkl
# 0.9957044673539519
# 99b_V-SortTwoFactors-23.pkl
# 0.3699949315762798
# 99b_V-SortTwoFactors-5.pkl
# 0.9398496240601504
# 99b_V-SortTwoFactors-8.pkl
# 0.8158730158730159
# 9a_H-CDV-9.pkl
# 0.36020942408376966
# 9b_V-CDV-15.pkl
# 0.9584615384615385
# 9b_V-CDV-22.pkl
# 0.9981718464351006
# 9b_V-CDV-4.pkl
# 0.9955056179775281
# 9b_V-FE-16.pkl
# 0.9987146529562982
# 9b_V-FE-23.pkl
# 0.9974554707379135
# 9b_V-FE-3.pkl
# 0.9984251968503937
# 9b_V-FE-9.pkl
# 1.0
# 9b_V-RV-11.pkl
# 0.996734693877551
# 9b_V-RV-18.pkl
# 0.9977924944812362
# 9b_V-RV-21.pkl
# 0.9977810650887574
# 9b_V-SortOverall-8.pkl
# 0.9911699779249448
# 9b_V-SortTwoFactors-12.pkl
# 0.9964966913195796
# 9b_V-SortTwoFactors-17.pkl
# 0.9966887417218543
# 9b_V-SortTwoFactors-24.pkl
# 0.9975490196078431
# 9b_V-SortTwoFactors-5.pkl
# 0.8227459016393442
#
# Confused
#
# 134a_V-CDV-11.pkl
# 0.8785971223021583
# 134a_V-CDV-3.pkl
# 0.8546384222059897
# 134a_V-RV-18.pkl
# 0.8530721282279609
# 134a_V-RV-21.pkl
# 0.8349650349650349
# 134a_V-SortTwoFactors-9.pkl
# 0.6297136376523959
# 22a_V-SortTwoFactors-12.pkl
# 0.3940117853161331
# 30a_V-SortTwoFactors-6.pkl
# 0.6050531914893617
# 31a_H-SortTwoFactors-24.pkl
# 0.44335778321108393
# 31a_H-SortTwoFactors-9.pkl
# 0.46991676575505353
# 33a_H-SortOverall-2.pkl
# 0.42539184952978054
# 34a_V-CDV-2.pkl
# 0.8246471226927253
# 34a_V-RV-9.pkl
# 0.9581437670609645
# 44a_V-RV-3.pkl
# 0.928087986463621
# 49a_H-FE-3.pkl
# 0.9324499030381384
# 52a_V-SortTwoFactors-11.pkl
# 0.9925312550738756
# 52a_V-SortTwoFactors-15.pkl
# 0.9976771196283392
# 59b_V-CDV-17.pkl
# 0.995741056218058
# 73a_H-CDV-3.pkl
# 0.6776400171013254
# 73a_H-CDV-8.pkl
# 0.6615969581749049
# 76a_V-SortTwoFactors-6.pkl
# 0.690188091529891
# 97a_H-RV-14.pkl
# 0.3763856401911929
#
# 5425.000000 points processed
# Number of invalid not_confused:  1323
# Number of invalid confused:  21
# Number of pump confused:  20
#
# total number of not_confused to exclued so far:  2131
# total number of confused to exclued so far:  25
# total number of pump or OE to exclued so far:  21

# %%
#2. Remove the last second of data to remove signs of intention to push the 'confused' button
#4. Replace negative feature values in remaining items with sentinel value of -1
#5. Split the remaining data items into 4
#6. Save data items in ./dataset/augmented/ directory

if os.path.exists('../dataset/augmented/confused_highly_valid/'):
    shutil.rmtree('../dataset/augmented/confused_highly_valid/')
if os.path.exists('../dataset/augmented/not_confused_highly_valid/'):
    shutil.rmtree('../dataset/augmented/not_confused_highly_valid/')
if os.path.exists('../dataset/augmented/pump_confused_highly_valid/'):
    shutil.rmtree('../dataset/augmented/pump_confused_highly_valid/')
            
# Make new temp directories
os.makedirs('../dataset/augmented/confused_highly_valid/')
os.makedirs('../dataset/augmented/not_confused_highly_valid/')
os.makedirs('../dataset/augmented/pump_confused_highly_valid/')

# %%
# remove excluded items from list of items in each class
for item in confused_names_exclude:
    confused_item_names.remove(item)
    
for item in not_confused_names_exclude:
    not_confused_item_names.remove(item)
    
for item in pump_names_exclude:
    pump_confused_item_names.remove(item)

# %%
to_path = '../dataset/augmented/confused_highly_valid/'
for name in confused_item_names:
    print(name)
    f = open(confused_path+name, 'rb')
    item = pickle.load(f)
    # replace remaining invalid values with -1
    item = fix_missing_eye(item)
    item = fix_invalid_rows(item)
    item = item.replace({6:4.0, 13:4.0}, -1)
    # remove last second
    item = item.values[:-SAMPLES_PER_SECOND]
    d1 = pd.DataFrame(item[0::4]).to_pickle(to_path+name.split('.')[0]+'-1.pkl')
    d2 = pd.DataFrame(item[1::4]).to_pickle(to_path+name.split('.')[0]+'-2.pkl')
    d3 = pd.DataFrame(item[2::4]).to_pickle(to_path+name.split('.')[0]+'-3.pkl')
    d4 = pd.DataFrame(item[3::4]).to_pickle(to_path+name.split('.')[0]+'-4.pkl')
    f.close()
# Out:
# 37a_H-SortTwoFactors-14.pkl
# 35a_H-SortTwoFactors-22.pkl
# 86a_V-FE-10.pkl
# 103a_H-CDV-17.pkl
# 12b_H-CDV-5.pkl
# 9a_H-SortTwoFactors-12.pkl
# 132b_H-CDV-6.pkl
# 58a_V-SortTwoFactors-6.pkl
# 145b_V-SortTwoFactors-10.pkl
# 112a_V-SortTwoFactors-5.pkl
# 103a_H-CDV-12.pkl
# 129b_V-SortTwoFactors-23.pkl
# 132a_V-SortOverall-9.pkl
# 37a_H-SortTwoFactors-12.pkl
# 74b_H-FE-12.pkl
# 134b_H-CDV-4.pkl
# 35a_H-SortTwoFactors-4.pkl
# 105b_V-FE-20.pkl
# 132b_H-SortOverall-9.pkl
# 39a_H-SortTwoFactors-24.pkl
# 1b_V-CDV-17.pkl
# 58a_V-SortTwoFactors-23.pkl
# 36a_V-SortTwoFactors-2.pkl
# 121b_V-FE-2.pkl
# 48a_V-SortTwoFactors-12.pkl
# 111a_H-SortTwoFactors-3.pkl
# 39b_V-RV-18.pkl
# 132b_H-CDV-12.pkl
# 143a_H-CDV-17.pkl
# 133a_H-CDV-16.pkl
# 39b_V-SortTwoFactors-17.pkl
# 14a_V-SortTwoFactors-3.pkl
# 50a_V-SortTwoFactors-22.pkl
# 114a_V-SortTwoFactors-12.pkl
# 141a_H-RV-18.pkl
# 40a_V-SortTwoFactors-17.pkl
# 132a_V-SortOverall-21.pkl
# 6b_H-SortOverall-10.pkl
# 132a_V-CDV-2.pkl
# 39b_V-SortTwoFactors-3.pkl
# 132b_H-CDV-16.pkl
# 141a_H-SortTwoFactors-22.pkl
# 137a_H-SortTwoFactors-2.pkl
# 105a_H-RV-22.pkl
# 86b_H-CDV-6.pkl
# 130a_V-RV-10.pkl
# 55b_V-CDV-11.pkl
# 10a_V-CDV-2.pkl
# 19b_V-RV-24.pkl
# 8a_V-SortTwoFactors-10.pkl
# 25a_H-RV-22.pkl
# 122a_V-SortTwoFactors-4.pkl
# 21b_V-SortTwoFactors-11.pkl
# 58a_V-SortTwoFactors-14.pkl
# 121a_H-SortTwoFactors-20.pkl
# 63a_H-SortTwoFactors-5.pkl
# 121a_H-CDV-9.pkl
# 7a_H-SortTwoFactors-4.pkl
# 32a_V-SortTwoFactors-11.pkl
# 126a_V-SortTwoFactors-6.pkl
# 8b_H-CDV-21.pkl
# 142b_H-CDV-22.pkl
# 142a_V-CDV-15.pkl
# 134b_H-CDV-15.pkl
# 131a_H-SortTwoFactors-12.pkl
# 105a_H-FE-17.pkl
# 131a_H-CDV-5.pkl
# 3a_H-SortTwoFactors-11.pkl
# 86a_V-SortTwoFactors-4.pkl
# 105b_V-RV-5.pkl
# 145b_V-SortTwoFactors-24.pkl
# 137a_H-FE-4.pkl
# 35a_H-SortTwoFactors-15.pkl
# 39a_H-SortTwoFactors-17.pkl
# 131b_V-SortTwoFactors-21.pkl
# 11a_H-SortTwoFactors-5.pkl
# 19b_V-SortTwoFactors-23.pkl
# 121b_V-SortTwoFactors-11.pkl
# 105a_H-RV-8.pkl
# 37a_H-SortTwoFactors-5.pkl
# 132a_V-SortTwoFactors-6.pkl
# 82a_V-SortTwoFactors-4.pkl
# 137b_V-FE-20.pkl
# 39a_H-SortTwoFactors-10.pkl
# 105b_V-FE-8.pkl

# %%
to_path = './dataset/augmented/not_confused_highly_valid/'
for name in not_confused_item_names:
    print(name)
    f = open(not_confused_path+name, 'rb')
    item = pickle.load(f)
    # replace remaining invalid values with -1
    item = fix_missing_eye(item)
    item = fix_invalid_rows(item)

    item = item.replace({6:4.0, 13:4.0}, -1)

    # remove last second
    item = item.values[:-SAMPLES_PER_SECOND]
    d1 = pd.DataFrame(item[0::4]).to_pickle(to_path+name.split('.')[0]+'-1.pkl')
    d2 = pd.DataFrame(item[1::4]).to_pickle(to_path+name.split('.')[0]+'-2.pkl')
    d3 = pd.DataFrame(item[2::4]).to_pickle(to_path+name.split('.')[0]+'-3.pkl')
    d4 = pd.DataFrame(item[3::4]).to_pickle(to_path+name.split('.')[0]+'-4.pkl')
    f.close()
# Out:
# 106b_H-CDV-9.pkl
# 45b_V-RV-22.pkl
# 79b_V-SortTwoFactors-21.pkl
# 91a_V-FE-4.pkl
# 54a_V-SortOverall-8.pkl
# 39b_V-CDV-10.pkl
# 63b_V-CDV-12.pkl
# 38a_V-FE-17.pkl
# 66b_H-RV-18.pkl
# 111a_H-SortOverall-4.pkl
# 85a_H-CDV-3.pkl
# 62b_V-RV-15.pkl
# 145b_V-RV-5.pkl
# 105a_H-SortTwoFactors-2.pkl
# 36b_H-SortTwoFactors-16.pkl
# 122b_H-FE-15.pkl
# 35b_V-SortTwoFactors-2.pkl
# 105b_V-SortTwoFactors-3.pkl
# 45b_V-SortOverall-3.pkl
# 62b_V-CDV-20.pkl
# 109a_H-SortTwoFactors-10.pkl
# 93b_H-SortTwoFactors-11.pkl
# 137a_H-SortOverall-20.pkl
# 34b_H-FE-15.pkl
# 77a_H-SortOverall-24.pkl
# 70a_V-FE-5.pkl
# 55b_V-RV-10.pkl
# 122b_H-RV-18.pkl
# 17b_V-RV-22.pkl
# 37a_H-SortTwoFactors-14.pkl
# 9a_H-RV-18.pkl
# 85a_H-FE-20.pkl
# 109a_H-RV-14.pkl
# 107a_H-FE-6.pkl
# 112b_H-RV-2.pkl
# 129b_V-RV-4.pkl
# 75b_V-CDV-20.pkl
# 19b_V-SortOverall-5.pkl
# 142b_H-SortOverall-2.pkl
# 13b_V-CDV-11.pkl
# 13a_H-CDV-24.pkl
# 148a_V-RV-17.pkl
# 105b_V-RV-16.pkl
# 66b_H-FE-15.pkl
# 116b_H-SortTwoFactors-16.pkl
# 4a_V-FE-3.pkl
# 82a_V-CDV-6.pkl
# 71b_V-SortTwoFactors-22.pkl
# 66b_H-SortOverall-8.pkl
# 19a_H-SortOverall-6.pkl
# 112b_H-CDV-16.pkl
# 55b_V-SortTwoFactors-8.pkl
# 146b_H-CDV-8.pkl
# 48a_V-RV-22.pkl
# 22b_H-CDV-3.pkl
# 70b_H-CDV-12.pkl
# 111a_H-SortTwoFactors-22.pkl
# 54b_H-RV-12.pkl
# 11b_V-SortTwoFactors-17.pkl
# 13b_V-SortOverall-6.pkl
# 149b_V-RV-3.pkl
# 50b_H-CDV-8.pkl
# 111b_V-CDV-12.pkl
# 2b_H-SortTwoFactors-4.pkl
# 127a_H-FE-9.pkl
# 82a_V-CDV-12.pkl
# 112b_H-SortTwoFactors-17.pkl
# 55a_H-SortTwoFactors-9.pkl
# 15b_V-RV-11.pkl
# 110b_H-FE-23.pkl
# 39a_H-FE-15.pkl
# 90a_H-FE-21.pkl
# 8a_V-CDV-8.pkl
# 4b_H-RV-18.pkl
# 2a_V-CDV-22.pkl
# 58a_V-FE-21.pkl
# 128a_V-FE-10.pkl
# 118a_V-RV-18.pkl
# 130a_V-FE-6.pkl
# 93a_V-RV-5.pkl
# 47b_V-CDV-3.pkl
# 71b_V-CDV-21.pkl
# 97a_H-CDV-2.pkl
# 113a_H-SortOverall-22.pkl
# 15a_H-SortOverall-9.pkl
# 1b_V-SortOverall-16.pkl
# 54b_H-FE-23.pkl
# 104b_H-CDV-6.pkl
# 74a_V-SortTwoFactors-21.pkl
# 4a_V-SortOverall-12.pkl
# 138a_V-CDV-22.pkl
# 145b_V-SortTwoFactors-2.pkl
# 25a_H-SortTwoFactors-12.pkl
# 16b_H-RV-20.pkl
# 19b_V-SortTwoFactors-14.pkl
# 14a_V-CDV-21.pkl
# 133b_V-SortOverall-21.pkl
# 142b_H-FE-4.pkl
# 107a_H-SortTwoFactors-24.pkl
# 97a_H-RV-11.pkl
# 70b_H-RV-10.pkl
# 47b_V-RV-10.pkl
# 40b_H-SortOverall-2.pkl
# 130b_H-FE-15.pkl
# 22b_H-FE-8.pkl
# 26b_H-SortOverall-20.pkl
# 113a_H-SortTwoFactors-14.pkl
# 13b_V-SortTwoFactors-21.pkl
# 149a_H-CDV-6.pkl
# 56b_H-SortOverall-23.pkl
# 74b_H-RV-18.pkl
# 67b_V-FE-16.pkl
# 77a_H-RV-4.pkl
# 110b_H-CDV-20.pkl
# 67b_V-SortOverall-23.pkl
# 29a_H-CDV-5.pkl
# 15a_H-FE-2.pkl
# 121a_H-SortOverall-21.pkl
# 8b_H-SortOverall-11.pkl
# 72a_V-CDV-11.pkl
# 110b_H-SortTwoFactors-21.pkl
# 55b_V-SortOverall-21.pkl
# 22b_H-FE-21.pkl
# 2b_H-CDV-16.pkl
# 3b_V-FE-11.pkl
# 133b_V-RV-15.pkl
# 95a_H-CDV-12.pkl
# 75b_V-SortTwoFactors-22.pkl
# 128a_V-RV-20.pkl
# 58b_H-SortOverall-5.pkl
# 22b_H-RV-10.pkl
# 26a_V-SortTwoFactors-4.pkl
# 4b_H-FE-14.pkl
# 103b_V-RV-10.pkl
# 96b_H-CDV-23.pkl
# 93a_V-FE-11.pkl
# 21b_V-FE-10.pkl
# 67b_V-CDV-9.pkl
# 130b_H-RV-24.pkl
# 26b_H-RV-18.pkl
# 2a_V-SortTwoFactors-4.pkl
# 129b_V-SortOverall-6.pkl
# 140a_V-SortTwoFactors-10.pkl
# 87a_V-FE-17.pkl
# 15b_V-CDV-2.pkl
# 29a_H-CDV-20.pkl
# 90a_H-CDV-3.pkl
# 27a_H-SortTwoFactors-24.pkl
# 100b_H-FE-10.pkl
# 12b_H-RV-8.pkl
# 65a_H-FE-2.pkl
# 36a_V-SortOverall-3.pkl
# 96b_H-FE-3.pkl
# 130b_H-RV-18.pkl
# 11b_V-RV-24.pkl
# 139b_V-SortTwoFactors-15.pkl
# 64a_V-CDV-23.pkl
# 50b_H-RV-9.pkl
# 125a_H-RV-9.pkl
# 141b_V-SortTwoFactors-4.pkl
# 132b_H-SortTwoFactors-8.pkl
# 126b_H-RV-11.pkl
# 144b_H-CDV-6.pkl
# 132b_H-RV-17.pkl
# 45a_H-RV-5.pkl
# 130b_H-RV-5.pkl
# 144a_V-SortTwoFactors-11.pkl
# 16a_V-SortOverall-4.pkl
# 46b_H-RV-12.pkl
# 103b_V-CDV-20.pkl
# 82a_V-RV-15.pkl
# 65b_V-RV-14.pkl
# 114a_V-CDV-14.pkl
# 79a_H-RV-18.pkl
# 10b_H-FE-9.pkl
# 92b_V-CDV-23.pkl
# 19a_H-FE-4.pkl
# 111b_V-CDV-3.pkl
# 15b_V-SortTwoFactors-8.pkl
# 100b_H-CDV-24.pkl
# 37b_V-CDV-6.pkl
# 10a_V-SortOverall-23.pkl
# 129b_V-CDV-21.pkl
# 3b_V-RV-8.pkl
# 58b_H-SortTwoFactors-17.pkl
# 22a_V-SortTwoFactors-3.pkl
# 71b_V-SortOverall-23.pkl
# 96a_V-FE-9.pkl
# 65b_V-FE-8.pkl
# 35a_H-SortOverall-24.pkl
# 87b_H-SortTwoFactors-20.pkl
# 35a_H-RV-5.pkl
# 13a_H-SortOverall-21.pkl
# 23b_V-RV-12.pkl
# 93b_H-CDV-10.pkl
# 67b_V-SortTwoFactors-24.pkl
# 17a_H-RV-3.pkl
# 129a_H-RV-22.pkl
# 81a_H-RV-18.pkl
# 7a_H-CDV-11.pkl
# 143b_V-CDV-3.pkl
# 6b_H-RV-9.pkl
# 83a_H-SortOverall-24.pkl
# 127b_V-FE-2.pkl
# 10a_V-SortOverall-8.pkl
# 39b_V-RV-9.pkl
# 72b_H-SortOverall-23.pkl
# 13b_V-FE-24.pkl
# 3b_V-SortOverall-12.pkl
# 21a_H-SortOverall-21.pkl
# 39b_V-SortOverall-24.pkl
# 77b_V-CDV-14.pkl
# 75b_V-FE-15.pkl
# 109a_H-RV-2.pkl
# 30b_H-SortOverall-22.pkl
# 47b_V-RV-4.pkl
# 137a_H-RV-5.pkl
# 126b_H-SortOverall-20.pkl
# 131b_V-RV-18.pkl
# 49a_H-RV-23.pkl
# 106b_H-RV-18.pkl
# 58b_H-SortTwoFactors-6.pkl
# 66b_H-SortOverall-24.pkl
# 146a_V-SortTwoFactors-24.pkl
# 57a_H-RV-9.pkl
# 150b_H-FE-21.pkl
# 11a_H-CDV-10.pkl
# 14b_H-CDV-2.pkl
# 95b_V-SortTwoFactors-9.pkl
# 1b_V-FE-20.pkl
# 38a_V-CDV-15.pkl
# 55b_V-FE-2.pkl
# 106b_H-FE-15.pkl
# 112b_H-FE-9.pkl
# 8b_H-RV-4.pkl
# 103a_H-CDV-17.pkl
# 75a_H-CDV-16.pkl
# 37b_V-RV-4.pkl
# 92a_H-CDV-14.pkl
# 10b_H-FE-15.pkl
# 150b_H-CDV-2.pkl
# 20a_V-SortTwoFactors-9.pkl
# 109a_H-CDV-5.pkl
# 110a_V-SortTwoFactors-8.pkl
# 23b_V-FE-21.pkl
# 122b_H-CDV-9.pkl
# 86a_V-RV-23.pkl
# 129a_H-FE-11.pkl
# 46b_H-CDV-2.pkl
# 4a_V-RV-8.pkl
# 65b_V-CDV-4.pkl
# 72b_H-FE-10.pkl
# 106a_V-SortOverall-3.pkl
# 75b_V-RV-18.pkl
# 114b_H-FE-14.pkl
# 140a_V-FE-5.pkl
# 35b_V-FE-5.pkl
# 28b_H-SortOverall-9.pkl
# 8a_V-FE-14.pkl
# 105a_H-SortTwoFactors-11.pkl
# 3a_H-CDV-12.pkl
# 122a_V-RV-3.pkl
# 3a_H-FE-8.pkl
# 77a_H-SortTwoFactors-9.pkl
# 3b_V-SortOverall-2.pkl
# 36b_H-CDV-6.pkl
# 105a_H-RV-4.pkl
# 130a_V-SortTwoFactors-16.pkl
# 123a_H-SortTwoFactors-5.pkl
# 75b_V-RV-5.pkl
# 150a_V-SortTwoFactors-9.pkl
# 7b_V-CDV-4.pkl
# 16a_V-CDV-15.pkl
# 118a_V-FE-16.pkl
# 58a_V-CDV-12.pkl
# 134b_H-RV-12.pkl
# 30b_H-SortTwoFactors-23.pkl
# 142b_H-CDV-3.pkl
# 47a_H-FE-6.pkl
# 12a_V-SortTwoFactors-21.pkl
# 11b_V-CDV-8.pkl
# 15b_V-CDV-24.pkl
# 31b_V-SortTwoFactors-6.pkl
# 26b_H-SortTwoFactors-24.pkl
# 25b_V-SortOverall-20.pkl
# 150a_V-SortOverall-6.pkl
# 77b_V-SortTwoFactors-17.pkl
# 10a_V-SortTwoFactors-16.pkl
# 150b_H-SortOverall-5.pkl
# 32b_H-SortTwoFactors-14.pkl
# 149b_V-CDV-24.pkl
# 84a_V-SortTwoFactors-6.pkl
# 48b_H-SortTwoFactors-24.pkl
# 145b_V-RV-14.pkl
# 32b_H-FE-11.pkl
# 110a_V-SortOverall-23.pkl
# 143b_V-SortOverall-21.pkl
# 83a_H-RV-14.pkl
# 83a_H-CDV-23.pkl
# 37a_H-SortOverall-20.pkl
# 25b_V-CDV-4.pkl
# 83b_V-CDV-16.pkl
# 40b_H-FE-5.pkl
# 137b_V-RV-22.pkl
# 56b_H-SortTwoFactors-21.pkl
# 47a_H-SortOverall-23.pkl
# 11b_V-FE-16.pkl
# 35b_V-RV-18.pkl
# 26b_H-FE-16.pkl
# 65a_H-SortOverall-5.pkl
# 8a_V-RV-18.pkl
# 96a_V-SortTwoFactors-20.pkl
# 21b_V-RV-22.pkl
# 17b_V-CDV-12.pkl
# 148a_V-SortTwoFactors-10.pkl
# 21a_H-SortOverall-4.pkl
# 12b_H-RV-16.pkl
# 25b_V-RV-16.pkl
# 83a_H-CDV-6.pkl
# 103b_V-FE-22.pkl
# 17b_V-SortOverall-23.pkl
# 128a_V-SortOverall-24.pkl
# 92a_H-SortOverall-15.pkl
# 4b_H-RV-3.pkl
# 50b_H-FE-15.pkl
# 104b_H-SortTwoFactors-12.pkl
# 81a_H-SortOverall-20.pkl
# 32a_V-FE-6.pkl
# 141b_V-SortTwoFactors-11.pkl
# 110b_H-RV-10.pkl
# 126a_V-SortTwoFactors-10.pkl
# 113a_H-CDV-12.pkl
# 40b_H-CDV-4.pkl
# 109b_V-RV-9.pkl
# 84a_V-CDV-3.pkl
# 50b_H-RV-18.pkl
# 57b_V-FE-10.pkl
# 94a_H-CDV-8.pkl
# 25a_H-FE-9.pkl
# 141b_V-FE-10.pkl
# 63b_V-RV-10.pkl
# 36b_H-SortOverall-3.pkl
# 19a_H-RV-11.pkl
# 35b_V-FE-15.pkl
# 150b_H-SortTwoFactors-9.pkl
# 72b_H-SortOverall-2.pkl
# 13b_V-SortTwoFactors-4.pkl
# 148b_H-SortOverall-3.pkl
# 112a_V-CDV-21.pkl
# 26b_H-SortTwoFactors-6.pkl
# 99b_V-SortOverall-4.pkl
# 64b_H-CDV-15.pkl
# 65a_H-RV-9.pkl
# 105a_H-CDV-20.pkl
# 9a_H-SortTwoFactors-12.pkl
# 139a_H-FE-3.pkl
# 71b_V-SortTwoFactors-6.pkl
# 10a_V-CDV-22.pkl
# 16a_V-SortTwoFactors-21.pkl
# 13b_V-RV-14.pkl
# 142a_V-SortOverall-3.pkl
# 50b_H-FE-2.pkl
# 125a_H-FE-2.pkl
# 52b_H-CDV-5.pkl
# 27a_H-RV-8.pkl
# 34b_H-SortTwoFactors-23.pkl
# 65b_V-SortTwoFactors-10.pkl
# 37b_V-SortTwoFactors-8.pkl
# 2b_H-FE-10.pkl
# 142a_V-RV-5.pkl
# 27b_V-FE-14.pkl
# 15b_V-SortTwoFactors-14.pkl
# 110b_H-SortTwoFactors-8.pkl
# 92a_H-RV-21.pkl
# 16b_H-SortOverall-4.pkl
# 131b_V-FE-14.pkl
# 144b_H-RV-17.pkl
# 6b_H-SortOverall-3.pkl
# 105b_V-CDV-6.pkl
# 109b_V-SortOverall-2.pkl
# 55b_V-FE-23.pkl
# 150b_H-RV-11.pkl
# 91b_H-SortTwoFactors-24.pkl
# 132b_H-CDV-6.pkl
# 64a_V-SortTwoFactors-12.pkl
# 127a_H-SortTwoFactors-3.pkl
# 86b_H-CDV-24.pkl
# 86a_V-SortTwoFactors-11.pkl
# 62b_V-CDV-5.pkl
# 148b_H-SortOverall-21.pkl
# 52b_H-SortTwoFactors-20.pkl
# 131b_V-SortOverall-24.pkl
# 129a_H-SortOverall-21.pkl
# 46b_H-SortTwoFactors-10.pkl
# 9a_H-FE-17.pkl
# 93a_V-SortOverall-10.pkl
# 21a_H-SortTwoFactors-11.pkl
# 93a_V-SortTwoFactors-2.pkl
# 45a_H-SortOverall-24.pkl
# 62b_V-SortTwoFactors-4.pkl
# 4b_H-CDV-23.pkl
# 4a_V-CDV-16.pkl
# 58a_V-SortTwoFactors-6.pkl
# 14b_H-RV-11.pkl
# 40b_H-SortOverall-20.pkl
# 74a_V-SortOverall-24.pkl
# 14a_V-SortTwoFactors-16.pkl
# 95a_H-SortTwoFactors-9.pkl
# 150a_V-FE-3.pkl
# 106a_V-SortOverall-22.pkl
# 25b_V-FE-3.pkl
# 6b_H-FE-2.pkl
# 145b_V-SortTwoFactors-10.pkl
# 75a_H-FE-6.pkl
# 116b_H-CDV-15.pkl
# 39b_V-FE-2.pkl
# 114b_H-SortTwoFactors-23.pkl
# 55b_V-CDV-4.pkl
# 85b_V-SortTwoFactors-20.pkl
# 123a_H-SortOverall-21.pkl
# 36b_H-SortTwoFactors-10.pkl
# 112b_H-SortTwoFactors-4.pkl
# 100b_H-SortTwoFactors-17.pkl
# 45b_V-RV-18.pkl
# 86a_V-FE-17.pkl
# 90a_H-SortTwoFactors-22.pkl
# 72b_H-RV-18.pkl
# 62b_V-FE-3.pkl
# 39b_V-CDV-16.pkl
# 72b_H-RV-24.pkl
# 100b_H-FE-2.pkl
# 84a_V-SortOverall-4.pkl
# 66b_H-RV-22.pkl
# 103a_H-SortTwoFactors-22.pkl
# 122b_H-FE-4.pkl
# 106b_H-RV-21.pkl
# 52b_H-FE-22.pkl
# 29a_H-RV-3.pkl
# 16b_H-SortOverall-22.pkl
# 93b_H-SortOverall-2.pkl
# 121b_V-SortTwoFactors-20.pkl
# 123b_V-SortTwoFactors-17.pkl
# 67a_H-RV-4.pkl
# 122b_H-RV-22.pkl
# 23a_H-SortTwoFactors-22.pkl
# 109a_H-RV-12.pkl
# 148b_H-SortTwoFactors-9.pkl
# 148a_V-CDV-3.pkl
# 81a_H-RV-9.pkl
# 97a_H-SortTwoFactors-5.pkl
# 7a_H-SortTwoFactors-23.pkl
# 140b_H-CDV-9.pkl
# 79a_H-RV-23.pkl
# 132a_V-SortOverall-9.pkl
# 141a_H-SortTwoFactors-2.pkl
# 125b_V-FE-16.pkl
# 84a_V-RV-8.pkl
# 116b_H-FE-22.pkl
# 81a_H-FE-12.pkl
# 95a_H-FE-14.pkl
# 13b_V-CDV-17.pkl
# 140a_V-SortTwoFactors-17.pkl
# 48a_V-RV-18.pkl
# 57b_V-RV-6.pkl
# 19a_H-RV-15.pkl
# 29b_V-CDV-12.pkl
# 9a_H-SortTwoFactors-16.pkl
# 29b_V-RV-9.pkl
# 57a_H-SortOverall-2.pkl
# 38b_H-SortTwoFactors-9.pkl
# 3b_V-CDV-9.pkl
# 3a_H-CDV-17.pkl
# 140a_V-RV-8.pkl
# 3a_H-SortTwoFactors-22.pkl
# 35b_V-RV-8.pkl
# 30b_H-RV-9.pkl
# 109b_V-FE-5.pkl
# 132b_H-FE-3.pkl
# 133b_V-FE-23.pkl
# 25a_H-RV-5.pkl
# 91b_H-FE-8.pkl
# 58b_H-CDV-22.pkl
# 75b_V-FE-8.pkl
# 39a_H-RV-4.pkl
# 21b_V-CDV-8.pkl
# 70b_H-SortOverall-21.pkl
# 50b_H-FE-11.pkl
# 75a_H-SortTwoFactors-4.pkl
# 84b_H-SortTwoFactors-2.pkl
# 2b_H-SortTwoFactors-20.pkl
# 64b_H-CDV-3.pkl
# 28b_H-CDV-21.pkl
# 125b_V-RV-4.pkl
# 132a_V-SortTwoFactors-24.pkl
# 4b_H-RV-22.pkl
# 104a_V-CDV-17.pkl
# 8b_H-SortOverall-16.pkl
# 149b_V-SortOverall-20.pkl
# 7a_H-SortOverall-16.pkl
# 110b_H-RV-14.pkl
# 145b_V-CDV-3.pkl
# 7b_V-FE-22.pkl
# 112a_V-FE-6.pkl
# 1a_H-SortTwoFactors-15.pkl
# 70b_H-RV-17.pkl
# 8a_V-FE-3.pkl
# 35b_V-RV-20.pkl
# 148a_V-SortTwoFactors-14.pkl
# 116b_H-SortOverall-20.pkl
# 110b_H-CDV-6.pkl
# 145b_V-RV-11.pkl
# 72a_V-RV-3.pkl
# 22b_H-RV-6.pkl
# 142a_V-SortTwoFactors-21.pkl
# 77b_V-FE-22.pkl
# 4a_V-SortOverall-15.pkl
# 75b_V-SortTwoFactors-4.pkl
# 75a_H-SortOverall-24.pkl
# 11a_H-SortTwoFactors-8.pkl
# 142b_H-FE-24.pkl
# 29a_H-RV-11.pkl
# 21b_V-SortOverall-2.pkl
# 37a_H-FE-2.pkl
# 36b_H-FE-21.pkl
# 100b_H-CDV-9.pkl
# 94b_V-SortOverall-16.pkl
# 141b_V-RV-18.pkl
# 11a_H-SortOverall-20.pkl
# 57b_V-RV-24.pkl
# 128a_V-SortTwoFactors-3.pkl
# 94a_H-SortTwoFactors-22.pkl
# 145a_H-SortTwoFactors-4.pkl
# 138a_V-SortTwoFactors-11.pkl
# 16b_H-CDV-9.pkl
# 74a_V-SortOverall-8.pkl
# 139b_V-RV-4.pkl
# 84b_H-RV-3.pkl
# 57b_V-RV-18.pkl
# 96a_V-CDV-10.pkl
# 96b_H-SortOverall-2.pkl
# 100a_V-FE-9.pkl
# 138a_V-CDV-6.pkl
# 81a_H-CDV-11.pkl
# 16b_H-CDV-24.pkl
# 130a_V-SortTwoFactors-12.pkl
# 116a_V-SortTwoFactors-3.pkl
# 104b_H-FE-22.pkl
# 103b_V-SortOverall-4.pkl
# 15a_H-CDV-15.pkl
# 22b_H-RV-16.pkl
# 39b_V-SortOverall-5.pkl
# 112b_H-SortTwoFactors-10.pkl
# 57b_V-FE-15.pkl
# 145a_H-RV-8.pkl
# 116b_H-SortTwoFactors-2.pkl
# 134b_H-CDV-4.pkl
# 129a_H-SortOverall-3.pkl
# 148a_V-SortOverall-5.pkl
# 13a_H-SortOverall-2.pkl
# 32b_H-RV-24.pkl
# 26b_H-RV-22.pkl
# 110b_H-FE-4.pkl
# 114b_H-FE-10.pkl
# 40b_H-SortTwoFactors-23.pkl
# 106a_V-CDV-21.pkl
# 20a_V-RV-5.pkl
# 111b_V-CDV-15.pkl
# 129a_H-FE-15.pkl
# 4b_H-SortTwoFactors-17.pkl
# 2b_H-FE-15.pkl
# 111b_V-RV-17.pkl
# 62b_V-FE-23.pkl
# 132b_H-RV-11.pkl
# 128a_V-CDV-21.pkl
# 116b_H-SortTwoFactors-11.pkl
# 10b_H-CDV-12.pkl
# 50b_H-SortTwoFactors-12.pkl
# 1b_V-RV-15.pkl
# 86a_V-CDV-9.pkl
# 92a_H-RV-18.pkl
# 109a_H-SortOverall-4.pkl
# 72a_V-SortTwoFactors-10.pkl
# 46b_H-RV-14.pkl
# 52b_H-RV-12.pkl
# 29a_H-SortTwoFactors-17.pkl
# 12a_V-CDV-10.pkl
# 137a_H-FE-9.pkl
# 27b_V-RV-20.pkl
# 140b_H-RV-3.pkl
# 112a_V-SortOverall-20.pkl
# 109a_H-SortTwoFactors-17.pkl
# 61b_H-CDV-23.pkl
# 100b_H-SortOverall-8.pkl
# 144b_H-FE-23.pkl
# 3b_V-FE-6.pkl
# 105b_V-FE-2.pkl
# 109a_H-FE-22.pkl
# 83b_V-FE-3.pkl
# 87a_V-SortOverall-12.pkl
# 86b_H-FE-2.pkl
# 129a_H-RV-18.pkl
# 112b_H-CDV-8.pkl
# 35a_H-SortOverall-9.pkl
# 121b_V-RV-12.pkl
# 15b_V-SortOverall-21.pkl
# 2b_H-RV-18.pkl
# 58a_V-SortOverall-20.pkl
# 74b_H-CDV-14.pkl
# 35a_H-SortTwoFactors-4.pkl
# 22b_H-SortTwoFactors-4.pkl
# 93b_H-CDV-14.pkl
# 74a_V-CDV-23.pkl
# 144a_V-SortOverall-24.pkl
# 84b_H-SortOverall-4.pkl
# 93b_H-SortTwoFactors-4.pkl
# 37b_V-RV-10.pkl
# 65b_V-SortOverall-20.pkl
# 14a_V-SortTwoFactors-11.pkl
# 87a_V-CDV-24.pkl
# 134b_H-SortOverall-5.pkl
# 77b_V-CDV-12.pkl
# 87b_H-CDV-11.pkl
# 62b_V-RV-8.pkl
# 73b_V-SortTwoFactors-10.pkl
# 139a_H-CDV-6.pkl
# 30b_H-FE-24.pkl
# 45a_H-SortTwoFactors-22.pkl
# 111a_H-SortOverall-20.pkl
# 116b_H-RV-10.pkl
# 131b_V-RV-22.pkl
# 125b_V-RV-24.pkl
# 6b_H-SortTwoFactors-6.pkl
# 130b_H-SortTwoFactors-4.pkl
# 83b_V-RV-9.pkl
# 92a_H-FE-17.pkl
# 112b_H-RV-24.pkl
# 17b_V-FE-16.pkl
# 48a_V-CDV-10.pkl
# 11b_V-CDV-23.pkl
# 23b_V-CDV-4.pkl
# 114b_H-SortOverall-24.pkl
# 17b_V-SortTwoFactors-24.pkl
# 96a_V-RV-5.pkl
# 125b_V-RV-18.pkl
# 93a_V-SortOverall-17.pkl
# 79b_V-RV-5.pkl
# 114a_V-CDV-10.pkl
# 77a_H-SortOverall-6.pkl
# 132b_H-SortOverall-9.pkl
# 143b_V-FE-24.pkl
# 34b_H-RV-21.pkl
# 77b_V-SortOverall-5.pkl
# 144b_H-RV-10.pkl
# 150b_H-RV-16.pkl
# 137b_V-SortTwoFactors-24.pkl
# 77b_V-FE-2.pkl
# 123a_H-SortOverall-2.pkl
# 29b_V-SortTwoFactors-4.pkl
# 140b_H-RV-18.pkl
# 15b_V-RV-4.pkl
# 1b_V-CDV-5.pkl
# 106b_H-SortOverall-6.pkl
# 32b_H-RV-3.pkl
# 126b_H-RV-15.pkl
# 148a_V-RV-12.pkl
# 84a_V-RV-16.pkl
# 70a_V-CDV-22.pkl
# 83a_H-RV-3.pkl
# 70b_H-RV-2.pkl
# 94b_V-RV-2.pkl
# 86b_H-SortTwoFactors-9.pkl
# 12b_H-FE-4.pkl
# 142b_H-RV-17.pkl
# 29b_V-FE-2.pkl
# 138a_V-RV-16.pkl
# 83a_H-FE-22.pkl
# 123b_V-FE-12.pkl
# 137b_V-FE-14.pkl
# 77b_V-CDV-3.pkl
# 82b_H-CDV-22.pkl
# 54b_H-CDV-5.pkl
# 146b_H-RV-23.pkl
# 4b_H-FE-10.pkl
# 52b_H-RV-4.pkl
# 83b_V-SortTwoFactors-15.pkl
# 86a_V-RV-2.pkl
# 128a_V-RV-18.pkl
# 150b_H-RV-6.pkl
# 70b_H-CDV-6.pkl
# 63b_V-SortTwoFactors-21.pkl
# 77a_H-FE-8.pkl
# 141b_V-SortTwoFactors-16.pkl
# 65b_V-CDV-21.pkl
# 133b_V-RV-11.pkl
# 77b_V-SortTwoFactors-11.pkl
# 104b_H-RV-11.pkl
# 57b_V-SortTwoFactors-5.pkl
# 131a_H-SortOverall-6.pkl
# 113a_H-CDV-15.pkl
# 2b_H-CDV-12.pkl
# 72b_H-CDV-20.pkl
# 74b_H-RV-20.pkl
# 72a_V-CDV-15.pkl
# 30b_H-SortOverall-8.pkl
# 31b_V-CDV-5.pkl
# 47b_V-RV-14.pkl
# 57a_H-SortTwoFactors-4.pkl
# 83b_V-CDV-11.pkl
# 67b_V-FE-5.pkl
# 93a_V-RV-18.pkl
# 26b_H-FE-11.pkl
# 20a_V-SortOverall-22.pkl
# 11b_V-FE-11.pkl
# 19b_V-RV-2.pkl
# 133b_V-CDV-3.pkl
# 9a_H-SortTwoFactors-2.pkl
# 31b_V-SortOverall-21.pkl
# 55a_H-RV-6.pkl
# 29a_H-SortOverall-24.pkl
# 145a_H-SortOverall-21.pkl
# 19b_V-SortTwoFactors-10.pkl
# 100b_H-RV-18.pkl
# 137b_V-RV-18.pkl
# 84b_H-SortOverall-22.pkl
# 17b_V-CDV-14.pkl
# 127b_V-CDV-4.pkl
# 1b_V-RV-4.pkl
# 16b_H-RV-18.pkl
# 21b_V-RV-18.pkl
# 8a_V-RV-9.pkl
# 114b_H-RV-22.pkl
# 48a_V-FE-17.pkl
# 10a_V-FE-6.pkl
# 107a_H-SortOverall-21.pkl
# 37a_H-RV-9.pkl
# 14b_H-CDV-10.pkl
# 104b_H-CDV-20.pkl
# 45b_V-FE-2.pkl
# 139b_V-SortOverall-21.pkl
# 114b_H-SortTwoFactors-9.pkl
# 32b_H-SortOverall-22.pkl
# 65a_H-CDV-15.pkl
# 131b_V-SortOverall-4.pkl
# 23a_H-SortOverall-21.pkl
# 140b_H-SortOverall-24.pkl
# 1a_H-CDV-22.pkl
# 81a_H-SortOverall-6.pkl
# 104b_H-SortTwoFactors-14.pkl
# 114b_H-SortOverall-3.pkl
# 25b_V-RV-10.pkl
# 84b_H-FE-8.pkl
# 50a_V-RV-6.pkl
# 100a_V-RV-2.pkl
# 103a_H-SortOverall-4.pkl
# 13a_H-SortTwoFactors-3.pkl
# 139b_V-CDV-20.pkl
# 126a_V-SortOverall-3.pkl
# 58a_V-CDV-15.pkl
# 25b_V-FE-21.pkl
# 127a_H-RV-5.pkl
# 106b_H-SortTwoFactors-23.pkl
# 12b_H-FE-21.pkl
# 96a_V-SortOverall-2.pkl
# 90a_H-RV-14.pkl
# 15b_V-RV-15.pkl
# 149a_H-FE-20.pkl
# 46a_V-SortOverall-8.pkl
# 145a_H-FE-3.pkl
# 63b_V-CDV-4.pkl
# 133b_V-SortTwoFactors-24.pkl
# 3a_H-SortOverall-6.pkl
# 54b_H-SortTwoFactors-10.pkl
# 139b_V-SortTwoFactors-10.pkl
# 64b_H-FE-22.pkl
# 105a_H-SortTwoFactors-16.pkl
# 111a_H-CDV-23.pkl
# 67a_H-CDV-22.pkl
# 123b_V-SortTwoFactors-3.pkl
# 21b_V-FE-15.pkl
# 77b_V-RV-10.pkl
# 40b_H-RV-10.pkl
# 45a_H-FE-8.pkl
# 65b_V-SortTwoFactors-16.pkl
# 130b_H-FE-8.pkl
# 37b_V-FE-20.pkl
# 38a_V-RV-22.pkl
# 75b_V-RV-23.pkl
# 84b_H-CDV-15.pkl
# 96a_V-CDV-4.pkl
# 93b_H-FE-3.pkl
# 47a_H-SortTwoFactors-14.pkl
# 27a_H-FE-6.pkl
# 86a_V-RV-18.pkl
# 45b_V-FE-17.pkl
# 92a_H-CDV-9.pkl
# 84a_V-FE-2.pkl
# 9a_H-SortOverall-5.pkl
# 150a_V-SortTwoFactors-24.pkl
# 126b_H-CDV-6.pkl
# 91b_H-CDV-22.pkl
# 1a_H-FE-6.pkl
# 112b_H-FE-14.pkl
# 106b_H-FE-12.pkl
# 30b_H-CDV-6.pkl
# 65b_V-RV-11.pkl
# 75a_H-CDV-11.pkl
# 29a_H-SortTwoFactors-4.pkl
# 46b_H-SortTwoFactors-16.pkl
# 9a_H-FE-11.pkl
# 116b_H-CDV-3.pkl
# 140b_H-FE-8.pkl
# 35a_H-FE-8.pkl
# 144a_V-SortOverall-9.pkl
# 10b_H-RV-23.pkl
# 70a_V-SortTwoFactors-24.pkl
# 129a_H-CDV-9.pkl
# 65b_V-RV-5.pkl
# 55b_V-RV-14.pkl
# 34b_H-FE-11.pkl
# 64a_V-SortTwoFactors-14.pkl
# 58b_H-SortTwoFactors-12.pkl
# 49a_H-RV-18.pkl
# 54b_H-SortOverall-21.pkl
# 90a_H-CDV-24.pkl
# 46a_V-SortOverall-20.pkl
# 22b_H-SortTwoFactors-22.pkl
# 142b_H-SortOverall-23.pkl
# 128a_V-SortTwoFactors-23.pkl
# 132b_H-SortOverall-20.pkl
# 28b_H-SortTwoFactors-16.pkl
# 130a_V-SortTwoFactors-4.pkl
# 36a_V-SortOverall-23.pkl
# 14b_H-RV-17.pkl
# 23b_V-RV-17.pkl
# 148a_V-FE-22.pkl
# 132b_H-FE-23.pkl
# 6b_H-SortTwoFactors-23.pkl
# 100b_H-SortOverall-22.pkl
# 57b_V-SortOverall-23.pkl
# 132a_V-RV-3.pkl
# 23a_H-RV-2.pkl
# 103b_V-SortTwoFactors-11.pkl
# 26a_V-SortOverall-8.pkl
# 72a_V-FE-12.pkl
# 141b_V-CDV-14.pkl
# 9a_H-CDV-15.pkl
# 126a_V-RV-11.pkl
# 23a_H-FE-23.pkl
# 141a_H-CDV-21.pkl
# 14a_V-FE-23.pkl
# 146b_H-SortTwoFactors-12.pkl
# 130a_V-CDV-11.pkl
# 46a_V-CDV-10.pkl
# 25a_H-SortTwoFactors-4.pkl
# 20a_V-RV-23.pkl
# 79b_V-RV-24.pkl
# 45b_V-CDV-21.pkl
# 26a_V-RV-3.pkl
# 56a_V-SortOverall-20.pkl
# 22b_H-CDV-23.pkl
# 90a_H-RV-5.pkl
# 144b_H-FE-4.pkl
# 114a_V-RV-9.pkl
# 21a_H-CDV-12.pkl
# 16a_V-FE-3.pkl
# 110b_H-SortOverall-22.pkl
# 47b_V-CDV-16.pkl
# 126a_V-FE-20.pkl
# 41a_H-CDV-5.pkl
# 15a_H-SortTwoFactors-23.pkl
# 55a_H-CDV-3.pkl
# 111a_H-RV-8.pkl
# 146b_H-SortTwoFactors-3.pkl
# 8a_V-SortOverall-12.pkl
# 130b_H-SortOverall-2.pkl
# 129b_V-RV-22.pkl
# 25a_H-SortOverall-21.pkl
# 14b_H-SortOverall-8.pkl
# 7b_V-SortTwoFactors-10.pkl
# 131a_H-CDV-8.pkl
# 83b_V-RV-17.pkl
# 45b_V-SortOverall-24.pkl
# 142a_V-FE-22.pkl
# 145a_H-CDV-20.pkl
# 50a_V-FE-16.pkl
# 74a_V-RV-18.pkl
# 121b_V-FE-2.pkl
# 106b_H-FE-5.pkl
# 29b_V-CDV-5.pkl
# 83b_V-CDV-5.pkl
# 143b_V-RV-4.pkl
# 36a_V-RV-4.pkl
# 133a_H-SortTwoFactors-15.pkl
# 137b_V-CDV-21.pkl
# 58b_H-FE-20.pkl
# 85a_H-SortOverall-21.pkl
# 54a_V-SortTwoFactors-21.pkl
# 107a_H-SortOverall-2.pkl
# 143a_H-SortOverall-3.pkl
# 26a_V-CDV-17.pkl
# 126b_H-SortTwoFactors-9.pkl
# 16b_H-SortTwoFactors-8.pkl
# 104a_V-FE-24.pkl
# 61a_V-SortOverall-4.pkl
# 148b_H-FE-2.pkl
# 7a_H-CDV-6.pkl
# 26a_V-RV-18.pkl
# 138a_V-SortTwoFactors-3.pkl
# 11a_H-RV-24.pkl
# 26a_V-SortTwoFactors-12.pkl
# 133b_V-RV-4.pkl
# 72b_H-SortTwoFactors-5.pkl
# 103a_H-CDV-2.pkl
# 7b_V-SortOverall-3.pkl
# 70a_V-FE-20.pkl
# 142b_H-SortTwoFactors-5.pkl
# 131b_V-SortTwoFactors-9.pkl
# 142a_V-RV-12.pkl
# 77a_H-SortTwoFactors-20.pkl
# 114a_V-FE-17.pkl
# 122b_H-CDV-16.pkl
# 35a_H-FE-17.pkl
# 122a_V-CDV-23.pkl
# 54a_V-CDV-22.pkl
# 2a_V-FE-3.pkl
# 141a_H-FE-12.pkl
# 150a_V-CDV-17.pkl
# 3a_H-RV-21.pkl
# 26b_H-CDV-23.pkl
# 13b_V-FE-9.pkl
# 141a_H-RV-6.pkl
# 56a_V-SortTwoFactors-17.pkl
# 64a_V-RV-3.pkl
# 56a_V-CDV-15.pkl
# 8b_H-CDV-8.pkl
# 104a_V-RV-14.pkl
# 56b_H-CDV-20.pkl
# 110a_V-RV-12.pkl
# 11a_H-RV-2.pkl
# 3b_V-SortTwoFactors-10.pkl
# 128a_V-RV-6.pkl
# 146a_V-FE-17.pkl
# 142a_V-SortOverall-24.pkl
# 47a_H-CDV-3.pkl
# 12a_V-RV-14.pkl
# 111b_V-SortTwoFactors-16.pkl
# 64a_V-CDV-5.pkl
# 123a_H-CDV-10.pkl
# 11a_H-SortTwoFactors-23.pkl
# 111a_H-SortTwoFactors-3.pkl
# 39b_V-RV-18.pkl
# 54a_V-FE-3.pkl
# 145a_H-RV-17.pkl
# 25b_V-SortOverall-6.pkl
# 10b_H-SortOverall-21.pkl
# 26b_H-RV-8.pkl
# 111b_V-SortTwoFactors-2.pkl
# 130a_V-FE-14.pkl
# 138a_V-SortOverall-23.pkl
# 130b_H-SortTwoFactors-21.pkl
# 107a_H-FE-14.pkl
# 25a_H-CDV-6.pkl
# 24a_V-SortTwoFactors-24.pkl
# 29b_V-RV-16.pkl
# 112a_V-SortTwoFactors-23.pkl
# 129b_V-SortOverall-20.pkl
# 116a_V-FE-9.pkl
# 132b_H-CDV-12.pkl
# 96b_H-SortOverall-24.pkl
# 148a_V-FE-9.pkl
# 39a_H-SortTwoFactors-6.pkl
# 50b_H-CDV-16.pkl
# 94a_H-SortOverall-12.pkl
# 38b_H-FE-17.pkl
# 37a_H-RV-15.pkl
# 14a_V-SortOverall-20.pkl
# 82b_H-SortOverall-23.pkl
# 64a_V-SortOverall-4.pkl
# 46a_V-FE-22.pkl
# 31a_H-FE-5.pkl
# 146a_V-SortTwoFactors-3.pkl
# 74a_V-RV-4.pkl
# 143a_H-CDV-17.pkl
# 121a_H-SortOverall-8.pkl
# 116a_V-SortTwoFactors-22.pkl
# 35b_V-CDV-23.pkl
# 29b_V-SortOverall-22.pkl
# 38b_H-FE-8.pkl
# 109b_V-SortTwoFactors-6.pkl
# 32b_H-SortTwoFactors-5.pkl
# 112a_V-FE-10.pkl
# 125a_H-FE-10.pkl
# 111a_H-CDV-2.pkl
# 126a_V-CDV-2.pkl
# 46b_H-CDV-24.pkl
# 58a_V-FE-5.pkl
# 143a_H-FE-21.pkl
# 28b_H-RV-14.pkl
# 13a_H-CDV-4.pkl
# 87a_V-SortTwoFactors-15.pkl
# 132a_V-RV-16.pkl
# 127a_H-SortOverall-4.pkl
# 2a_V-FE-12.pkl
# 109b_V-SortTwoFactors-24.pkl
# 64b_H-SortTwoFactors-24.pkl
# 127b_V-SortOverall-5.pkl
# 152b_H-SortTwoFactors-21.pkl
# 79b_V-CDV-9.pkl
# 140a_V-RV-23.pkl
# 82b_H-CDV-4.pkl
# 121a_H-SortTwoFactors-10.pkl
# 36b_H-FE-5.pkl
# 143a_H-FE-5.pkl
# 56a_V-RV-23.pkl
# 37a_H-CDV-23.pkl
# 109b_V-CDV-4.pkl
# 113a_H-SortOverall-9.pkl
# 36a_V-SortTwoFactors-20.pkl
# 46a_V-RV-11.pkl
# 144b_H-SortTwoFactors-8.pkl
# 85a_H-RV-4.pkl
# 1a_H-RV-10.pkl
# 133a_H-CDV-16.pkl
# 45b_V-SortTwoFactors-11.pkl
# 7b_V-RV-2.pkl
# 20a_V-FE-11.pkl
# 122b_H-SortOverall-23.pkl
# 35a_H-CDV-14.pkl
# 38a_V-SortOverall-23.pkl
# 140a_V-CDV-11.pkl
# 47a_H-CDV-20.pkl
# 2a_V-RV-21.pkl
# 72b_H-SortTwoFactors-21.pkl
# 148b_H-FE-24.pkl
# 72a_V-RV-20.pkl
# 1a_H-SortOverall-17.pkl
# 67a_H-SortOverall-23.pkl
# 8b_H-RV-24.pkl
# 146b_H-RV-6.pkl
# 133a_H-SortTwoFactors-2.pkl
# 14b_H-SortTwoFactors-3.pkl
# 126a_V-SortOverall-22.pkl
# 131a_H-RV-4.pkl
# 123a_H-RV-24.pkl
# 26a_V-FE-16.pkl
# 104a_V-CDV-4.pkl
# 8b_H-RV-18.pkl
# 9a_H-SortOverall-14.pkl
# 149b_V-CDV-5.pkl
# 127a_H-CDV-2.pkl
# 44b_H-SortOverall-2.pkl
# 114a_V-SortOverall-20.pkl
# 123a_H-RV-18.pkl
# 92b_V-SortOverall-5.pkl
# 114a_V-RV-18.pkl
# 93b_H-RV-23.pkl
# 54a_V-SortOverall-24.pkl
# 113a_H-FE-10.pkl
# 72a_V-SortOverall-21.pkl
# 54a_V-RV-9.pkl
# 21b_V-SortOverall-23.pkl
# 87b_H-SortTwoFactors-2.pkl
# 65a_H-SortOverall-24.pkl
# 109a_H-SortOverall-21.pkl
# 15a_H-FE-22.pkl
# 40a_V-SortOverall-23.pkl
# 144b_H-SortOverall-20.pkl
# 81a_H-SortTwoFactors-8.pkl
# 30a_V-SortOverall-20.pkl
# 54a_V-CDV-2.pkl
# 131a_H-SortTwoFactors-21.pkl
# 28b_H-RV-5.pkl
# 19b_V-CDV-3.pkl
# 7a_H-SortTwoFactors-8.pkl
# 50a_V-RV-18.pkl
# 67a_H-RV-18.pkl
# 142a_V-CDV-2.pkl
# 107a_H-CDV-9.pkl
# 146a_V-RV-18.pkl
# 47a_H-SortTwoFactors-5.pkl
# 23b_V-SortTwoFactors-9.pkl
# 54b_H-CDV-15.pkl
# 50a_V-SortTwoFactors-4.pkl
# 144a_V-RV-5.pkl
# 65a_H-SortTwoFactors-6.pkl
# 57b_V-CDV-11.pkl
# 95a_H-SortTwoFactors-21.pkl
# 110a_V-SortTwoFactors-16.pkl
# 46a_V-RV-6.pkl
# 62b_V-SortTwoFactors-21.pkl
# 121a_H-CDV-24.pkl
# 83b_V-FE-24.pkl
# 29b_V-FE-24.pkl
# 113a_H-SortTwoFactors-8.pkl
# 2a_V-SortTwoFactors-11.pkl
# 113a_H-RV-20.pkl
# 16a_V-FE-12.pkl
# 32a_V-SortTwoFactors-20.pkl
# 7a_H-SortOverall-2.pkl
# 132b_H-SortTwoFactors-15.pkl
# 38a_V-SortTwoFactors-14.pkl
# 84b_H-RV-10.pkl
# 36a_V-CDV-6.pkl
# 104a_V-SortTwoFactors-9.pkl
# 118a_V-FE-5.pkl
# 25a_H-CDV-11.pkl
# 50b_H-SortTwoFactors-4.pkl
# 144b_H-CDV-24.pkl
# 32a_V-CDV-10.pkl
# 8b_H-SortOverall-2.pkl
# 13a_H-SortTwoFactors-17.pkl
# 31a_H-CDV-14.pkl
# 63a_H-CDV-3.pkl
# 72a_V-SortTwoFactors-6.pkl
# 111b_V-FE-8.pkl
# 15a_H-RV-12.pkl
# 149a_H-SortTwoFactors-5.pkl
# 11a_H-FE-9.pkl
# 127a_H-RV-11.pkl
# 145a_H-CDV-6.pkl
# 28b_H-SortOverall-24.pkl
# 133a_H-RV-17.pkl
# 48a_V-RV-9.pkl
# 110a_V-SortOverall-4.pkl
# 87b_H-SortOverall-15.pkl
# 23b_V-FE-2.pkl
# 87b_H-RV-24.pkl
# 4a_V-CDV-9.pkl
# 133a_H-CDV-5.pkl
# 84b_H-FE-21.pkl
# 148a_V-SortOverall-23.pkl
# 145b_V-CDV-17.pkl
# 87b_H-RV-18.pkl
# 149b_V-SortTwoFactors-4.pkl
# 11a_H-FE-17.pkl
# 12b_H-SortTwoFactors-15.pkl
# 30b_H-CDV-12.pkl
# 47a_H-RV-12.pkl
# 18b_H-SortTwoFactors-21.pkl
# 12a_V-CDV-5.pkl
# 56a_V-FE-9.pkl
# 125b_V-CDV-10.pkl
# 130a_V-SortOverall-23.pkl
# 45a_H-RV-21.pkl
# 37b_V-SortTwoFactors-23.pkl
# 140a_V-SortOverall-20.pkl
# 131a_H-CDV-20.pkl
# 55a_H-SortOverall-20.pkl
# 14a_V-RV-10.pkl
# 129a_H-SortTwoFactors-12.pkl
# 14a_V-SortOverall-9.pkl
# 97a_H-FE-3.pkl
# 47b_V-SortOverall-21.pkl
# 48a_V-SortOverall-21.pkl
# 122a_V-FE-16.pkl
# 106a_V-RV-18.pkl
# 16b_H-SortTwoFactors-14.pkl
# 38b_H-RV-3.pkl
# 150a_V-FE-21.pkl
# 92b_V-FE-11.pkl
# 64b_H-SortOverall-4.pkl
# 27a_H-RV-18.pkl
# 131a_H-RV-24.pkl
# 10a_V-RV-18.pkl
# 62b_V-SortOverall-9.pkl
# 26a_V-SortOverall-21.pkl
# 150a_V-RV-10.pkl
# 128a_V-SortOverall-4.pkl
# 99a_H-RV-4.pkl
# 149a_H-SortOverall-2.pkl
# 26a_V-FE-9.pkl
# 144a_V-RV-16.pkl
# 148b_H-CDV-6.pkl
# 122b_H-SortTwoFactors-24.pkl
# 138a_V-RV-2.pkl
# 85a_H-SortTwoFactors-11.pkl
# 87a_V-RV-8.pkl
# 96b_H-RV-11.pkl
# 63a_H-SortTwoFactors-8.pkl
# 139b_V-FE-23.pkl
# 10a_V-FE-15.pkl
# 41a_H-FE-6.pkl
# 144a_V-CDV-4.pkl
# 11b_V-FE-3.pkl
# 150a_V-CDV-2.pkl
# 105a_H-RV-15.pkl
# 129b_V-FE-11.pkl
# 26b_H-SortOverall-9.pkl
# 65a_H-CDV-4.pkl
# 106a_V-RV-5.pkl
# 35b_V-SortTwoFactors-14.pkl
# 142b_H-CDV-12.pkl
# 8b_H-SortTwoFactors-9.pkl
# 121a_H-SortTwoFactors-15.pkl
# 36b_H-RV-8.pkl
# 143a_H-RV-8.pkl
# 142b_H-CDV-16.pkl
# 95b_V-FE-15.pkl
# 32a_V-SortTwoFactors-3.pkl
# 142a_V-CDV-23.pkl
# 30a_V-RV-17.pkl
# 103b_V-SortTwoFactors-17.pkl
# 86b_H-SortTwoFactors-20.pkl
# 37a_H-SortOverall-6.pkl
# 92b_V-RV-24.pkl
# 2a_V-SortOverall-6.pkl
# 131a_H-FE-11.pkl
# 114a_V-SortTwoFactors-12.pkl
# 22a_V-SortTwoFactors-15.pkl
# 105a_H-CDV-3.pkl
# 150a_V-RV-14.pkl
# 131b_V-FE-3.pkl
# 87a_V-FE-4.pkl
# 127a_H-CDV-16.pkl
# 56a_V-CDV-8.pkl
# 67a_H-SortTwoFactors-16.pkl
# 1b_V-SortTwoFactors-3.pkl
# 100a_V-SortTwoFactors-22.pkl
# 116b_H-FE-4.pkl
# 20a_V-SortOverall-2.pkl
# 28b_H-FE-22.pkl
# 92b_V-SortTwoFactors-20.pkl
# 64a_V-SortOverall-24.pkl
# 8b_H-CDV-15.pkl
# 50b_H-SortOverall-20.pkl
# 145b_V-SortOverall-20.pkl
# 106a_V-RV-20.pkl
# 4b_H-SortOverall-16.pkl
# 47b_V-SortTwoFactors-23.pkl
# 89a_V-RV-11.pkl
# 18b_H-RV-16.pkl
# 144a_V-FE-23.pkl
# 70a_V-SortOverall-23.pkl
# 129b_V-RV-18.pkl
# 56a_V-RV-5.pkl
# 104b_H-SortOverall-23.pkl
# 2a_V-RV-18.pkl
# 24a_V-FE-20.pkl
# 104b_H-RV-2.pkl
# 95b_V-RV-18.pkl
# 50a_V-CDV-24.pkl
# 123a_H-SortTwoFactors-22.pkl
# 99b_V-FE-2.pkl
# 92a_H-FE-2.pkl
# 106a_V-SortTwoFactors-14.pkl
# 77b_V-SortOverall-20.pkl
# 57b_V-SortTwoFactors-12.pkl
# 145a_H-SortOverall-9.pkl
# 21b_V-SortTwoFactors-4.pkl
# 85b_V-FE-3.pkl
# 149a_H-SortTwoFactors-23.pkl
# 63b_V-RV-6.pkl
# 22b_H-SortOverall-24.pkl
# 131a_H-SortOverall-22.pkl
# 14a_V-RV-4.pkl
# 25a_H-SortOverall-2.pkl
# 110b_H-SortOverall-3.pkl
# 141a_H-RV-18.pkl
# 18b_H-CDV-20.pkl
# 57a_H-RV-24.pkl
# 74a_V-RV-22.pkl
# 40a_V-SortTwoFactors-17.pkl
# 48a_V-FE-5.pkl
# 106b_H-SortTwoFactors-4.pkl
# 73a_H-FE-16.pkl
# 36b_H-SortOverall-23.pkl
# 127a_H-SortTwoFactors-23.pkl
# 123a_H-CDV-17.pkl
# 21a_H-SortTwoFactors-5.pkl
# 106b_H-SortOverall-24.pkl
# 67a_H-RV-21.pkl
# 143b_V-SortOverall-6.pkl
# 71b_V-RV-8.pkl
# 110a_V-FE-24.pkl
# 149b_V-FE-23.pkl
# 109b_V-CDV-23.pkl
# 79a_H-SortOverall-4.pkl
# 83b_V-SortTwoFactors-4.pkl
# 65b_V-SortTwoFactors-2.pkl
# 56a_V-SortTwoFactors-10.pkl
# 114b_H-RV-5.pkl
# 126b_H-SortTwoFactors-21.pkl
# 17b_V-SortOverall-2.pkl
# 144a_V-FE-8.pkl
# 7a_H-RV-12.pkl
# 40a_V-CDV-20.pkl
# 113a_H-RV-18.pkl
# 8a_V-SortTwoFactors-21.pkl
# 7a_H-FE-5.pkl
# 21a_H-FE-16.pkl
# 55b_V-SortTwoFactors-24.pkl
# 93b_H-FE-16.pkl
# 90b_V-RV-8.pkl
# 16a_V-FE-17.pkl
# 26a_V-RV-23.pkl
# 123a_H-FE-11.pkl
# 16b_H-RV-6.pkl
# 26a_V-SortTwoFactors-15.pkl
# 137a_H-FE-17.pkl
# 100a_V-FE-17.pkl
# 142a_V-RV-14.pkl
# 32b_H-SortOverall-4.pkl
# 121b_V-CDV-14.pkl
# 111b_V-RV-5.pkl
# 26a_V-CDV-10.pkl
# 15a_H-RV-17.pkl
# 122a_V-SortOverall-2.pkl
# 133a_H-FE-23.pkl
# 25a_H-CDV-14.pkl
# 144a_V-CDV-14.pkl
# 32b_H-CDV-20.pkl
# 90a_H-SortTwoFactors-6.pkl
# 111b_V-SortTwoFactors-10.pkl
# 46b_H-SortOverall-21.pkl
# 100a_V-CDV-8.pkl
# 57a_H-SortOverall-22.pkl
# 113a_H-RV-6.pkl
# 9a_H-RV-3.pkl
# 32a_V-FE-14.pkl
# 7a_H-FE-22.pkl
# 141a_H-SortOverall-20.pkl
# 103a_H-SortOverall-21.pkl
# 150b_H-SortOverall-23.pkl
# 103b_V-FE-3.pkl
# 86a_V-SortOverall-24.pkl
# 77a_H-FE-23.pkl
# 9a_H-SortOverall-10.pkl
# 13a_H-FE-5.pkl
# 14a_V-RV-15.pkl
# 47b_V-CDV-11.pkl
# 85b_V-CDV-5.pkl
# 45a_H-RV-18.pkl
# 126a_V-CDV-24.pkl
# 141b_V-FE-2.pkl
# 56a_V-FE-16.pkl
# 72a_V-RV-18.pkl
# 75b_V-SortOverall-9.pkl
# 21b_V-RV-6.pkl
# 82b_H-RV-2.pkl
# 143a_H-CDV-4.pkl
# 112a_V-CDV-9.pkl
# 4b_H-SortOverall-8.pkl
# 55a_H-RV-16.pkl
# 92b_V-FE-14.pkl
# 143a_H-RV-16.pkl
# 140b_H-CDV-20.pkl
# 139b_V-RV-17.pkl
# 133a_H-SortOverall-24.pkl
# 95b_V-SortOverall-20.pkl
# 65a_H-FE-22.pkl
# 133a_H-RV-9.pkl
# 65a_H-SortTwoFactors-20.pkl
# 4a_V-SortTwoFactors-22.pkl
# 21b_V-CDV-20.pkl
# 130b_H-CDV-23.pkl
# 96b_H-RV-14.pkl
# 20a_V-RV-18.pkl
# 12b_H-SortOverall-3.pkl
# 48a_V-SortTwoFactors-4.pkl
# 132a_V-CDV-2.pkl
# 45b_V-SortTwoFactors-15.pkl
# 121a_H-FE-22.pkl
# 13a_H-RV-10.pkl
# 35b_V-SortTwoFactors-11.pkl
# 106a_V-FE-8.pkl
# 25b_V-SortTwoFactors-2.pkl
# 37a_H-FE-22.pkl
# 21b_V-SortTwoFactors-21.pkl
# 1a_H-SortTwoFactors-3.pkl
# 134b_H-FE-3.pkl
# 126a_V-RV-14.pkl
# 146a_V-SortOverall-6.pkl
# 118a_V-CDV-22.pkl
# 20a_V-CDV-24.pkl
# 1a_H-CDV-4.pkl
# 75a_H-RV-23.pkl
# 146b_H-SortTwoFactors-17.pkl
# 28b_H-CDV-2.pkl
# 38b_H-SortOverall-5.pkl
# 121a_H-RV-5.pkl
# 72a_V-FE-17.pkl
# 34b_H-CDV-14.pkl
# 145a_H-SortTwoFactors-22.pkl
# 103a_H-RV-3.pkl
# 112a_V-FE-14.pkl
# 10a_V-SortTwoFactors-3.pkl
# 2b_H-SortOverall-6.pkl
# 146a_V-FE-2.pkl
# 149b_V-SortOverall-6.pkl
# 129b_V-SortTwoFactors-9.pkl
# 90b_V-SortTwoFactors-14.pkl
# 82b_H-FE-21.pkl
# 121a_H-CDV-3.pkl
# 8a_V-CDV-23.pkl
# 133a_H-FE-3.pkl
# 91b_H-SortOverall-12.pkl
# 21a_H-CDV-17.pkl
# 14a_V-CDV-5.pkl
# 23a_H-CDV-5.pkl
# 37a_H-CDV-3.pkl
# 54b_H-SortTwoFactors-4.pkl
# 20a_V-SortTwoFactors-21.pkl
# 12b_H-SortOverall-22.pkl
# 35a_H-CDV-12.pkl
# 13a_H-FE-23.pkl
# 125b_V-CDV-17.pkl
# 2b_H-RV-5.pkl
# 137a_H-SortTwoFactors-11.pkl
# 109a_H-SortTwoFactors-3.pkl
# 66a_V-RV-20.pkl
# 104b_H-FE-9.pkl
# 7b_V-SortTwoFactors-15.pkl
# 32a_V-SortOverall-21.pkl
# 105a_H-FE-23.pkl
# 23a_H-RV-17.pkl
# 141b_V-RV-8.pkl
# 11b_V-SortOverall-20.pkl
# 7b_V-SortOverall-17.pkl
# 8a_V-SortOverall-17.pkl
# 64b_H-FE-5.pkl
# 111a_H-FE-5.pkl
# 87a_V-SortTwoFactors-5.pkl
# 21a_H-RV-24.pkl
# 100a_V-RV-18.pkl
# 106a_V-SortTwoFactors-6.pkl
# 137a_H-RV-18.pkl
# 146a_V-CDV-21.pkl
# 143a_H-SortTwoFactors-14.pkl
# 35b_V-SortOverall-22.pkl
# 146b_H-CDV-14.pkl
# 12b_H-SortTwoFactors-12.pkl
# 21a_H-RV-18.pkl
# 112b_H-SortOverall-20.pkl
# 95a_H-RV-5.pkl
# 70a_V-SortOverall-8.pkl
# 85a_H-SortOverall-5.pkl
# 133b_V-SortTwoFactors-5.pkl
# 3a_H-FE-14.pkl
# 27a_H-SortOverall-23.pkl
# 36a_V-FE-22.pkl
# 87b_H-SortOverall-12.pkl
# 83b_V-SortOverall-22.pkl
# 111b_V-SortOverall-22.pkl
# 3a_H-SortOverall-16.pkl
# 15a_H-SortOverall-21.pkl
# 25a_H-RV-10.pkl
# 96b_H-SortTwoFactors-12.pkl
# 148b_H-SortTwoFactors-22.pkl
# 21a_H-FE-6.pkl
# 4a_V-FE-11.pkl
# 104a_V-FE-3.pkl
# 8a_V-SortOverall-6.pkl
# 34b_H-RV-2.pkl
# 74a_V-FE-10.pkl
# 146a_V-RV-22.pkl
# 58b_H-RV-14.pkl
# 84b_H-CDV-5.pkl
# 47a_H-FE-24.pkl
# 57b_V-CDV-17.pkl
# 130a_V-RV-21.pkl
# 47b_V-SortTwoFactors-2.pkl
# 77a_H-RV-10.pkl
# 40a_V-RV-10.pkl
# 17a_H-SortOverall-2.pkl
# 54a_V-RV-16.pkl
# 84b_H-RV-17.pkl
# 145a_H-FE-23.pkl
# 15a_H-CDV-6.pkl
# 126a_V-FE-4.pkl
# 32a_V-SortOverall-4.pkl
# 104a_V-SortTwoFactors-21.pkl
# 81a_H-SortTwoFactors-16.pkl
# 31b_V-RV-2.pkl
# 8b_H-FE-12.pkl
# 10b_H-SortTwoFactors-24.pkl
# 133b_V-FE-8.pkl
# 40b_H-CDV-17.pkl
# 36a_V-RV-12.pkl
# 150a_V-CDV-12.pkl
# 77a_H-CDV-3.pkl
# 57a_H-FE-17.pkl
# 1b_V-SortTwoFactors-22.pkl
# 31a_H-CDV-12.pkl
# 25a_H-FE-20.pkl
# 3a_H-RV-18.pkl
# 103a_H-RV-14.pkl
# 25b_V-SortTwoFactors-23.pkl
# 122b_H-SortOverall-2.pkl
# 70a_V-CDV-6.pkl
# 4a_V-RV-21.pkl
# 3b_V-SortTwoFactors-15.pkl
# 70b_H-SortTwoFactors-9.pkl
# 67a_H-SortTwoFactors-9.pkl
# 104a_V-RV-11.pkl
# 137a_H-CDV-10.pkl
# 58b_H-SortOverall-21.pkl
# 16a_V-SortOverall-22.pkl
# 27a_H-CDV-20.pkl
# 57a_H-CDV-8.pkl
# 30a_V-CDV-21.pkl
# 114a_V-RV-23.pkl
# 105b_V-SortOverall-24.pkl
# 146b_H-FE-9.pkl
# 93b_H-RV-18.pkl
# 83a_H-SortTwoFactors-21.pkl
# 61a_V-SortTwoFactors-2.pkl
# 107a_H-FE-11.pkl
# 141a_H-CDV-8.pkl
# 129a_H-SortTwoFactors-14.pkl
# 126b_H-CDV-12.pkl
# 23b_V-SortTwoFactors-15.pkl
# 29b_V-SortTwoFactors-21.pkl
# 132a_V-FE-22.pkl
# 144b_H-SortTwoFactors-21.pkl
# 148a_V-RV-4.pkl
# 139b_V-CDV-6.pkl
# 20a_V-FE-16.pkl
# 84a_V-SortOverall-20.pkl
# 95b_V-CDV-8.pkl
# 91b_H-CDV-5.pkl
# 112a_V-RV-18.pkl
# 125a_H-RV-18.pkl
# 143a_H-SortOverall-24.pkl
# 27a_H-RV-22.pkl
# 114a_V-FE-5.pkl
# 2a_V-CDV-8.pkl
# 140a_V-CDV-16.pkl
# 36a_V-CDV-17.pkl
# 37b_V-SortOverall-24.pkl
# 14b_H-FE-4.pkl
# 122a_V-RV-21.pkl
# 58a_V-RV-8.pkl
# 63a_H-FE-6.pkl
# 130a_V-CDV-15.pkl
# 94a_H-SortTwoFactors-2.pkl
# 133a_H-CDV-11.pkl
# 61a_V-RV-3.pkl
# 144a_V-RV-10.pkl
# 93a_V-SortTwoFactors-20.pkl
# 56a_V-RV-18.pkl
# 46a_V-CDV-4.pkl
# 96b_H-CDV-5.pkl
# 87a_V-SortTwoFactors-10.pkl
# 38b_H-RV-23.pkl
# 10b_H-SortTwoFactors-3.pkl
# 2a_V-FE-17.pkl
# 139b_V-SortOverall-9.pkl
# 46a_V-SortTwoFactors-23.pkl
# 137a_H-SortTwoFactors-2.pkl
# 129a_H-SortTwoFactors-4.pkl
# 26b_H-SortOverall-2.pkl
# 109b_V-SortTwoFactors-10.pkl
# 111a_H-RV-18.pkl
# 74a_V-SortTwoFactors-2.pkl
# 85b_V-SortTwoFactors-4.pkl
# 13a_H-RV-22.pkl
# 144a_V-SortTwoFactors-3.pkl
# 23a_H-FE-3.pkl
# 9a_H-CDV-20.pkl
# 46a_V-SortTwoFactors-12.pkl
# 148b_H-RV-23.pkl
# 141a_H-CDV-14.pkl
# 30a_V-RV-18.pkl
# 105a_H-RV-22.pkl
# 37a_H-FE-10.pkl
# 2a_V-SortOverall-9.pkl
# 138a_V-RV-9.pkl
# 61a_V-FE-6.pkl
# 90b_V-SortTwoFactors-24.pkl
# 130b_H-CDV-11.pkl
# 139b_V-FE-14.pkl
# 82b_H-RV-20.pkl
# 65a_H-RV-21.pkl
# 14b_H-SortTwoFactors-14.pkl
# 86b_H-CDV-6.pkl
# 112a_V-FE-24.pkl
# 79b_V-RV-11.pkl
# 52b_H-CDV-15.pkl
# 75b_V-SortOverall-14.pkl
# 104b_H-SortOverall-4.pkl
# 112a_V-RV-15.pkl
# 129b_V-CDV-5.pkl
# 35b_V-CDV-17.pkl
# 116a_V-SortTwoFactors-16.pkl
# 114a_V-FE-8.pkl
# 2a_V-CDV-5.pkl
# 121b_V-SortOverall-3.pkl
# 12b_H-SortTwoFactors-6.pkl
# 140b_H-SortOverall-5.pkl
# 109b_V-FE-11.pkl
# 110b_H-SortOverall-17.pkl
# 14a_V-SortOverall-14.pkl
# 48a_V-SortOverall-16.pkl
# 100a_V-SortTwoFactors-5.pkl
# 90a_H-FE-4.pkl
# 143a_H-SortOverall-15.pkl
# 4a_V-SortTwoFactors-10.pkl
# 72a_V-CDV-4.pkl
# 65a_H-SortTwoFactors-12.pkl
# 65a_H-FE-10.pkl
# 37b_V-SortOverall-15.pkl
# 55a_H-RV-18.pkl
# 146b_H-SortOverall-11.pkl
# 100b_H-SortTwoFactors-4.pkl
# 75a_H-FE-22.pkl
# 129b_V-RV-17.pkl
# 130a_V-SortOverall-8.pkl
# 37a_H-RV-21.pkl
# 123b_V-FE-2.pkl
# 56a_V-FE-2.pkl
# 14a_V-SortOverall-2.pkl
# 4a_V-SortOverall-5.pkl
# 104b_H-SortOverall-10.pkl
# 67a_H-SortOverall-15.pkl
# 4a_V-CDV-2.pkl
# 22b_H-SortOverall-17.pkl
# 112a_V-SortTwoFactors-17.pkl
# 142a_V-FE-17.pkl
# 7a_H-FE-10.pkl
# 92a_H-RV-5.pkl
# 90b_V-SortTwoFactors-9.pkl
# 123a_H-RV-12.pkl
# 137a_H-RV-14.pkl
# 105b_V-SortOverall-15.pkl
# 84b_H-FE-16.pkl
# 133a_H-SortTwoFactors-8.pkl
# 83a_H-SortTwoFactors-10.pkl
# 40a_V-FE-11.pkl
# 114a_V-SortOverall-16.pkl
# 133b_V-SortTwoFactors-9.pkl
# 143b_V-FE-5.pkl
# 36a_V-FE-5.pkl
# 40a_V-SortTwoFactors-24.pkl
# 1a_H-SortOverall-5.pkl
# 50a_V-FE-23.pkl
# 70a_V-SortOverall-4.pkl
# 127a_H-SortTwoFactors-10.pkl
# 104a_V-RV-20.pkl
# 144b_H-SortOverall-16.pkl
# 133a_H-SortTwoFactors-20.pkl
# 1b_V-SortOverall-6.pkl
# 45b_V-SortTwoFactors-6.pkl
# 100a_V-SortOverall-11.pkl
# 58b_H-SortOverall-10.pkl
# 30a_V-SortOverall-16.pkl
# 3a_H-RV-15.pkl
# 74a_V-FE-20.pkl
# 23b_V-SortTwoFactors-3.pkl
# 21a_H-RV-2.pkl
# 94b_V-SortOverall-3.pkl
# 12a_V-FE-11.pkl
# 74b_H-SortTwoFactors-21.pkl
# 13a_H-SortTwoFactors-20.pkl
# 73a_H-RV-14.pkl
# 50a_V-RV-12.pkl
# 145a_H-FE-12.pkl
# 83b_V-SortOverall-6.pkl
# 93b_H-FE-24.pkl
# 35a_H-FE-23.pkl
# 70a_V-FE-14.pkl
# 95a_H-SortTwoFactors-17.pkl
# 113a_H-SortTwoFactors-3.pkl
# 62b_V-SortTwoFactors-16.pkl
# 7a_H-SortOverall-9.pkl
# 40a_V-CDV-12.pkl
# 7a_H-RV-20.pkl
# 19a_H-CDV-14.pkl
# 7a_H-RV-3.pkl
# 83b_V-FE-12.pkl
# 8b_H-FE-22.pkl
# 10b_H-SortTwoFactors-14.pkl
# 83a_H-SortOverall-4.pkl
# 32a_V-SortTwoFactors-16.pkl
# 54b_H-CDV-22.pkl
# 77a_H-RV-21.pkl
# 26a_V-CDV-2.pkl
# 13b_V-RV-8.pkl
# 22a_V-RV-18.pkl
# 31b_V-CDV-17.pkl
# 143b_V-SortOverall-8.pkl
# 130a_V-CDV-2.pkl
# 31a_H-CDV-22.pkl
# 2a_V-RV-2.pkl
# 113a_H-CDV-4.pkl
# 142a_V-CDV-9.pkl
# 103a_H-RV-18.pkl
# 149b_V-FE-11.pkl
# 15a_H-RV-24.pkl
# 137b_V-CDV-15.pkl
# 93b_H-CDV-6.pkl
# 87b_H-SortTwoFactors-9.pkl
# 48a_V-RV-3.pkl
# 133a_H-RV-21.pkl
# 66b_H-RV-9.pkl
# 106b_H-SortOverall-16.pkl
# 11a_H-SortOverall-3.pkl
# 11a_H-SortTwoFactors-16.pkl
# 9a_H-FE-4.pkl
# 109a_H-SortOverall-16.pkl
# 72a_V-SortOverall-16.pkl
# 142a_V-SortOverall-11.pkl
# 21a_H-RV-15.pkl
# 145b_V-SortOverall-4.pkl
# 57b_V-SortTwoFactors-20.pkl
# 70a_V-RV-18.pkl
# 145a_H-CDV-14.pkl
# 47a_H-RV-18.pkl
# 19b_V-FE-17.pkl
# 141a_H-CDV-4.pkl
# 45a_H-SortTwoFactors-6.pkl
# 12b_H-SortTwoFactors-23.pkl
# 129b_V-SortOverall-15.pkl
# 83b_V-RV-23.pkl
# 19b_V-SortOverall-12.pkl
# 112b_H-SortOverall-11.pkl
# 75a_H-SortOverall-5.pkl
# 50a_V-SortTwoFactors-14.pkl
# 29b_V-SortTwoFactors-11.pkl
# 132a_V-FE-12.pkl
# 111a_H-FE-14.pkl
# 131b_V-CDV-23.pkl
# 71a_H-FE-4.pkl
# 91b_H-CDV-9.pkl
# 14a_V-CDV-8.pkl
# 139b_V-RV-24.pkl
# 18b_H-RV-18.pkl
# 92b_V-SortTwoFactors-12.pkl
# 28b_H-FE-10.pkl
# 7b_V-RV-9.pkl
# 47b_V-SortOverall-17.pkl
# 122a_V-FE-20.pkl
# 133a_H-RV-6.pkl
# 122b_H-SortTwoFactors-6.pkl
# 139b_V-RV-18.pkl
# 22a_V-CDV-22.pkl
# 143b_V-CDV-17.pkl
# 29b_V-SortOverall-17.pkl
# 1a_H-FE-16.pkl
# 106a_V-RV-12.pkl
# 143a_H-CDV-22.pkl
# 113a_H-SortOverall-2.pkl
# 109b_V-RV-21.pkl
# 144b_H-SortTwoFactors-3.pkl
# 144a_V-RV-20.pkl
# 56a_V-CDV-6.pkl
# 131a_H-FE-23.pkl
# 122b_H-SortTwoFactors-12.pkl
# 58a_V-RV-4.pkl
# 63a_H-RV-2.pkl
# 46b_H-CDV-11.pkl
# 132a_V-RV-23.pkl
# 56a_V-RV-14.pkl
# 63b_V-SortTwoFactors-3.pkl
# 139b_V-SortOverall-5.pkl
# 95b_V-RV-2.pkl
# 47b_V-SortOverall-5.pkl
# 140a_V-RV-14.pkl
# 118a_V-CDV-11.pkl
# 47a_H-SortOverall-4.pkl
# 37a_H-CDV-16.pkl
# 146b_H-SortTwoFactors-24.pkl
# 92b_V-CDV-6.pkl
# 111a_H-CDV-9.pkl
# 150a_V-RV-18.pkl
# 86a_V-SortOverall-6.pkl
# 28b_H-RV-23.pkl
# 92b_V-FE-4.pkl
# 10a_V-FE-21.pkl
# 27a_H-FE-21.pkl
# 114a_V-SortTwoFactors-22.pkl
# 18b_H-FE-17.pkl
# 2b_H-SortOverall-9.pkl
# 85a_H-SortTwoFactors-6.pkl
# 20a_V-RV-15.pkl
# 146a_V-RV-5.pkl
# 31a_H-RV-6.pkl
# 140a_V-CDV-24.pkl
# 38a_V-SortOverall-16.pkl
# 50b_H-SortOverall-10.pkl
# 2a_V-SortOverall-20.pkl
# 10a_V-RV-10.pkl
# 126a_V-FE-16.pkl
# 148a_V-FE-2.pkl
# 143a_H-CDV-9.pkl
# 50b_H-SortOverall-3.pkl
# 2b_H-FE-2.pkl
# 126a_V-CDV-15.pkl
# 13a_H-FE-8.pkl
# 12a_V-SortTwoFactors-4.pkl
# 14a_V-RV-18.pkl
# 64b_H-RV-2.pkl
# 132a_V-CDV-10.pkl
# 45a_H-RV-15.pkl
# 95b_V-RV-14.pkl
# 106a_V-SortTwoFactors-9.pkl
# 146a_V-CDV-12.pkl
# 103b_V-RV-6.pkl
# 126a_V-SortOverall-17.pkl
# 64a_V-RV-20.pkl
# 27a_H-CDV-12.pkl
# 150b_H-SortOverall-12.pkl
# 87b_H-RV-10.pkl
# 9a_H-SortOverall-21.pkl
# 67b_V-SortTwoFactors-6.pkl
# 54a_V-FE-14.pkl
# 123a_H-CDV-3.pkl
# 65a_H-SortOverall-11.pkl
# 140b_H-SortTwoFactors-12.pkl
# 95a_H-FE-2.pkl
# 21b_V-SortOverall-16.pkl
# 140b_H-SortTwoFactors-6.pkl
# 111b_V-SortOverall-11.pkl
# 57a_H-RV-14.pkl
# 34b_H-SortOverall-5.pkl
# 146a_V-FE-20.pkl
# 121b_V-FE-8.pkl
# 58b_H-FE-16.pkl
# 36a_V-FE-11.pkl
# 85a_H-SortOverall-17.pkl
# 54a_V-SortTwoFactors-17.pkl
# 56b_H-CDV-17.pkl
# 146a_V-RV-11.pkl
# 110a_V-FE-14.pkl
# 150a_V-CDV-20.pkl
# 127a_H-FE-14.pkl
# 133a_H-FE-12.pkl
# 21a_H-FE-9.pkl
# 28b_H-FE-4.pkl
# 64a_V-RV-8.pkl
# 107a_H-SortOverall-8.pkl
# 96b_H-SortTwoFactors-21.pkl
# 141a_H-FE-5.pkl
# 48a_V-SortTwoFactors-24.pkl
# 83b_V-SortTwoFactors-8.pkl
# 81a_H-SortTwoFactors-24.pkl
# 107a_H-RV-12.pkl
# 32b_H-SortOverall-9.pkl
# 133b_V-FE-6.pkl
# 123a_H-FE-20.pkl
# 11a_H-RV-12.pkl
# 84b_H-RV-18.pkl
# 58b_H-CDV-9.pkl
# 77a_H-SortTwoFactors-16.pkl
# 64a_V-FE-10.pkl
# 32a_V-RV-15.pkl
# 110a_V-SortTwoFactors-22.pkl
# 67a_H-CDV-2.pkl
# 142a_V-RV-18.pkl
# 7b_V-SortOverall-8.pkl
# 16b_H-FE-2.pkl
# 131a_H-SortTwoFactors-2.pkl
# 126b_H-SortTwoFactors-2.pkl
# 16b_H-SortTwoFactors-3.pkl
# 144b_H-CDV-11.pkl
# 32b_H-CDV-10.pkl
# 34b_H-FE-4.pkl
# 25a_H-CDV-24.pkl
# 111b_V-RV-9.pkl
# 31b_V-SortTwoFactors-20.pkl
# 92b_V-SortTwoFactors-3.pkl
# 56a_V-SortTwoFactors-21.pkl
# 104a_V-RV-5.pkl
# 105b_V-SortTwoFactors-10.pkl
# 27a_H-SortOverall-11.pkl
# 15a_H-FE-16.pkl
# 70b_H-SortOverall-5.pkl
# 28b_H-SortTwoFactors-3.pkl
# 35a_H-CDV-2.pkl
# 12a_V-RV-22.pkl
# 103a_H-FE-16.pkl
# 127a_H-RV-18.pkl
# 83b_V-SortOverall-10.pkl
# 111b_V-SortTwoFactors-20.pkl
# 36b_H-SortOverall-12.pkl
# 100a_V-CDV-4.pkl
# 134a_V-FE-5.pkl
# 86a_V-SortOverall-14.pkl
# 148a_V-SortOverall-16.pkl
# 87b_H-FE-3.pkl
# 93b_H-RV-17.pkl
# 138a_V-SortOverall-15.pkl
# 130b_H-SortTwoFactors-17.pkl
# 29b_V-RV-20.pkl
# 141a_H-SortOverall-10.pkl
# 118a_V-SortTwoFactors-21.pkl
# 75a_H-SortTwoFactors-21.pkl
# 26a_V-FE-22.pkl
# 11a_H-FE-22.pkl
# 130b_H-SortOverall-9.pkl
# 37b_V-SortTwoFactors-16.pkl
# 92b_V-SortOverall-22.pkl
# 140a_V-SortOverall-15.pkl
# 23b_V-SortOverall-10.pkl
# 18b_H-CDV-9.pkl
# 137a_H-SortTwoFactors-23.pkl
# 150b_H-SortTwoFactors-22.pkl
# 121a_H-RV-23.pkl
# 125a_H-CDV-5.pkl
# 25a_H-SortOverall-16.pkl
# 11b_V-SortOverall-12.pkl
# 72b_H-SortTwoFactors-15.pkl
# 131a_H-CDV-15.pkl
# 140a_V-SortOverall-4.pkl
# 96b_H-FE-15.pkl
# 46a_V-FE-14.pkl
# 36b_H-CDV-11.pkl
# 74a_V-FE-6.pkl
# 35a_H-CDV-20.pkl
# 114a_V-RV-2.pkl
# 122b_H-SortOverall-17.pkl
# 46b_H-RV-5.pkl
# 16b_H-SortTwoFactors-21.pkl
# 92b_V-RV-15.pkl
# 133a_H-CDV-22.pkl
# 45a_H-CDV-23.pkl
# 8a_V-SortTwoFactors-5.pkl
# 145a_H-SortTwoFactors-10.pkl
# 86b_H-SortOverall-4.pkl
# 19b_V-SortTwoFactors-6.pkl
# 38b_H-CDV-2.pkl
# 22a_V-SortTwoFactors-24.pkl
# 48a_V-SortOverall-6.pkl
# 96b_H-RV-18.pkl
# 55a_H-FE-17.pkl
# 116b_H-FE-9.pkl
# 56a_V-SortTwoFactors-3.pkl
# 126a_V-CDV-8.pkl
# 103a_H-FE-5.pkl
# 139a_H-SortOverall-5.pkl
# 70b_H-SortTwoFactors-22.pkl
# 17a_H-CDV-6.pkl
# 20a_V-CDV-6.pkl
# 129b_V-FE-24.pkl
# 37b_V-CDV-22.pkl
# 23a_H-RV-9.pkl
# 2a_V-FE-24.pkl
# 54b_H-FE-3.pkl
# 66a_V-FE-8.pkl
# 11b_V-RV-2.pkl
# 64b_H-SortTwoFactors-12.pkl
# 146a_V-SortOverall-8.pkl
# 35b_V-SortTwoFactors-21.pkl
# 121a_H-SortTwoFactors-20.pkl
# 79a_H-CDV-14.pkl
# 30a_V-RV-22.pkl
# 10b_H-SortTwoFactors-8.pkl
# 23b_V-CDV-23.pkl
# 105a_H-RV-18.pkl
# 36b_H-FE-9.pkl
# 19a_H-SortTwoFactors-3.pkl
# 109b_V-SortTwoFactors-16.pkl
# 14b_H-SortTwoFactors-12.pkl
# 106a_V-FE-24.pkl
# 128a_V-SortOverall-9.pkl
# 36a_V-SortTwoFactors-10.pkl
# 46a_V-RV-21.pkl
# 139b_V-FE-12.pkl
# 130a_V-CDV-22.pkl
# 65a_H-FE-16.pkl
# 82b_H-FE-17.pkl
# 41a_H-RV-18.pkl
# 133a_H-SortOverall-10.pkl
# 7b_V-FE-6.pkl
# 28b_H-FE-17.pkl
# 45a_H-CDV-2.pkl
# 126b_H-FE-5.pkl
# 3a_H-SortTwoFactors-3.pkl
# 121a_H-CDV-9.pkl
# 29b_V-SortOverall-10.pkl
# 145b_V-SortOverall-15.pkl
# 46b_H-FE-9.pkl
# 20a_V-SortTwoFactors-17.pkl
# 66b_H-SortTwoFactors-21.pkl
# 24a_V-FE-15.pkl
# 13a_H-FE-15.pkl
# 23b_V-SortOverall-14.pkl
# 140a_V-FE-22.pkl
# 70a_V-SortOverall-16.pkl
# 15a_H-SortTwoFactors-10.pkl
# 27a_H-SortTwoFactors-3.pkl
# 50b_H-CDV-24.pkl
# 104b_H-FE-3.pkl
# 129a_H-SortTwoFactors-23.pkl
# 103a_H-SortOverall-15.pkl
# 74a_V-CDV-5.pkl
# 29b_V-RV-18.pkl
# 140a_V-SortTwoFactors-2.pkl
# 70a_V-SortTwoFactors-3.pkl
# 83b_V-RV-18.pkl
# 77a_H-FE-17.pkl
# 92b_V-SortOverall-9.pkl
# 100a_V-RV-12.pkl
# 22b_H-SortOverall-11.pkl
# 129b_V-SortOverall-12.pkl
# 85b_V-RV-2.pkl
# 57a_H-SortOverall-16.pkl
# 18a_V-CDV-20.pkl
# 55b_V-SortOverall-6.pkl
# 85a_H-SortOverall-12.pkl
# 127a_H-RV-20.pkl
# 28b_H-SortOverall-15.pkl
# 54a_V-RV-5.pkl
# 105b_V-SortTwoFactors-14.pkl
# 65a_H-SortOverall-14.pkl
# 128a_V-RV-8.pkl
# 55a_H-CDV-23.pkl
# 141a_H-RV-11.pkl
# 96b_H-SortTwoFactors-4.pkl
# 55a_H-SortOverall-5.pkl
# 148b_H-SortTwoFactors-14.pkl
# 25a_H-FE-17.pkl
# 144b_H-CDV-15.pkl
# 57a_H-FE-20.pkl
# 107a_H-CDV-5.pkl
# 94a_H-SortOverall-6.pkl
# 148b_H-RV-5.pkl
# 110a_V-FE-11.pkl
# 26a_V-CDV-24.pkl
# 123a_H-RV-6.pkl
# 104b_H-SortTwoFactors-5.pkl
# 23a_H-SortTwoFactors-4.pkl
# 47b_V-SortTwoFactors-8.pkl
# 92a_H-SortTwoFactors-6.pkl
# 142a_V-RV-20.pkl
# 70a_V-FE-12.pkl
# 113a_H-RV-11.pkl
# 114b_H-FE-4.pkl
# 130a_V-RV-17.pkl
# 107a_H-RV-17.pkl
# 132b_H-SortTwoFactors-24.pkl
# 16a_V-SortTwoFactors-6.pkl
# 7b_V-SortTwoFactors-5.pkl
# 54a_V-RV-20.pkl
# 31b_V-RV-8.pkl
# 94b_V-SortTwoFactors-22.pkl
# 38a_V-SortTwoFactors-24.pkl
# 131b_V-SortTwoFactors-6.pkl
# 46a_V-FE-2.pkl
# 126a_V-SortTwoFactors-6.pkl
# 21a_H-FE-22.pkl
# 83b_V-FE-14.pkl
# 29b_V-FE-14.pkl
# 121b_V-CDV-21.pkl
# 26a_V-SortTwoFactors-20.pkl
# 40a_V-CDV-14.pkl
# 50a_V-SortTwoFactors-9.pkl
# 40b_H-CDV-21.pkl
# 104a_V-FE-16.pkl
# 26b_H-CDV-10.pkl
# 36a_V-RV-24.pkl
# 58b_H-RV-23.pkl
# 23a_H-SortOverall-6.pkl
# 104a_V-FE-8.pkl
# 1b_V-SortTwoFactors-14.pkl
# 47a_H-SortTwoFactors-8.pkl
# 36a_V-RV-18.pkl
# 142b_H-SortTwoFactors-21.pkl
# 28b_H-RV-8.pkl
# 67b_V-SortOverall-4.pkl
# 111b_V-FE-4.pkl
# 25b_V-SortTwoFactors-15.pkl
# 11a_H-CDV-4.pkl
# 50a_V-RV-15.pkl
# 67a_H-SortTwoFactors-3.pkl
# 67a_H-FE-24.pkl
# 55b_V-CDV-17.pkl
# 123a_H-CDV-23.pkl
# 79a_H-SortTwoFactors-8.pkl
# 110a_V-RV-21.pkl
# 3a_H-FE-23.pkl
# 3b_V-SortTwoFactors-23.pkl
# 142a_V-FE-10.pkl
# 141a_H-SortOverall-15.pkl
# 123a_H-RV-15.pkl
# 146a_V-CDV-16.pkl
# 105b_V-SortOverall-12.pkl
# 131a_H-SortOverall-16.pkl
# 114a_V-SortOverall-11.pkl
# 19b_V-FE-11.pkl
# 40a_V-FE-16.pkl
# 145a_H-RV-24.pkl
# 58b_H-RV-8.pkl
# 83a_H-SortTwoFactors-17.pkl
# 138a_V-SortOverall-10.pkl
# 93b_H-RV-12.pkl
# 30b_H-SortTwoFactors-2.pkl
# 129b_V-RV-10.pkl
# 8a_V-SortOverall-20.pkl
# 82b_H-FE-3.pkl
# 14b_H-SortOverall-6.pkl
# 126a_V-FE-12.pkl
# 95b_V-RV-10.pkl
# 132b_H-CDV-21.pkl
# 111a_H-RV-6.pkl
# 96b_H-SortOverall-17.pkl
# 141b_V-RV-3.pkl
# 35b_V-CDV-10.pkl
# 20a_V-FE-20.pkl
# 112a_V-RV-12.pkl
# 92b_V-FE-21.pkl
# 144a_V-FE-17.pkl
# 73a_H-SortOverall-15.pkl
# 4a_V-SortTwoFactors-17.pkl
# 48a_V-SortOverall-11.pkl
# 50b_H-SortOverall-14.pkl
# 29b_V-SortOverall-6.pkl
# 103a_H-RV-8.pkl
# 46b_H-CDV-17.pkl
# 26a_V-FE-5.pkl
# 122b_H-SortTwoFactors-14.pkl
# 92b_V-RV-10.pkl
# 129b_V-SortTwoFactors-2.pkl
# 145a_H-SortTwoFactors-15.pkl
# 55a_H-FE-12.pkl
# 146a_V-FE-9.pkl
# 58a_V-SortTwoFactors-11.pkl
# 45a_H-FE-20.pkl
# 95b_V-FE-21.pkl
# 142b_H-CDV-22.pkl
# 148b_H-RV-18.pkl
# 121a_H-FE-17.pkl
# 61a_V-CDV-5.pkl
# 65a_H-CDV-8.pkl
# 26a_V-SortOverall-6.pkl
# 46a_V-SortTwoFactors-15.pkl
# 121a_H-FE-4.pkl
# 126a_V-RV-21.pkl
# 111a_H-RV-21.pkl
# 8b_H-SortTwoFactors-3.pkl
# 142a_V-CDV-15.pkl
# 1a_H-SortTwoFactors-8.pkl
# 116b_H-RV-6.pkl
# 133b_V-CDV-10.pkl
# 65a_H-RV-18.pkl
# 87a_V-RV-6.pkl
# 32b_H-SortTwoFactors-8.pkl
# 48b_H-SortOverall-2.pkl
# 74a_V-RV-9.pkl
# 27a_H-RV-16.pkl
# 110b_H-SortOverall-12.pkl
# 21b_V-CDV-17.pkl
# 104a_V-SortOverall-2.pkl
# 65a_H-SortTwoFactors-17.pkl
# 95b_V-SortOverall-17.pkl
# 122b_H-SortOverall-10.pkl
# 55a_H-RV-21.pkl
# 64a_V-SortOverall-9.pkl
# 7b_V-SortTwoFactors-20.pkl
# 1a_H-SortOverall-24.pkl
# 104b_H-SortOverall-15.pkl
# 37a_H-RV-18.pkl
# 11b_V-SortOverall-15.pkl
# 21b_V-FE-5.pkl
# 106a_V-CDV-4.pkl
# 31b_V-SortOverall-3.pkl
# 91b_H-RV-23.pkl
# 75b_V-SortOverall-2.pkl
# 14a_V-RV-22.pkl
# 123a_H-SortTwoFactors-14.pkl
# 121a_H-RV-18.pkl
# 29b_V-SortTwoFactors-15.pkl
# 96a_V-SortTwoFactors-6.pkl
# 131a_H-FE-3.pkl
# 14a_V-FE-6.pkl
# 54a_V-FE-12.pkl
# 25a_H-SortOverall-8.pkl
# 150b_H-SortOverall-14.pkl
# 130b_H-SortTwoFactors-10.pkl
# 112b_H-SortOverall-15.pkl
# 8b_H-RV-17.pkl
# 16a_V-SortOverall-16.pkl
# 32a_V-FE-23.pkl
# 121b_V-RV-6.pkl
# 13b_V-SortOverall-12.pkl
# 54a_V-SortTwoFactors-11.pkl
# 18b_H-RV-2.pkl
# 58b_H-SortOverall-15.pkl
# 39b_V-RV-15.pkl
# 137a_H-CDV-24.pkl
# 21a_H-CDV-3.pkl
# 113a_H-FE-5.pkl
# 103a_H-FE-11.pkl
# 149b_V-RV-18.pkl
# 9a_H-RV-8.pkl
# 137a_H-CDV-3.pkl
# 103a_H-RV-20.pkl
# 32a_V-CDV-22.pkl
# 64a_V-FE-6.pkl
# 122a_V-SortOverall-9.pkl
# 3a_H-RV-10.pkl
# 133a_H-FE-14.pkl
# 131a_H-SortTwoFactors-12.pkl
# 109a_H-CDV-20.pkl
# 71b_V-RV-2.pkl
# 57b_V-CDV-22.pkl
# 36a_V-CDV-8.pkl
# 133b_V-SortOverall-2.pkl
# 141a_H-SortTwoFactors-16.pkl
# 32a_V-RV-12.pkl
# 116b_H-SortOverall-5.pkl
# 72b_H-SortTwoFactors-9.pkl
# 144a_V-FE-2.pkl
# 7a_H-RV-18.pkl
# 2a_V-SortTwoFactors-23.pkl
# 8a_V-SortTwoFactors-16.pkl
# 84b_H-RV-23.pkl
# 142b_H-SortTwoFactors-9.pkl
# 34b_H-SortTwoFactors-6.pkl
# 126a_V-RV-5.pkl
# 137a_H-FE-21.pkl
# 77a_H-RV-18.pkl
# 40a_V-RV-18.pkl
# 104a_V-SortTwoFactors-6.pkl
# 109b_V-CDV-14.pkl
# 22a_V-RV-21.pkl
# 13b_V-FE-5.pkl
# 25b_V-CDV-17.pkl
# 23b_V-SortOverall-6.pkl
# 144a_V-CDV-22.pkl
# 142a_V-SortTwoFactors-8.pkl
# 32b_H-CDV-16.pkl
# 11a_H-FE-6.pkl
# 114a_V-CDV-4.pkl
# 39a_H-SortOverall-14.pkl
# 104a_V-RV-18.pkl
# 133a_H-RV-18.pkl
# 100a_V-SortOverall-15.pkl
# 16a_V-CDV-2.pkl
# 12a_V-RV-18.pkl
# 144b_H-SortOverall-12.pkl
# 25a_H-RV-18.pkl
# 11b_V-SortOverall-5.pkl
# 145a_H-SortOverall-2.pkl
# 146b_H-CDV-20.pkl
# 35b_V-SortOverall-16.pkl
# 103b_V-FE-9.pkl
# 52b_H-SortTwoFactors-3.pkl
# 47a_H-RV-21.pkl
# 26b_H-RV-4.pkl
# 93b_H-SortOverall-21.pkl
# 18b_H-SortTwoFactors-12.pkl
# 70a_V-RV-21.pkl
# 27a_H-CDV-15.pkl
# 39b_V-CDV-6.pkl
# 130a_V-FE-24.pkl
# 63b_V-FE-5.pkl
# 106a_V-SortTwoFactors-23.pkl
# 92a_H-SortOverall-8.pkl
# 86a_V-SortOverall-12.pkl
# 30a_V-SortTwoFactors-24.pkl
# 10b_H-SortOverall-11.pkl
# 145a_H-CDV-11.pkl
# 144b_H-SortTwoFactors-14.pkl
# 105a_H-FE-17.pkl
# 132a_V-FE-17.pkl
# 4b_H-SortOverall-2.pkl
# 23b_V-SortTwoFactors-20.pkl
# 112a_V-CDV-3.pkl
# 86b_H-FE-21.pkl
# 131a_H-CDV-5.pkl
# 30a_V-FE-11.pkl
# 67a_H-SortOverall-11.pkl
# 97a_H-RV-4.pkl
# 127a_H-SortOverall-15.pkl
# 99a_H-SortTwoFactors-2.pkl
# 99a_H-CDV-3.pkl
# 84b_H-SortTwoFactors-20.pkl
# 27a_H-CDV-5.pkl
# 144b_H-FE-9.pkl
# 131a_H-RV-17.pkl
# 143a_H-RV-20.pkl
# 140b_H-CDV-16.pkl
# 21a_H-CDV-23.pkl
# 62b_V-SortOverall-6.pkl
# 143a_H-SortOverall-11.pkl
# 38b_H-FE-4.pkl
# 47b_V-SortOverall-12.pkl
# 138a_V-FE-5.pkl
# 109b_V-RV-18.pkl
# 85a_H-SortTwoFactors-22.pkl
# 85a_H-FE-2.pkl
# 96b_H-RV-22.pkl
# 76b_H-FE-3.pkl
# 127a_H-CDV-21.pkl
# 140a_V-CDV-3.pkl
# 29a_H-SortOverall-6.pkl
# 150a_V-RV-23.pkl
# 58a_V-FE-9.pkl
# 45b_V-SortTwoFactors-23.pkl
# 28b_H-RV-18.pkl
# 131b_V-FE-8.pkl
# 20a_V-RV-12.pkl
# 93a_V-SortTwoFactors-15.pkl
# 72a_V-FE-23.pkl
# 64b_H-SortTwoFactors-14.pkl
# 14a_V-FE-12.pkl
# 37a_H-CDV-11.pkl
# 25b_V-SortTwoFactors-8.pkl
# 38b_H-RV-16.pkl
# 106a_V-FE-2.pkl
# 20a_V-CDV-10.pkl
# 111a_H-SortOverall-10.pkl
# 45a_H-SortTwoFactors-12.pkl
# 47b_V-FE-6.pkl
# 39b_V-SortOverall-12.pkl
# 87a_V-SortOverall-20.pkl
# 54b_H-SortOverall-2.pkl
# 126b_H-FE-14.pkl
# 111b_V-FE-14.pkl
# 139b_V-SortTwoFactors-2.pkl
# 129a_H-RV-16.pkl
# 67b_V-SortTwoFactors-10.pkl
# 71a_H-SortOverall-6.pkl
# 150a_V-FE-8.pkl
# 85a_H-RV-18.pkl
# 126b_H-SortOverall-16.pkl
# 23b_V-CDV-8.pkl
# 87b_H-SortTwoFactors-14.pkl
# 12b_H-CDV-17.pkl
# 100b_H-SortOverall-6.pkl
# 122b_H-FE-20.pkl
# 10a_V-SortOverall-17.pkl
# 150b_H-FE-17.pkl
# 77a_H-SortOverall-11.pkl
# 86b_H-SortOverall-14.pkl
# 131b_V-RV-12.pkl
# 150a_V-SortTwoFactors-15.pkl
# 142a_V-FE-6.pkl
# 92a_H-RV-16.pkl
# 29a_H-SortTwoFactors-9.pkl
# 75a_H-CDV-20.pkl
# 72a_V-SortTwoFactors-22.pkl
# 114b_H-CDV-15.pkl
# 22a_V-RV-2.pkl
# 49a_H-FE-24.pkl
# 122b_H-RV-11.pkl
# 34b_H-CDV-3.pkl
# 13a_H-CDV-11.pkl
# 84b_H-CDV-24.pkl
# 75b_V-RV-12.pkl
# 150b_H-CDV-8.pkl
# 10b_H-CDV-20.pkl
# 122b_H-CDV-3.pkl
# 116b_H-SortTwoFactors-23.pkl
# 11b_V-RV-10.pkl
# 57b_V-RV-9.pkl
# 20a_V-FE-3.pkl
# 137a_H-SortOverall-6.pkl
# 148b_H-SortOverall-8.pkl
# 105b_V-CDV-22.pkl
# 86b_H-SortTwoFactors-5.pkl
# 8a_V-FE-22.pkl
# 47b_V-FE-15.pkl
# 29a_H-FE-12.pkl
# 149b_V-FE-2.pkl
# 64a_V-CDV-17.pkl
# 38b_H-SortTwoFactors-6.pkl
# 21b_V-FE-24.pkl
# 111a_H-SortTwoFactors-17.pkl
# 27a_H-SortTwoFactors-10.pkl
# 77b_V-RV-21.pkl
# 130a_V-SortTwoFactors-20.pkl
# 16b_H-CDV-16.pkl
# 139b_V-CDV-11.pkl
# 90a_H-SortOverall-2.pkl
# 58a_V-CDV-24.pkl
# 22b_H-RV-18.pkl
# 30b_H-SortTwoFactors-15.pkl
# 54b_H-CDV-9.pkl
# 143b_V-SortTwoFactors-11.pkl
# 103a_H-SortOverall-9.pkl
# 39a_H-SortOverall-8.pkl
# 86a_V-SortTwoFactors-4.pkl
# 112b_H-SortTwoFactors-22.pkl
# 36b_H-RV-22.pkl
# 39a_H-RV-11.pkl
# 57b_V-RV-16.pkl
# 26b_H-SortTwoFactors-12.pkl
# 79b_V-SortOverall-14.pkl
# 55b_V-SortOverall-15.pkl
# 1b_V-SortOverall-23.pkl
# 149b_V-CDV-12.pkl
# 113a_H-SortOverall-17.pkl
# 103b_V-FE-15.pkl
# 40a_V-SortTwoFactors-9.pkl
# 63b_V-SortTwoFactors-11.pkl
# 130b_H-SortOverall-16.pkl
# 15b_V-SortOverall-3.pkl
# 40b_H-RV-6.pkl
# 16b_H-RV-15.pkl
# 37a_H-RV-4.pkl
# 47b_V-RV-18.pkl
# 84a_V-FE-17.pkl
# 72a_V-FE-5.pkl
# 2b_H-SortOverall-21.pkl
# 107a_H-SortTwoFactors-10.pkl
# 95a_H-SortOverall-10.pkl
# 50a_V-SortOverall-11.pkl
# 37a_H-SortOverall-17.pkl
# 29a_H-RV-23.pkl
# 63b_V-FE-17.pkl
# 54b_H-FE-17.pkl
# 67b_V-FE-8.pkl
# 43b_V-CDV-3.pkl
# 84b_H-SortOverall-12.pkl
# 113a_H-SortTwoFactors-21.pkl
# 39a_H-CDV-2.pkl
# 17b_V-SortOverall-15.pkl
# 140b_H-SortOverall-14.pkl
# 110b_H-CDV-15.pkl
# 30b_H-SortOverall-5.pkl
# 110a_V-CDV-20.pkl
# 32b_H-SortTwoFactors-23.pkl
# 133b_V-RV-20.pkl
# 77a_H-FE-5.pkl
# 2b_H-CDV-23.pkl
# 11b_V-SortTwoFactors-6.pkl
# 121a_H-SortOverall-14.pkl
# 4b_H-RV-9.pkl
# 72a_V-CDV-24.pkl
# 128a_V-RV-15.pkl
# 130b_H-CDV-3.pkl
# 12a_V-SortTwoFactors-16.pkl
# 96b_H-CDV-16.pkl
# 90a_H-RV-18.pkl
# 19a_H-CDV-9.pkl
# 132b_H-RV-5.pkl
# 96a_V-CDV-23.pkl
# 27a_H-SortOverall-2.pkl
# 4b_H-FE-21.pkl
# 58a_V-RV-18.pkl
# 67b_V-RV-12.pkl
# 17b_V-FE-8.pkl
# 26b_H-CDV-3.pkl
# 140a_V-RV-6.pkl
# 65a_H-RV-3.pkl
# 145b_V-FE-12.pkl
# 148b_H-CDV-20.pkl
# 64b_H-CDV-23.pkl
# 150b_H-SortTwoFactors-3.pkl
# 32b_H-RV-17.pkl
# 1b_V-CDV-8.pkl
# 37b_V-SortTwoFactors-2.pkl
# 10a_V-CDV-14.pkl
# 13b_V-RV-22.pkl
# 45a_H-FE-4.pkl
# 111b_V-RV-18.pkl
# 126b_H-RV-18.pkl
# 84a_V-CDV-10.pkl
# 4b_H-SortTwoFactors-24.pkl
# 148a_V-SortTwoFactors-6.pkl
# 23b_V-FE-16.pkl
# 30b_H-RV-18.pkl
# 1a_H-RV-2.pkl
# 6b_H-FE-12.pkl
# 55b_V-FE-9.pkl
# 77b_V-SortOverall-8.pkl
# 99b_V-FE-24.pkl
# 114a_V-CDV-21.pkl
# 132b_H-SortOverall-4.pkl
# 79a_H-FE-20.pkl
# 96a_V-RV-8.pkl
# 125a_H-SortOverall-3.pkl
# 109a_H-SortTwoFactors-24.pkl
# 103a_H-SortTwoFactors-10.pkl
# 143b_V-RV-18.pkl
# 140b_H-FE-4.pkl
# 93a_V-SortTwoFactors-8.pkl
# 45b_V-CDV-4.pkl
# 85a_H-CDV-23.pkl
# 12a_V-CDV-23.pkl
# 129a_H-SortOverall-17.pkl
# 16b_H-SortOverall-10.pkl
# 71b_V-FE-16.pkl
# 96a_V-FE-17.pkl
# 139a_H-SortTwoFactors-2.pkl
# 19a_H-SortOverall-10.pkl
# 17b_V-SortTwoFactors-9.pkl
# 37b_V-RV-21.pkl
# 144a_V-SortOverall-15.pkl
# 39b_V-FE-8.pkl
# 45b_V-RV-16.pkl
# 77b_V-CDV-23.pkl
# 7b_V-CDV-11.pkl
# 22b_H-SortTwoFactors-12.pkl
# 116b_H-RV-21.pkl
# 95a_H-RV-15.pkl
# 145b_V-SortTwoFactors-24.pkl
# 77a_H-CDV-14.pkl
# 46a_V-SortTwoFactors-5.pkl
# 116a_V-CDV-14.pkl
# 38a_V-FE-21.pkl
# 63b_V-CDV-24.pkl
# 30b_H-SortOverall-17.pkl
# 93a_V-CDV-12.pkl
# 112b_H-CDV-5.pkl
# 13a_H-SortOverall-16.pkl
# 122b_H-FE-8.pkl
# 17b_V-SortTwoFactors-17.pkl
# 112a_V-SortOverall-11.pkl
# 129b_V-CDV-16.pkl
# 137a_H-FE-4.pkl
# 106b_H-RV-11.pkl
# 35a_H-FE-6.pkl
# 114b_H-SortOverall-17.pkl
# 148b_H-SortOverall-15.pkl
# 100a_V-SortOverall-6.pkl
# 12a_V-RV-9.pkl
# 110a_V-FE-3.pkl
# 86b_H-CDV-10.pkl
# 131b_V-FE-20.pkl
# 67a_H-RV-8.pkl
# 8b_H-FE-5.pkl
# 109a_H-SortOverall-9.pkl
# 1b_V-RV-24.pkl
# 91b_H-SortTwoFactors-10.pkl
# 38b_H-CDV-15.pkl
# 37b_V-FE-5.pkl
# 38a_V-CDV-20.pkl
# 23a_H-SortTwoFactors-12.pkl
# 1b_V-RV-18.pkl
# 132a_V-SortOverall-5.pkl
# 96a_V-RV-24.pkl
# 55b_V-RV-3.pkl
# 93b_H-RV-5.pkl
# 148a_V-RV-21.pkl
# 140b_H-RV-17.pkl
# 139b_V-SortTwoFactors-22.pkl
# 83a_H-FE-11.pkl
# 54b_H-RV-18.pkl
# 63b_V-RV-18.pkl
# 149b_V-RV-9.pkl
# 114b_H-FE-21.pkl
# 39a_H-SortTwoFactors-17.pkl
# 105a_H-FE-5.pkl
# 105a_H-CDV-14.pkl
# 48a_V-RV-14.pkl
# 40b_H-RV-22.pkl
# 72a_V-SortOverall-9.pkl
# 142b_H-RV-18.pkl
# 106a_V-CDV-10.pkl
# 148a_V-SortOverall-8.pkl
# 70a_V-CDV-11.pkl
# 11b_V-SortTwoFactors-21.pkl
# 146b_H-CDV-2.pkl
# 31b_V-FE-15.pkl
# 145a_H-RV-5.pkl
# 63b_V-SortOverall-2.pkl
# 86a_V-FE-5.pkl
# 3b_V-RV-17.pkl
# 146b_H-RV-10.pkl
# 91b_H-FE-4.pkl
# 110b_H-RV-24.pkl
# 31b_V-RV-18.pkl
# 84b_H-FE-6.pkl
# 125b_V-RV-8.pkl
# 65b_V-CDV-12.pkl
# 146b_H-FE-21.pkl
# 11a_H-SortOverall-11.pkl
# 87a_V-CDV-3.pkl
# 28b_H-CDV-11.pkl
# 96a_V-SortOverall-11.pkl
# 131a_H-SortOverall-9.pkl
# 110b_H-RV-18.pkl
# 132a_V-SortTwoFactors-14.pkl
# 138a_V-SortTwoFactors-20.pkl
# 50b_H-FE-21.pkl
# 149a_H-CDV-24.pkl
# 118a_V-RV-12.pkl
# 112a_V-RV-2.pkl
# 67b_V-RV-2.pkl
# 31b_V-SortOverall-12.pkl
# 74a_V-SortTwoFactors-17.pkl
# 114a_V-SortTwoFactors-6.pkl
# 105a_H-SortOverall-6.pkl
# 145b_V-RV-21.pkl
# 130b_H-FE-22.pkl
# 138a_V-CDV-14.pkl
# 75a_H-SortOverall-15.pkl
# 38b_H-SortOverall-14.pkl
# 14a_V-CDV-17.pkl
# 123b_V-RV-10.pkl
# 7b_V-FE-12.pkl
# 1b_V-FE-2.pkl
# 11b_V-FE-22.pkl
# 100b_H-RV-16.pkl
# 143b_V-SortOverall-15.pkl
# 105b_V-SortOverall-4.pkl
# 141b_V-CDV-6.pkl
# 19b_V-FE-4.pkl
# 55a_H-RV-8.pkl
# 133b_V-SortOverall-16.pkl
# 64b_H-SortOverall-17.pkl
# 64b_H-RV-20.pkl
# 83a_H-CDV-16.pkl
# 141b_V-SortOverall-5.pkl
# 122a_V-SortOverall-15.pkl
# 93a_V-RV-16.pkl
# 142b_H-RV-6.pkl
# 10a_V-FE-9.pkl
# 100b_H-CDV-5.pkl
# 15a_H-FE-8.pkl
# 1a_H-CDV-11.pkl
# 67b_V-SortOverall-15.pkl
# 130a_V-RV-5.pkl
# 71a_H-CDV-23.pkl
# 107a_H-CDV-22.pkl
# 45b_V-RV-5.pkl
# 93a_V-CDV-4.pkl
# 121b_V-SortTwoFactors-4.pkl
# 16b_H-CDV-5.pkl
# 93a_V-FE-6.pkl
# 139b_V-RV-8.pkl
# 149a_H-RV-22.pkl
# 39a_H-FE-22.pkl
# 74b_H-FE-23.pkl
# 15b_V-CDV-10.pkl
# 32b_H-CDV-6.pkl
# 103b_V-SortOverall-8.pkl
# 25b_V-FE-12.pkl
# 106b_H-SortTwoFactors-10.pkl
# 55a_H-SortTwoFactors-2.pkl
# 12b_H-RV-2.pkl
# 3a_H-SortOverall-9.pkl
# 130b_H-RV-12.pkl
# 87a_V-FE-21.pkl
# 138a_V-RV-18.pkl
# 79a_H-FE-9.pkl
# 29b_V-CDV-23.pkl
# 67b_V-CDV-3.pkl
# 133b_V-SortTwoFactors-17.pkl
# 112b_H-CDV-21.pkl
# 19a_H-RV-18.pkl
# 138a_V-RV-24.pkl
# 84a_V-RV-18.pkl
# 71b_V-SortTwoFactors-15.pkl
# 106b_H-SortOverall-8.pkl
# 16a_V-SortTwoFactors-14.pkl
# 128a_V-CDV-11.pkl
# 105b_V-RV-21.pkl
# 84a_V-RV-5.pkl
# 77b_V-RV-4.pkl
# 22b_H-SortOverall-2.pkl
# 15a_H-SortTwoFactors-3.pkl
# 132b_H-SortTwoFactors-2.pkl
# 34b_H-SortTwoFactors-16.pkl
# 56b_H-RV-16.pkl
# 27a_H-FE-9.pkl
# 150b_H-RV-18.pkl
# 71b_V-RV-24.pkl
# 103a_H-CDV-23.pkl
# 22a_V-FE-8.pkl
# 1a_H-FE-9.pkl
# 148b_H-SortTwoFactors-4.pkl
# 103b_V-CDV-16.pkl
# 97a_H-SortTwoFactors-8.pkl
# 137b_V-SortTwoFactors-16.pkl
# 109a_H-RV-23.pkl
# 55b_V-FE-16.pkl
# 144b_H-RV-22.pkl
# 50b_H-SortTwoFactors-22.pkl
# 79a_H-RV-12.pkl
# 112a_V-SortTwoFactors-8.pkl
# 96a_V-FE-3.pkl
# 129a_H-CDV-6.pkl
# 150a_V-SortOverall-11.pkl
# 144a_V-SortOverall-6.pkl
# 45a_H-SortOverall-11.pkl
# 46b_H-FE-15.pkl
# 22a_V-SortOverall-17.pkl
# 6b_H-SortTwoFactors-8.pkl
# 146a_V-SortTwoFactors-10.pkl
# 131b_V-SortOverall-11.pkl
# 121b_V-SortTwoFactors-11.pkl
# 10b_H-RV-10.pkl
# 6b_H-RV-20.pkl
# 132b_H-FE-10.pkl
# 62b_V-RV-22.pkl
# 139a_H-CDV-8.pkl
# 74a_V-CDV-11.pkl
# 2b_H-RV-14.pkl
# 23b_V-RV-24.pkl
# 4a_V-CDV-23.pkl
# 58a_V-SortOverall-10.pkl
# 106b_H-CDV-2.pkl
# 63a_H-CDV-10.pkl
# 64b_H-SortTwoFactors-6.pkl
# 121b_V-RV-22.pkl
# 90a_H-CDV-17.pkl
# 23b_V-RV-18.pkl
# 72b_H-SortOverall-17.pkl
# 132a_V-FE-4.pkl
# 14b_H-RV-18.pkl
# 87b_H-CDV-23.pkl
# 109b_V-SortOverall-17.pkl
# 10b_H-CDV-2.pkl
# 87a_V-CDV-16.pkl
# 145b_V-FE-6.pkl
# 35b_V-SortOverall-6.pkl
# 57b_V-SortOverall-14.pkl
# 129a_H-RV-10.pkl
# 62b_V-RV-2.pkl
# 93b_H-CDV-22.pkl
# 148a_V-FE-15.pkl
# 74a_V-SortOverall-15.pkl
# 100b_H-RV-3.pkl
# 14b_H-RV-20.pkl
# 132b_H-FE-14.pkl
# 39b_V-SortOverall-14.pkl
# 132a_V-RV-8.pkl
# 109a_H-FE-6.pkl
# 7b_V-CDV-16.pkl
# 116b_H-CDV-24.pkl
# 39a_H-CDV-16.pkl
# 71b_V-SortOverall-3.pkl
# 22b_H-SortTwoFactors-15.pkl
# 6b_H-RV-18.pkl
# 29a_H-FE-2.pkl
# 152a_V-SortTwoFactors-24.pkl
# 54b_H-SortOverall-16.pkl
# 86a_V-CDV-20.pkl
# 86b_H-SortOverall-12.pkl
# 52b_H-SortTwoFactors-11.pkl
# 70a_V-RV-2.pkl
# 143b_V-SortTwoFactors-2.pkl
# 122b_H-RV-5.pkl
# 16b_H-SortOverall-17.pkl
# 57a_H-RV-5.pkl
# 21a_H-SortTwoFactors-20.pkl
# 19a_H-SortOverall-17.pkl
# 19a_H-RV-2.pkl
# 92a_H-CDV-24.pkl
# 15b_V-SortTwoFactors-6.pkl
# 103b_V-CDV-12.pkl
# 52b_H-SortOverall-8.pkl
# 112b_H-FE-23.pkl
# 75b_V-CDV-6.pkl
# 67a_H-FE-5.pkl
# 91b_H-SortTwoFactors-6.pkl
# 110b_H-SortTwoFactors-5.pkl
# 121b_V-FE-17.pkl
# 71b_V-SortTwoFactors-11.pkl
# 17b_V-CDV-3.pkl
# 93b_H-FE-8.pkl
# 23b_V-FE-11.pkl
# 29b_V-FE-8.pkl
# 106a_V-CDV-15.pkl
# 35b_V-FE-24.pkl
# 67b_V-CDV-20.pkl
# 140a_V-FE-9.pkl
# 57b_V-SortOverall-8.pkl
# 64a_V-CDV-11.pkl
# 105a_H-SortTwoFactors-21.pkl
# 83a_H-RV-9.pkl
# 123b_V-FE-24.pkl
# 9a_H-SortTwoFactors-23.pkl
# 3a_H-FE-4.pkl
# 150b_H-FE-4.pkl
# 15b_V-RV-22.pkl
# 90a_H-RV-23.pkl
# 146b_H-RV-15.pkl
# 52b_H-FE-6.pkl
# 86a_V-RV-8.pkl
# 127a_H-FE-6.pkl
# 39a_H-FE-5.pkl
# 57b_V-FE-21.pkl
# 46a_V-SortOverall-3.pkl
# 36b_H-RV-18.pkl
# 106b_H-SortTwoFactors-14.pkl
# 63a_H-SortOverall-4.pkl
# 11b_V-CDV-4.pkl
# 132a_V-SortTwoFactors-11.pkl
# 114b_H-SortTwoFactors-2.pkl
# 67b_V-SortOverall-11.pkl
# 45b_V-FE-9.pkl
# 130a_V-FE-9.pkl
# 141b_V-SortTwoFactors-20.pkl
# 32b_H-SortOverall-15.pkl
# 4b_H-FE-6.pkl
# 113a_H-CDV-23.pkl
# 72b_H-CDV-16.pkl
# 11a_H-SortOverall-14.pkl
# 145b_V-RV-18.pkl
# 19b_V-RV-8.pkl
# 50a_V-SortOverall-17.pkl
# 133b_V-SortOverall-12.pkl
# 55a_H-FE-4.pkl
# 8a_V-RV-15.pkl
# 1a_H-SortTwoFactors-20.pkl
# 32b_H-FE-21.pkl
# 123b_V-RV-15.pkl
# 48a_V-FE-20.pkl
# 74a_V-SortTwoFactors-12.pkl
# 64b_H-RV-18.pkl
# 12b_H-CDV-9.pkl
# 25b_V-CDV-9.pkl
# 75a_H-SortOverall-10.pkl
# 57b_V-CDV-2.pkl
# 10a_V-RV-5.pkl
# 21b_V-RV-12.pkl
# 74b_H-CDV-5.pkl
# 84b_H-SortOverall-14.pkl
# 148a_V-SortTwoFactors-20.pkl
# 4a_V-SortOverall-20.pkl
# 141a_H-SortOverall-3.pkl
# 83a_H-RV-18.pkl
# 103b_V-SortTwoFactors-2.pkl
# 31b_V-SortOverall-16.pkl
# 29a_H-RV-18.pkl
# 40b_H-FE-9.pkl
# 125b_V-SortTwoFactors-15.pkl
# 54b_H-FE-11.pkl
# 100b_H-RV-12.pkl
# 38b_H-SortOverall-10.pkl
# 4b_H-CDV-4.pkl
# 70b_H-RV-23.pkl
# 104b_H-CDV-8.pkl
# 146a_V-SortOverall-14.pkl
# 25b_V-SortOverall-11.pkl
# 104b_H-CDV-16.pkl
# 152b_H-FE-23.pkl
# 128a_V-FE-22.pkl
# 104a_V-CDV-23.pkl
# 55b_V-SortOverall-12.pkl
# 65a_H-CDV-23.pkl
# 15b_V-FE-12.pkl
# 55a_H-SortTwoFactors-24.pkl
# 32a_V-RV-2.pkl
# 1b_V-CDV-21.pkl
# 81a_H-SortOverall-10.pkl
# 15a_H-RV-5.pkl
# 74b_H-SortOverall-2.pkl
# 96a_V-SortOverall-15.pkl
# 48a_V-CDV-2.pkl
# 139b_V-CDV-16.pkl
# 96b_H-CDV-10.pkl
# 40b_H-CDV-8.pkl
# 31b_V-FE-11.pkl
# 123a_H-SortTwoFactors-8.pkl
# 75b_V-SortTwoFactors-11.pkl
# 150a_V-SortTwoFactors-4.pkl
# 143b_V-SortTwoFactors-16.pkl
# 13a_H-SortTwoFactors-9.pkl
# 18a_V-SortTwoFactors-24.pkl
# 58a_V-RV-22.pkl
# 105a_H-CDV-10.pkl
# 142b_H-RV-20.pkl
# 122a_V-FE-6.pkl
# 54b_H-RV-20.pkl
# 27a_H-SortTwoFactors-17.pkl
# 63b_V-RV-20.pkl
# 70b_H-CDV-20.pkl
# 13b_V-RV-18.pkl
# 126b_H-RV-22.pkl
# 27a_H-RV-4.pkl
# 123a_H-SortOverall-9.pkl
# 52b_H-CDV-9.pkl
# 4b_H-SortTwoFactors-5.pkl
# 13b_V-CDV-23.pkl
# 77b_V-FE-9.pkl
# 129a_H-FE-20.pkl
# 50b_H-RV-6.pkl
# 79a_H-CDV-5.pkl
# 22a_V-SortOverall-4.pkl
# 132b_H-RV-18.pkl
# 109a_H-CDV-8.pkl
# 20a_V-SortTwoFactors-4.pkl
# 110a_V-SortTwoFactors-5.pkl
# 47a_H-SortTwoFactors-22.pkl
# 128a_V-CDV-14.pkl
# 91b_H-CDV-14.pkl
# 107a_H-SortTwoFactors-4.pkl
# 17b_V-RV-10.pkl
# 29a_H-SortTwoFactors-22.pkl
# 132a_V-SortTwoFactors-6.pkl
# 114b_H-CDV-12.pkl
# 4a_V-SortTwoFactors-4.pkl
# 23a_H-SortTwoFactors-16.pkl
# 141b_V-SortOverall-17.pkl
# 82a_V-FE-17.pkl
# 45a_H-SortOverall-14.pkl
# 52b_H-FE-16.pkl
# 95a_H-SortOverall-4.pkl
# 64a_V-SortTwoFactors-2.pkl
# 82a_V-SortTwoFactors-4.pkl
# 95a_H-CDV-3.pkl
# 146a_V-SortTwoFactors-15.pkl
# 83b_V-RV-2.pkl
# 35a_H-SortTwoFactors-11.pkl
# 150b_H-FE-10.pkl
# 55b_V-RV-22.pkl
# 11b_V-CDV-14.pkl
# 137a_H-RV-8.pkl
# 2b_H-CDV-3.pkl
# 11a_H-CDV-21.pkl
# 131b_V-RV-15.pkl
# 58b_H-SortTwoFactors-24.pkl
# 92a_H-FE-20.pkl
# 137a_H-SortOverall-12.pkl
# 79b_V-FE-6.pkl
# 21a_H-SortOverall-10.pkl
# 17a_H-FE-4.pkl
# 28b_H-SortTwoFactors-20.pkl
# 65b_V-SortOverall-17.pkl
# 140b_H-FE-22.pkl
# 2b_H-RV-11.pkl
# 36b_H-SortTwoFactors-24.pkl
# 75a_H-RV-2.pkl
# 54a_V-SortOverall-6.pkl
# 13a_H-SortOverall-12.pkl
# 6b_H-SortTwoFactors-15.pkl
# 75b_V-FE-24.pkl
# 63a_H-SortOverall-11.pkl
# 56b_H-FE-22.pkl
# 90a_H-SortTwoFactors-16.pkl
# 25b_V-RV-5.pkl
# 40b_H-SortOverall-12.pkl
# 74a_V-CDV-16.pkl
# 100b_H-SortTwoFactors-21.pkl
# 86a_V-FE-21.pkl
# 4b_H-CDV-11.pkl
# 39b_V-RV-4.pkl
# 93a_V-CDV-14.pkl
# 128a_V-SortTwoFactors-17.pkl
# 30b_H-FE-11.pkl
# 10b_H-SortOverall-6.pkl
# 111a_H-SortOverall-15.pkl
# 39b_V-CDV-20.pkl
# 83a_H-SortOverall-15.pkl
# 72b_H-RV-12.pkl
# 45b_V-RV-12.pkl
# 14a_V-SortTwoFactors-24.pkl
# 77a_H-CDV-12.pkl
# 87a_V-CDV-11.pkl
# 114b_H-SortOverall-11.pkl
# 86b_H-CDV-16.pkl
# 103b_V-SortOverall-14.pkl
# 150a_V-SortOverall-16.pkl
# 106b_H-RV-17.pkl
# 144b_H-SortOverall-2.pkl
# 93a_V-SortOverall-22.pkl
# 22a_V-SortOverall-10.pkl
# 71b_V-FE-12.pkl
# 143b_V-RV-20.pkl
# 131b_V-SortOverall-16.pkl
# 105a_H-SortOverall-12.pkl
# 66b_H-CDV-6.pkl
# 70a_V-SortTwoFactors-10.pkl
# 109a_H-RV-18.pkl
# 75b_V-CDV-10.pkl
# 7a_H-SortTwoFactors-15.pkl
# 79a_H-RV-15.pkl
# 37a_H-SortTwoFactors-24.pkl
# 30b_H-RV-20.pkl
# 15b_V-FE-5.pkl
# 9a_H-CDV-6.pkl
# 32b_H-FE-2.pkl
# 92a_H-SortTwoFactors-23.pkl
# 2b_H-FE-22.pkl
# 37b_V-FE-14.pkl
# 65b_V-SortTwoFactors-22.pkl
# 125a_H-RV-4.pkl
# 84a_V-CDV-14.pkl
# 13a_H-CDV-14.pkl
# 28b_H-SortOverall-6.pkl
# 29b_V-RV-3.pkl
# 148a_V-CDV-11.pkl
# 140a_V-SortTwoFactors-21.pkl
# 79a_H-RV-6.pkl
# 137b_V-FE-8.pkl
# 129a_H-SortOverall-8.pkl
# 3b_V-CDV-3.pkl
# 111a_H-SortTwoFactors-12.pkl
# 70b_H-FE-3.pkl
# 112a_V-SortOverall-4.pkl
# 40b_H-RV-18.pkl
# 64b_H-FE-16.pkl
# 54b_H-SortTwoFactors-24.pkl
# 12a_V-SortTwoFactors-12.pkl
# 2b_H-SortTwoFactors-8.pkl
# 95b_V-CDV-16.pkl
# 126b_H-SortOverall-8.pkl
# 30b_H-SortTwoFactors-10.pkl
# 83b_V-SortTwoFactors-20.pkl
# 31b_V-SortTwoFactors-9.pkl
# 57a_H-SortTwoFactors-11.pkl
# 103b_V-RV-21.pkl
# 66b_H-CDV-10.pkl
# 23a_H-SortOverall-15.pkl
# 140b_H-SortOverall-10.pkl
# 128a_V-SortOverall-16.pkl
# 17b_V-SortOverall-11.pkl
# 145b_V-CDV-9.pkl
# 63b_V-SortTwoFactors-14.pkl
# 25b_V-RV-24.pkl
# 104b_H-RV-18.pkl
# 32a_V-FE-8.pkl
# 8a_V-CDV-4.pkl
# 94a_H-SortTwoFactors-15.pkl
# 12b_H-RV-24.pkl
# 133b_V-RV-18.pkl
# 149b_V-SortOverall-16.pkl
# 74a_V-SortOverall-3.pkl
# 35b_V-CDV-4.pkl
# 83a_H-CDV-8.pkl
# 93a_V-RV-9.pkl
# 77b_V-SortTwoFactors-24.pkl
# 12b_H-RV-18.pkl
# 25b_V-RV-18.pkl
# 121a_H-SortTwoFactors-2.pkl
# 7b_V-FE-14.pkl
# 114b_H-RV-16.pkl
# 22b_H-FE-5.pkl
# 84a_V-SortTwoFactors-9.pkl
# 47a_H-SortOverall-11.pkl
# 110a_V-SortOverall-10.pkl
# 72a_V-RV-8.pkl
# 107a_H-SortOverall-15.pkl
# 138a_V-FE-12.pkl
# 17b_V-CDV-20.pkl
# 129a_H-RV-2.pkl
# 142a_V-SortTwoFactors-16.pkl
# 21b_V-SortOverall-9.pkl
# 65b_V-SortOverall-9.pkl
# 142b_H-FE-8.pkl
# 116b_H-SortOverall-17.pkl
# 16b_H-RV-11.pkl
# 29a_H-SortOverall-10.pkl
# 47b_V-RV-20.pkl
# 64b_H-SortOverall-11.pkl
# 64b_H-CDV-8.pkl
# 126a_V-SortTwoFactors-23.pkl
# 10a_V-SortTwoFactors-24.pkl
# 90a_H-FE-10.pkl
# 36b_H-FE-17.pkl
# 65b_V-CDV-15.pkl
# 21b_V-CDV-3.pkl
# 87a_V-SortOverall-2.pkl
# 84b_H-SortTwoFactors-9.pkl
# 31b_V-RV-23.pkl
# 8b_H-SortTwoFactors-23.pkl
# 149a_H-RV-18.pkl
# 4b_H-RV-15.pkl
# 104b_H-SortTwoFactors-21.pkl
# 2b_H-SortTwoFactors-17.pkl
# 123b_V-CDV-5.pkl
# 25b_V-FE-14.pkl
# 12b_H-FE-14.pkl
# 118a_V-FE-24.pkl
# 67b_V-RV-17.pkl
# 50b_H-RV-17.pkl
# 75b_V-FE-3.pkl
# 100a_V-FE-3.pkl
# 133b_V-FE-14.pkl
# 96b_H-SortOverall-8.pkl
# 22b_H-RV-20.pkl
# 77b_V-SortTwoFactors-6.pkl
# 70b_H-FE-11.pkl
# 100b_H-FE-20.pkl
# 32b_H-RV-12.pkl
# 137b_V-FE-20.pkl
# 7b_V-RV-24.pkl
# 106b_H-CDV-22.pkl
# 55b_V-SortTwoFactors-5.pkl
# 93a_V-FE-21.pkl
# 128a_V-CDV-2.pkl
# 7b_V-RV-18.pkl
# 67a_H-CDV-17.pkl
# 130b_H-RV-14.pkl
# 112b_H-SortOverall-6.pkl
# 75b_V-RV-16.pkl
# 43b_V-SortOverall-2.pkl
# 4a_V-RV-6.pkl
# 139a_H-RV-4.pkl
# 45a_H-RV-9.pkl
# 72b_H-FE-22.pkl
# 10a_V-CDV-11.pkl
# 86a_V-CDV-3.pkl
# 84a_V-SortTwoFactors-15.pkl
# 137b_V-SortTwoFactors-10.pkl
# 38b_H-CDV-12.pkl
# 65b_V-RV-18.pkl
# 82a_V-SortOverall-3.pkl
# 52b_H-RV-18.pkl
# 140b_H-CDV-2.pkl
# 129b_V-SortTwoFactors-14.pkl
# 141a_H-SortTwoFactors-9.pkl
# 144a_V-SortTwoFactors-21.pkl
# 46b_H-RV-22.pkl
# 143b_V-FE-10.pkl
# 105b_V-CDV-9.pkl
# 144b_H-RV-18.pkl
# 65b_V-RV-24.pkl
# 33b_V-RV-10.pkl
# 10b_H-RV-16.pkl
# 3b_V-RV-4.pkl
# 112a_V-SortOverall-16.pkl
# 62b_V-CDV-11.pkl
# 105b_V-FE-8.pkl
# 93b_H-SortTwoFactors-20.pkl
# 93b_H-SortOverall-9.pkl
# 34b_H-FE-24.pkl
# 64a_V-SortTwoFactors-21.pkl
# 129a_H-CDV-24.pkl
# 46b_H-SortTwoFactors-3.pkl
# 77a_H-SortOverall-15.pkl
# 86a_V-SortTwoFactors-22.pkl
# 106a_V-SortOverall-11.pkl
# 61b_H-SortOverall-24.pkl
# 7a_H-CDV-21.pkl
# 13b_V-FE-16.pkl
# 90a_H-CDV-11.pkl
# 72b_H-SortOverall-11.pkl
# 45a_H-SortTwoFactors-16.pkl
# 10a_V-SortOverall-4.pkl
# 86b_H-FE-8.pkl
# 58a_V-SortOverall-16.pkl
# 67b_V-SortTwoFactors-14.pkl
# 95a_H-SortTwoFactors-6.pkl
# 116b_H-RV-18.pkl
# 35a_H-SortOverall-3.pkl
# 6b_H-RV-5.pkl
# 121b_V-RV-18.pkl
# 123a_H-SortOverall-16.pkl
# 126b_H-FE-10.pkl
